# %%
#Start here with Justin

# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#Use the citipy module to determine city based on latitude and longitude.
# %pip install citipy
from citipy import citipy
# Out:
# Requirement already satisfied: citipy in c:\users\mjrot\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\mjrot\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
 # Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 646

# %%
#starting mod 626
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
##HERE?  dot this below too?  
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a32531e6ef8d14acfd43407075a03339

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a32531e6ef8d14acfd43407075a03339&q=Boston

# %%
#mod 6.2.4
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}],"base":"stations","main":{"temp":65.5,"feels_like":66.11,"temp_min":63.95,"temp_max":68.49,"pressure":1024,"humidity":93},"visibility":10000,"wind":{"speed":1.01,"deg":146,"gust":3},"clouds":{"all":90},"dt":1626134993,"sys":{"type":2,"id":2013408,"country":"US","sunrise":1626081503,"sunset":1626135659},"timezone":-14400,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 65.5,
#   'feels_like': 66.11,
#   'temp_min': 63.95,
#   'temp_max': 68.49,
#   'pressure': 1024,
#   'humidity': 93},
#  'visibility': 10000,
#  'wind': {'speed': 1.01, 'deg': 146, 'gust': 3},
#  'clouds': {'all': 90},
#  'dt': 1626134993,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1626081503,
#   'sunset': 1626135659},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
print(city_url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a32531e6ef8d14acfd43407075a03339&q=Boston

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
  
#Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
        # Parse out the needed data.
            city_lat = city_weather["coord"]["lat"]
            city_lng = city_weather["coord"]["lon"]
            city_max_temp = city_weather["main"]["temp_max"]
            city_humidity = city_weather["main"]["humidity"]
            city_clouds = city_weather["clouds"]["all"]
            city_wind = city_weather["wind"]["speed"]
            city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
            city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
            city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
# If an error is experienced, skip the city.
    except:
            print("City not found. Skipping...")
    pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
record_count += 1
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ribeira grande
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | tazovskiy
# Processing Record 4 of Set 1 | severo-yeniseyskiy
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | hilo
# Processing Record 7 of Set 1 | san quintin
# Processing Record 8 of Set 1 | longyearbyen
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | east london
# Processing Record 11 of Set 1 | asau
# Processing Record 12 of Set 1 | new norfolk
# Processing Record 13 of Set 1 | banda aceh
# Processing Record 14 of Set 1 | labuhan
# Processing Record 15 of Set 1 | fortuna
# Processing Record 16 of Set 1 | anloga
# Processing Record 17 of Set 1 | bathsheba
# Processing Record 18 of Set 1 | notodden
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | villa union
# Processing Record 21 of Set 1 | magdagachi
# Processing Record 22 of Set 1 | troitskoye
# Processing Record 23 of Set 1 | chuy
# Processing Record 24 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 1 | kenai
# Processing Record 26 of Set 1 | katherine
# Processing Record 27 of Set 1 | boke
# Processing Record 28 of Set 1 | qaanaaq
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | sao jose da coroa grande
# Processing Record 31 of Set 1 | clarence town
# Processing Record 32 of Set 1 | port macquarie
# Processing Record 33 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 1 | bredasdorp
# Processing Record 35 of Set 1 | saint-philippe
# Processing Record 36 of Set 1 | muisne
# Processing Record 37 of Set 1 | grindavik
# Processing Record 38 of Set 1 | williams lake
# Processing Record 39 of Set 1 | kaitangata
# Processing Record 40 of Set 1 | ponta do sol
# Processing Record 41 of Set 1 | samarai
# Processing Record 42 of Set 1 | college
# Processing Record 43 of Set 1 | navabad
# City not found. Skipping...
# Processing Record 44 of Set 1 | kapaa
# Processing Record 45 of Set 1 | hobart
# Processing Record 46 of Set 1 | imeni poliny osipenko
# Processing Record 47 of Set 1 | kieta
# Processing Record 48 of Set 1 | ushuaia
# Processing Record 49 of Set 1 | nikolskoye
# Processing Record 50 of Set 1 | barrow
# Processing Record 1 of Set 2 | caravelas
# Processing Record 2 of Set 2 | cordoba
# Processing Record 3 of Set 2 | coahuayana
# Processing Record 4 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 2 | morondava
# Processing Record 6 of Set 2 | punta arenas
# Processing Record 7 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 8 of Set 2 | bethel
# Processing Record 9 of Set 2 | suez
# Processing Record 10 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 2 | mason city
# Processing Record 12 of Set 2 | ngorongoro
# Processing Record 13 of Set 2 | mataura
# Processing Record 14 of Set 2 | bronnoysund
# Processing Record 15 of Set 2 | hoi an
# Processing Record 16 of Set 2 | vaini
# Processing Record 17 of Set 2 | kununurra
# Processing Record 18 of Set 2 | sept-iles
# Processing Record 19 of Set 2 | margate
# Processing Record 20 of Set 2 | beira
# Processing Record 21 of Set 2 | pontianak
# Processing Record 22 of Set 2 | busselton
# Processing Record 23 of Set 2 | port elizabeth
# Processing Record 24 of Set 2 | akureyri
# Processing Record 25 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 2 | constitucion
# Processing Record 27 of Set 2 | tiksi
# Processing Record 28 of Set 2 | tabon
# Processing Record 29 of Set 2 | airai
# Processing Record 30 of Set 2 | japura
# Processing Record 31 of Set 2 | ilulissat
# Processing Record 32 of Set 2 | victoria
# Processing Record 33 of Set 2 | mehamn
# Processing Record 34 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 2 | cockburn town
# Processing Record 36 of Set 2 | bengkulu
# Processing Record 37 of Set 2 | butaritari
# Processing Record 38 of Set 2 | urucara
# Processing Record 39 of Set 2 | taoudenni
# Processing Record 40 of Set 2 | hithadhoo
# Processing Record 41 of Set 2 | kodiak
# Processing Record 42 of Set 2 | katsuura
# Processing Record 43 of Set 2 | upernavik
# Processing Record 44 of Set 2 | port alfred
# Processing Record 45 of Set 2 | skiros
# City not found. Skipping...
# Processing Record 46 of Set 2 | balkhash
# Processing Record 47 of Set 2 | melfi
# Processing Record 48 of Set 2 | saskylakh
# Processing Record 49 of Set 2 | verkhoshizhemye
# Processing Record 50 of Set 2 | arraial do cabo
# Processing Record 1 of Set 3 | shitanjing
# Processing Record 2 of Set 3 | lobva
# Processing Record 3 of Set 3 | burkhala
# City not found. Skipping...
# Processing Record 4 of Set 3 | thompson
# Processing Record 5 of Set 3 | hay river
# Processing Record 6 of Set 3 | karratha
# Processing Record 7 of Set 3 | sitka
# Processing Record 8 of Set 3 | medea
# Processing Record 9 of Set 3 | castro
# Processing Record 10 of Set 3 | fairbanks
# Processing Record 11 of Set 3 | key west
# Processing Record 12 of Set 3 | berdyuzhye
# City not found. Skipping...
# Processing Record 13 of Set 3 | port augusta
# Processing Record 14 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 3 | khatanga
# Processing Record 16 of Set 3 | boende
# Processing Record 17 of Set 3 | salalah
# Processing Record 18 of Set 3 | iqaluit
# Processing Record 19 of Set 3 | tura
# Processing Record 20 of Set 3 | torbay
# Processing Record 21 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 23 of Set 3 | soke
# Processing Record 24 of Set 3 | princeton
# Processing Record 25 of Set 3 | chokurdakh
# Processing Record 26 of Set 3 | abapo
# Processing Record 27 of Set 3 | provideniya
# Processing Record 28 of Set 3 | vila franca do campo
# Processing Record 29 of Set 3 | leningradskiy
# Processing Record 30 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 31 of Set 3 | rincon de la victoria
# Processing Record 32 of Set 3 | severnyy
# Processing Record 33 of Set 3 | hasaki
# Processing Record 34 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 3 | mahon
# Processing Record 37 of Set 3 | norman wells
# Processing Record 38 of Set 3 | taltal
# Processing Record 39 of Set 3 | freeport
# Processing Record 40 of Set 3 | puksoozero
# Processing Record 41 of Set 3 | laguna
# Processing Record 42 of Set 3 | kaeo
# Processing Record 43 of Set 3 | hambantota
# Processing Record 44 of Set 3 | rio grande
# Processing Record 45 of Set 3 | avarua
# Processing Record 46 of Set 3 | atuona
# Processing Record 47 of Set 3 | alofi
# Processing Record 48 of Set 3 | shingu
# Processing Record 49 of Set 3 | roald
# Processing Record 50 of Set 3 | carnarvon
# Processing Record 1 of Set 4 | weligama
# Processing Record 2 of Set 4 | kawana waters
# City not found. Skipping...
# Processing Record 3 of Set 4 | rocha
# Processing Record 4 of Set 4 | cayenne
# Processing Record 5 of Set 4 | saint george
# Processing Record 6 of Set 4 | sobolevo
# Processing Record 7 of Set 4 | kondinskoye
# Processing Record 8 of Set 4 | tuktoyaktuk
# Processing Record 9 of Set 4 | sao desiderio
# Processing Record 10 of Set 4 | kupang
# Processing Record 11 of Set 4 | coari
# Processing Record 12 of Set 4 | porto novo
# Processing Record 13 of Set 4 | tucuman
# Processing Record 14 of Set 4 | kindu
# Processing Record 15 of Set 4 | pangody
# Processing Record 16 of Set 4 | itatiaia
# Processing Record 17 of Set 4 | bestobe
# Processing Record 18 of Set 4 | bambanglipuro
# Processing Record 19 of Set 4 | cape town
# Processing Record 20 of Set 4 | haines junction
# Processing Record 21 of Set 4 | batagay-alyta
# Processing Record 22 of Set 4 | ossora
# Processing Record 23 of Set 4 | bluff
# Processing Record 24 of Set 4 | sangar
# Processing Record 25 of Set 4 | rundu
# Processing Record 26 of Set 4 | dunedin
# Processing Record 27 of Set 4 | lingao
# Processing Record 28 of Set 4 | portland
# Processing Record 29 of Set 4 | coihaique
# Processing Record 30 of Set 4 | ust-tsilma
# Processing Record 31 of Set 4 | gravdal
# Processing Record 32 of Set 4 | oussouye
# Processing Record 33 of Set 4 | lebu
# Processing Record 34 of Set 4 | sao filipe
# Processing Record 35 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 4 | strezhevoy
# Processing Record 37 of Set 4 | uramita
# Processing Record 38 of Set 4 | taian
# Processing Record 39 of Set 4 | nanortalik
# Processing Record 40 of Set 4 | anshun
# Processing Record 41 of Set 4 | vieste
# Processing Record 42 of Set 4 | gizo
# Processing Record 43 of Set 4 | pervomayskiy
# Processing Record 44 of Set 4 | oranzherei
# Processing Record 45 of Set 4 | brae
# Processing Record 46 of Set 4 | port blair
# Processing Record 47 of Set 4 | saldanha
# Processing Record 48 of Set 4 | klaksvik
# Processing Record 49 of Set 4 | sola
# Processing Record 50 of Set 4 | tagusao
# Processing Record 1 of Set 5 | victoria point
# Processing Record 2 of Set 5 | cherskiy
# Processing Record 3 of Set 5 | astana
# Processing Record 4 of Set 5 | bodden town
# Processing Record 5 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 5 | jamestown
# Processing Record 7 of Set 5 | goure
# Processing Record 8 of Set 5 | eureka
# Processing Record 9 of Set 5 | enumclaw
# Processing Record 10 of Set 5 | severo-kurilsk
# Processing Record 11 of Set 5 | whitehorse
# Processing Record 12 of Set 5 | mahebourg
# Processing Record 13 of Set 5 | shenzhen
# Processing Record 14 of Set 5 | evansville
# Processing Record 15 of Set 5 | praia
# Processing Record 16 of Set 5 | mar del plata
# Processing Record 17 of Set 5 | pandan
# Processing Record 18 of Set 5 | lakatoro
# Processing Record 19 of Set 5 | lavrentiya
# Processing Record 20 of Set 5 | ibra
# Processing Record 21 of Set 5 | lata
# Processing Record 22 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 5 | arlit
# Processing Record 24 of Set 5 | northam
# Processing Record 25 of Set 5 | nanga eboko
# Processing Record 26 of Set 5 | bambamarca
# Processing Record 27 of Set 5 | ahipara
# Processing Record 28 of Set 5 | cabangahan
# Processing Record 29 of Set 5 | defiance
# Processing Record 30 of Set 5 | zaragoza
# Processing Record 31 of Set 5 | fort nelson
# Processing Record 32 of Set 5 | berdigestyakh
# Processing Record 33 of Set 5 | talnakh
# Processing Record 34 of Set 5 | vestmannaeyjar
# Processing Record 35 of Set 5 | lompoc
# Processing Record 36 of Set 5 | meulaboh
# Processing Record 37 of Set 5 | skjervoy
# Processing Record 38 of Set 5 | vardo
# Processing Record 39 of Set 5 | sorland
# Processing Record 40 of Set 5 | benghazi
# Processing Record 41 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 5 | saryozek
# Processing Record 43 of Set 5 | beyneu
# Processing Record 44 of Set 5 | acaponeta
# Processing Record 45 of Set 5 | necochea
# Processing Record 46 of Set 5 | hobyo
# Processing Record 47 of Set 5 | snyder
# Processing Record 48 of Set 5 | lumsden
# Processing Record 49 of Set 5 | antalaha
# Processing Record 50 of Set 5 | malindi
# Processing Record 1 of Set 6 | tromso
# Processing Record 2 of Set 6 | montalban
# Processing Record 3 of Set 6 | oriximina
# Processing Record 4 of Set 6 | harda
# Processing Record 5 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 6 of Set 6 | dakar
# Processing Record 7 of Set 6 | port-gentil
# Processing Record 8 of Set 6 | torbat-e jam
# Processing Record 9 of Set 6 | ankang
# Processing Record 10 of Set 6 | narsaq
# Processing Record 11 of Set 6 | axim
# Processing Record 12 of Set 6 | seymchan
# Processing Record 13 of Set 6 | jacqueville
# Processing Record 14 of Set 6 | salisbury
# Processing Record 15 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 16 of Set 6 | santa cruz
# Processing Record 17 of Set 6 | lasa
# Processing Record 18 of Set 6 | rudsar
# Processing Record 19 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 6 | beauchamps
# Processing Record 21 of Set 6 | pasighat
# Processing Record 22 of Set 6 | chinsali
# Processing Record 23 of Set 6 | canazas
# Processing Record 24 of Set 6 | georgetown
# Processing Record 25 of Set 6 | conceicao do mato dentro
# Processing Record 26 of Set 6 | kangaatsiaq
# Processing Record 27 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 28 of Set 6 | baniachang
# Processing Record 29 of Set 6 | gedo
# Processing Record 30 of Set 6 | bilma
# Processing Record 31 of Set 6 | atar
# Processing Record 32 of Set 6 | cirpan
# City not found. Skipping...
# Processing Record 33 of Set 6 | sicamous
# Processing Record 34 of Set 6 | alugan
# Processing Record 35 of Set 6 | pevek
# Processing Record 36 of Set 6 | dharchula
# Processing Record 37 of Set 6 | opole lubelskie
# Processing Record 38 of Set 6 | hengyang
# Processing Record 39 of Set 6 | amantea
# Processing Record 40 of Set 6 | boyabat
# Processing Record 41 of Set 6 | dergachi
# Processing Record 42 of Set 6 | garango
# Processing Record 43 of Set 6 | khormuj
# City not found. Skipping...
# Processing Record 44 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 6 | kapuskasing
# Processing Record 46 of Set 6 | clyde river
# Processing Record 47 of Set 6 | tutoia
# Processing Record 48 of Set 6 | sambava
# Processing Record 49 of Set 6 | khawhai
# Processing Record 50 of Set 6 | tasiilaq
# Processing Record 1 of Set 7 | kavieng
# Processing Record 2 of Set 7 | cavnic
# Processing Record 3 of Set 7 | waddan
# Processing Record 4 of Set 7 | puerto escondido
# Processing Record 5 of Set 7 | bereznik
# Processing Record 6 of Set 7 | hede
# Processing Record 7 of Set 7 | tubuala
# Processing Record 8 of Set 7 | tiznit
# Processing Record 9 of Set 7 | desna
# Processing Record 10 of Set 7 | pinehurst
# Processing Record 11 of Set 7 | cabo san lucas
# Processing Record 12 of Set 7 | husavik
# Processing Record 13 of Set 7 | tautira
# Processing Record 14 of Set 7 | imbituba
# Processing Record 15 of Set 7 | bairiki
# Processing Record 16 of Set 7 | agaro
# Processing Record 17 of Set 7 | sarai
# Processing Record 18 of Set 7 | vanimo
# Processing Record 19 of Set 7 | hovd
# Processing Record 20 of Set 7 | hearst
# Processing Record 21 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 22 of Set 7 | lagoa
# Processing Record 23 of Set 7 | olafsvik
# Processing Record 24 of Set 7 | jasper
# Processing Record 25 of Set 7 | sindor
# Processing Record 26 of Set 7 | guerrero negro
# Processing Record 27 of Set 7 | xiantao
# Processing Record 28 of Set 7 | bambous virieux
# Processing Record 29 of Set 7 | tuatapere
# Processing Record 30 of Set 7 | huangmei
# Processing Record 31 of Set 7 | ballyshannon
# Processing Record 32 of Set 7 | hualmay
# Processing Record 33 of Set 7 | beloha
# Processing Record 34 of Set 7 | kasra
# City not found. Skipping...
# Processing Record 35 of Set 7 | isangel
# Processing Record 36 of Set 7 | benguela
# Processing Record 37 of Set 7 | bandarbeyla
# Processing Record 38 of Set 7 | zhangjiakou
# Processing Record 39 of Set 7 | cap malheureux
# Processing Record 40 of Set 7 | mopipi
# Processing Record 41 of Set 7 | sao francisco
# Processing Record 42 of Set 7 | berlevag
# Processing Record 43 of Set 7 | san isidro
# Processing Record 44 of Set 7 | korla
# Processing Record 45 of Set 7 | simao
# Processing Record 46 of Set 7 | waingapu
# Processing Record 47 of Set 7 | baruun-urt
# Processing Record 48 of Set 7 | san javier
# Processing Record 49 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 7 | luanda
# Processing Record 1 of Set 8 | narrabri
# Processing Record 2 of Set 8 | kendari
# Processing Record 3 of Set 8 | durban
# Processing Record 4 of Set 8 | bariadi
# Processing Record 5 of Set 8 | urumqi
# Processing Record 6 of Set 8 | galle
# Processing Record 7 of Set 8 | takoradi
# Processing Record 8 of Set 8 | quang ngai
# Processing Record 9 of Set 8 | talcahuano
# Processing Record 10 of Set 8 | half moon bay
# Processing Record 11 of Set 8 | gimli
# Processing Record 12 of Set 8 | ewa beach
# Processing Record 13 of Set 8 | pangnirtung
# Processing Record 14 of Set 8 | swan river
# Processing Record 15 of Set 8 | chapais
# Processing Record 16 of Set 8 | bibiani
# Processing Record 17 of Set 8 | touros
# Processing Record 18 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 19 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 20 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 21 of Set 8 | quelimane
# Processing Record 22 of Set 8 | kahului
# Processing Record 23 of Set 8 | mao
# Processing Record 24 of Set 8 | acapulco
# Processing Record 25 of Set 8 | linqiong
# Processing Record 26 of Set 8 | esperance
# Processing Record 27 of Set 8 | pillaro
# Processing Record 28 of Set 8 | salinopolis
# Processing Record 29 of Set 8 | west lafayette
# Processing Record 30 of Set 8 | sainte-marie
# Processing Record 31 of Set 8 | mayumba
# Processing Record 32 of Set 8 | qinggang
# Processing Record 33 of Set 8 | jingdezhen
# Processing Record 34 of Set 8 | codrington
# Processing Record 35 of Set 8 | monroe
# Processing Record 36 of Set 8 | hamilton
# Processing Record 37 of Set 8 | luganville
# Processing Record 38 of Set 8 | faya
# Processing Record 39 of Set 8 | nabire
# Processing Record 40 of Set 8 | toucheng
# Processing Record 41 of Set 8 | itarema
# Processing Record 42 of Set 8 | arman
# Processing Record 43 of Set 8 | saravan
# Processing Record 44 of Set 8 | nome
# Processing Record 45 of Set 8 | broome
# Processing Record 46 of Set 8 | ixtlahuacan del rio
# Processing Record 47 of Set 8 | ternate
# Processing Record 48 of Set 8 | vila
# Processing Record 49 of Set 8 | tual
# Processing Record 50 of Set 8 | bandar-e lengeh
# Processing Record 1 of Set 9 | ancud
# Processing Record 2 of Set 9 | bukene
# Processing Record 3 of Set 9 | bridgetown
# Processing Record 4 of Set 9 | pran buri
# Processing Record 5 of Set 9 | dingle
# Processing Record 6 of Set 9 | namatanai
# Processing Record 7 of Set 9 | tukan
# Processing Record 8 of Set 9 | humaita
# Processing Record 9 of Set 9 | nemuro
# Processing Record 10 of Set 9 | aquiraz
# Processing Record 11 of Set 9 | port lincoln
# Processing Record 12 of Set 9 | yanam
# Processing Record 13 of Set 9 | san patricio
# Processing Record 14 of Set 9 | faanui
# Processing Record 15 of Set 9 | thinadhoo
# Processing Record 16 of Set 9 | muscat
# Processing Record 17 of Set 9 | pechenga
# Processing Record 18 of Set 9 | ratnagiri
# Processing Record 19 of Set 9 | gao
# Processing Record 20 of Set 9 | aripuana
# Processing Record 21 of Set 9 | huarmey
# Processing Record 22 of Set 9 | muros
# Processing Record 23 of Set 9 | opuwo
# Processing Record 24 of Set 9 | vestmanna
# Processing Record 25 of Set 9 | san juan
# Processing Record 26 of Set 9 | north bend
# Processing Record 27 of Set 9 | port hedland
# Processing Record 28 of Set 9 | raudeberg
# Processing Record 29 of Set 9 | alyangula
# Processing Record 30 of Set 9 | uige
# Processing Record 31 of Set 9 | pemangkat
# Processing Record 32 of Set 9 | atambua
# Processing Record 33 of Set 9 | palmer
# Processing Record 34 of Set 9 | wanaka
# Processing Record 35 of Set 9 | acin
# City not found. Skipping...
# Processing Record 36 of Set 9 | santiago de cuba
# Processing Record 37 of Set 9 | padang
# Processing Record 38 of Set 9 | sayyan
# Processing Record 39 of Set 9 | tecoanapa
# Processing Record 40 of Set 9 | usinsk
# Processing Record 41 of Set 9 | saint-augustin
# Processing Record 42 of Set 9 | lakes entrance
# Processing Record 43 of Set 9 | rio gallegos
# Processing Record 44 of Set 9 | escarcega
# Processing Record 45 of Set 9 | abu samrah
# Processing Record 46 of Set 9 | claresholm
# Processing Record 47 of Set 9 | soyo
# Processing Record 48 of Set 9 | dubenskiy
# City not found. Skipping...
# Processing Record 49 of Set 9 | siteki
# Processing Record 50 of Set 9 | vari
# Processing Record 1 of Set 10 | mananara
# Processing Record 2 of Set 10 | henties bay
# Processing Record 3 of Set 10 | luwuk
# Processing Record 4 of Set 10 | bud
# Processing Record 5 of Set 10 | tigil
# Processing Record 6 of Set 10 | mount gambier
# Processing Record 7 of Set 10 | tucuma
# Processing Record 8 of Set 10 | lahaina
# Processing Record 9 of Set 10 | excelsior springs
# Processing Record 10 of Set 10 | svetlyy
# Processing Record 11 of Set 10 | okhotsk
# Processing Record 12 of Set 10 | puerto narino
# Processing Record 13 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 14 of Set 10 | la romana
# Processing Record 15 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 16 of Set 10 | kongolo
# Processing Record 17 of Set 10 | riyadh
# Processing Record 18 of Set 10 | santiago del estero
# Processing Record 19 of Set 10 | yasnyy
# Processing Record 20 of Set 10 | talara
# Processing Record 21 of Set 10 | ucluelet
# Processing Record 22 of Set 10 | poya
# Processing Record 23 of Set 10 | nileshwar
# Processing Record 24 of Set 10 | port hardy
# Processing Record 25 of Set 10 | kurumkan
# Processing Record 26 of Set 10 | inongo
# Processing Record 27 of Set 10 | salinas
# Processing Record 28 of Set 10 | myitkyina
# Processing Record 29 of Set 10 | egvekinot
# Processing Record 30 of Set 10 | altona
# Processing Record 31 of Set 10 | bom jesus
# Processing Record 32 of Set 10 | listvyanskiy
# Processing Record 33 of Set 10 | qingdao
# Processing Record 34 of Set 10 | bairnsdale
# Processing Record 35 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 10 | pochutla
# Processing Record 37 of Set 10 | sozimskiy
# Processing Record 38 of Set 10 | atka
# City not found. Skipping...
# Processing Record 39 of Set 10 | bubaque
# Processing Record 40 of Set 10 | coquimbo
# Processing Record 41 of Set 10 | antibes
# Processing Record 42 of Set 10 | lac du bonnet
# Processing Record 43 of Set 10 | manuk mangkaw
# Processing Record 44 of Set 10 | bulawayo
# Processing Record 45 of Set 10 | katha
# City not found. Skipping...
# Processing Record 46 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 47 of Set 10 | fethiye
# Processing Record 48 of Set 10 | havre-saint-pierre
# Processing Record 49 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 50 of Set 10 | roebourne
# Processing Record 1 of Set 11 | sao gabriel da cachoeira
# Processing Record 2 of Set 11 | solnechnyy
# Processing Record 3 of Set 11 | jacareacanga
# Processing Record 4 of Set 11 | lourdes
# Processing Record 5 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 6 of Set 11 | goderich
# Processing Record 7 of Set 11 | sotuta
# Processing Record 8 of Set 11 | simi
# Processing Record 9 of Set 11 | pokhara
# Processing Record 10 of Set 11 | khorixas
# Processing Record 11 of Set 11 | yar-sale
# Processing Record 12 of Set 11 | zhaotong
# Processing Record 13 of Set 11 | matara
# Processing Record 14 of Set 11 | shadrinsk
# Processing Record 15 of Set 11 | gulu
# Processing Record 16 of Set 11 | sinnamary
# Processing Record 17 of Set 11 | dalvik
# Processing Record 18 of Set 11 | finschhafen
# Processing Record 19 of Set 11 | cidreira
# Processing Record 20 of Set 11 | iguape
# Processing Record 21 of Set 11 | tooele
# Processing Record 22 of Set 11 | zeya
# Processing Record 23 of Set 11 | umm lajj
# Processing Record 24 of Set 11 | lucapa
# Processing Record 25 of Set 11 | jalu
# Processing Record 26 of Set 11 | saint-georges
# Processing Record 27 of Set 11 | moron
# Processing Record 28 of Set 11 | tanout
# Processing Record 29 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 11 | chunhuhub
# Processing Record 31 of Set 11 | tarata
# Processing Record 32 of Set 11 | el sauzal
# Processing Record 33 of Set 11 | umm kaddadah
# Processing Record 34 of Set 11 | kysyl-syr
# Processing Record 35 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 11 | kurilsk
# Processing Record 37 of Set 11 | muzhi
# Processing Record 38 of Set 11 | alice springs
# Processing Record 39 of Set 11 | pontian kecil
# Processing Record 40 of Set 11 | sieradz
# Processing Record 41 of Set 11 | colac
# Processing Record 42 of Set 11 | kruisfontein
# Processing Record 43 of Set 11 | parker
# Processing Record 44 of Set 11 | viedma
# Processing Record 45 of Set 11 | veraval
# Processing Record 46 of Set 11 | akmene
# Processing Record 47 of Set 11 | loreto
# Processing Record 48 of Set 11 | pirovskoye
# Processing Record 49 of Set 11 | shubarkuduk
# Processing Record 50 of Set 11 | varkkallai
# Processing Record 1 of Set 12 | zaysan
# Processing Record 2 of Set 12 | nelson
# Processing Record 3 of Set 12 | marsabit
# Processing Record 4 of Set 12 | sao joao da barra
# Processing Record 5 of Set 12 | okato
# Processing Record 6 of Set 12 | hami
# Processing Record 7 of Set 12 | yarim
# Processing Record 8 of Set 12 | kifri
# Processing Record 9 of Set 12 | biysk
# Processing Record 10 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 12 | teknaf
# Processing Record 12 of Set 12 | belyy yar
# Processing Record 13 of Set 12 | saint anthony
# Processing Record 14 of Set 12 | zyryanka
# Processing Record 15 of Set 12 | mezen
# Processing Record 16 of Set 12 | magadan
# Processing Record 17 of Set 12 | aksay
# Processing Record 18 of Set 12 | bossembele
# City not found. Skipping...
# Processing Record 19 of Set 12 | keroka
# Processing Record 20 of Set 12 | gornyy
# Processing Record 21 of Set 12 | kermanshah
# Processing Record 22 of Set 12 | xinzhou
# Processing Record 23 of Set 12 | chongwe
# Processing Record 24 of Set 12 | vaitape
# Processing Record 25 of Set 12 | te anau
# Processing Record 26 of Set 12 | bardiyah
# Processing Record 27 of Set 12 | magan
# Processing Record 28 of Set 12 | pekan
# Processing Record 29 of Set 12 | dikson
# Processing Record 30 of Set 12 | porbandar
# Processing Record 31 of Set 12 | inta
# Processing Record 32 of Set 12 | gotsu
# Processing Record 33 of Set 12 | emba
# Processing Record 34 of Set 12 | andevoranto
# City not found. Skipping...
# Processing Record 35 of Set 12 | hire
# City not found. Skipping...
# Processing Record 36 of Set 12 | sisimiut
# Processing Record 37 of Set 12 | maputo
# Processing Record 38 of Set 12 | nyandoma
# Processing Record 39 of Set 12 | torrington
# Processing Record 40 of Set 12 | rusape
# Processing Record 41 of Set 12 | cam pha
# City not found. Skipping...
# Processing Record 42 of Set 12 | boguchany
# Processing Record 43 of Set 12 | upata
# Processing Record 44 of Set 12 | pingzhuang
# Processing Record 45 of Set 12 | playa vicente
# Processing Record 46 of Set 12 | ostrovnoy
# Processing Record 47 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 12 | aasiaat
# Processing Record 49 of Set 12 | mozarlandia
# Processing Record 50 of Set 12 | sjenica
# Processing Record 1 of Set 13 | pocone
# Processing Record 2 of Set 13 | beringovskiy
# Processing Record 3 of Set 13 | menomonie
# Processing Record 4 of Set 13 | fare
# Processing Record 5 of Set 13 | farah
# Processing Record 6 of Set 13 | inhambane
# Processing Record 7 of Set 13 | calama
# Processing Record 8 of Set 13 | wa
# City not found. Skipping...
# Processing Record 9 of Set 13 | lazaro cardenas
# Processing Record 10 of Set 13 | port said
# Processing Record 11 of Set 13 | okha
# Processing Record 12 of Set 13 | non thai
# Processing Record 13 of Set 13 | nizwa
# Processing Record 14 of Set 13 | quito
# Processing Record 15 of Set 13 | mayo
# Processing Record 16 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 13 | flinders
# Processing Record 18 of Set 13 | komsomolskiy
# Processing Record 19 of Set 13 | purpe
# Processing Record 20 of Set 13 | barrhead
# Processing Record 21 of Set 13 | teguise
# Processing Record 22 of Set 13 | kommunisticheskiy
# Processing Record 23 of Set 13 | blagoyevo
# Processing Record 24 of Set 13 | yulara
# Processing Record 25 of Set 13 | altay
# Processing Record 26 of Set 13 | agadez
# Processing Record 27 of Set 13 | bredy
# Processing Record 28 of Set 13 | muskegon
# Processing Record 29 of Set 13 | ola
# Processing Record 30 of Set 13 | awbari
# Processing Record 31 of Set 13 | hofn
# Processing Record 32 of Set 13 | pozzallo
# Processing Record 33 of Set 13 | nanakuli
# Processing Record 34 of Set 13 | christchurch
# Processing Record 35 of Set 13 | yerofey pavlovich
# Processing Record 36 of Set 13 | halifax
# Processing Record 37 of Set 13 | preobrazheniye
# Processing Record 38 of Set 13 | teahupoo
# Processing Record 39 of Set 13 | camacha
# Processing Record 40 of Set 13 | bilibino
# Processing Record 41 of Set 13 | harper
# Processing Record 42 of Set 13 | macas
# Processing Record 43 of Set 13 | uaua
# Processing Record 44 of Set 13 | rawson
# Processing Record 45 of Set 13 | nishihara
# Processing Record 46 of Set 13 | west wendover
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
######copying over from other file here on**************

# %%
#starting mod 626

# %%
#starting mod 626

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
  
#Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
        # Parse out the needed data.
            city_lat = city_weather["coord"]["lat"]
            city_lng = city_weather["coord"]["lon"]
            city_max_temp = city_weather["main"]["temp_max"]
            city_humidity = city_weather["main"]["humidity"]
            city_clouds = city_weather["clouds"]["all"]
            city_wind = city_weather["wind"]["speed"]
            city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
            city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
            city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
# If an error is experienced, skip the city.
    except:
            print("City not found. Skipping...")
    pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
record_count += 1
# Out:
# Beginning Data Retrieval
# -----------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-92e337bc1f0c> in <module>
#      17         record_count = 1
#      18     # Create endpoint URL with each city.
# ---> 19     city_url = url + "&q=" + city.replace(" ","+")
#      20
#      21     # Log the URL, record, and set numbers and the city.
#
# NameError: name 'url' is not defined

# %%
#starting mod 626

#starting mod 626
# Import the datetime module from the datetime library.
from datetime import datetime

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
  
 #Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
        # Parse out the needed data.
            city_lat = city_weather["coord"]["lat"]
            city_lng = city_weather["coord"]["lon"]
            city_max_temp = city_weather["main"]["temp_max"]
            city_humidity = city_weather["main"]["humidity"]
            city_clouds = city_weather["clouds"]["all"]
            city_wind = city_weather["wind"]["speed"]
            city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
            city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
            city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
# If an error is experienced, skip the city.
    except:
            print("City not found. Skipping...")
    pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
record_count += 1
# Out:
# Beginning Data Retrieval
# -----------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-6e320ae52125> in <module>
#      23         record_count = 1
#      24     # Create endpoint URL with each city.
# ---> 25     city_url = url + "&q=" + city.replace(" ","+")
#      26
#      27     # Log the URL, record, and set numbers and the city.
#
# NameError: name 'url' is not defined

# %%
 ##START dataframe creation here

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#organize the columns in the DataFrame.  ###????
city_data_df = city_data_df[['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
                             'Wind Speed', ]]
city_data_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-04a0393a446d> in <module>
#       1 #organize the columns in the DataFrame.  ###????
# ----> 2 city_data_df = city_data_df[['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#       3                              'Wind Speed', ]]
#       4 city_data_df.head(10)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1306             if missing == len(indexer):
#    1307                 axis_name = self.obj._get_axis_name(axis)
# -> 1308                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1309
#    1310             ax = self.obj._get_axis(axis)
#
# KeyError: "None of [Index(['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity',\n       'Cloudiness', 'Wind Speed'],\n      dtype='object')] are in the [columns]"

# %%
# Create the output file (CSV).   this is not working   
#output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
#city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
#START PLOTTING CODE 
#1st get data

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Lat'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-3b701faf1e14> in <module>
#       1 # Extract relevant fields from the DataFrame for plotting.
# ----> 2 lats = city_data_df["Lat"]
#       3 max_temps = city_data_df["Max Temp"]
#       4 humidity = city_data_df["Humidity"]
#       5 cloudiness = city_data_df["Cloudiness"]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Lat'

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today
# Out:
# 1626134822.137951

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-5734c8a754b4> in <module>
#       4 # Build the scatter plot for latitude vs. max temperature.
#       5 plt.scatter(lats,
# ----> 6             max_temps,
#       7             edgecolor="black", linewidths=1, marker="o",
#       8             alpha=0.8, label="Cities")
#
# NameError: name 'max_temps' is not defined

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-e2953eb9c712> in <module>
#       1 # Build the scatter plots for latitude vs. humidity.
#       2 plt.scatter(lats,
# ----> 3             humidity,
#       4             edgecolor="black", linewidths=1, marker="o",
#       5             alpha=0.8, label="Cities")
#
# NameError: name 'humidity' is not defined

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-71ad295a9d07> in <module>
#       1 # Build the scatter plots for latitude vs. cloudiness.
#       2 plt.scatter(lats,
# ----> 3             cloudiness,
#       4             edgecolor="black", linewidths=1, marker="o",
#       5             alpha=0.8, label="Cities")
#
# NameError: name 'cloudiness' is not defined

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-c2dc6bdc83cb> in <module>
#       1 # Build the scatter plots for latitude vs. wind speed.
#       2 plt.scatter(lats,
# ----> 3             wind_speed,
#       4             edgecolor="black", linewidths=1, marker="o",
#       5             alpha=0.8, label="Cities")
#
# NameError: name 'wind_speed' is not defined

# %%
#Practice Using Linear Regression

# %%
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create an equal number of latitudes and temperatures.
lats = [42.5, 43.9, 8.1, 36.8, 79.9, 69.1, 25.7, 15.3, 12.7, 64.5]
temps = [80.5, 75.3, 90.9, 90.0, 40.4, 62.3, 85.4, 79.6, 72.5, 72.0]

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(lats, temps)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -0.45x + 92.94
# The p-value is: 0.011

# %%
# Calculate the regression line "y values" from the slope and intercept.
regress_values = [(lat * slope + intercept) for lat in lats]

# %%
# Import Matplotlib.
import matplotlib.pyplot as plt
# Create a scatter plot of the x and y values.
plt.scatter(lats,temps)
# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
plt.plot(lats,regress_values,"r")
# Annotate the text for the line equation and add its coordinates.
plt.annotate(line_eq, (10,40), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Temp')
plt.show()

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

# Calculate the regression line "y values" from the slope and intercept.
regress_values = x_values * slope + intercept

# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create a scatter plot of the x and y values.
plt.scatter(x_values,y_values)
# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
plt.plot(x_values,regress_values,"r")
# Annotate the text for the line equation and add its coordinates.
plt.annotate(line_eq, (10,40), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Temp')
plt.show()

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)]

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-ce21b4553224> in <module>
#       1 # Linear regression on the Southern Hemisphere
# ----> 2 x_values = southern_hemi_df["Lat"]
#       3 y_values = southern_hemi_df["Max Temp"]
#       4 # Call the function.
#       5 plot_linear_regression(x_values, y_values,
#
# NameError: name 'southern_hemi_df' is not defined

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-96278159dc69> in <module>
#       1 # Linear regression on the Northern Hemisphere
# ----> 2 x_values = northern_hemi_df["Lat"]
#       3 y_values = northern_hemi_df["Humidity"]
#       4 # Call the function.
#       5 plot_linear_regression(x_values, y_values,
#
# NameError: name 'northern_hemi_df' is not defined

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n
                        for % Humidity', '% Humidity',(-50,15))
# Out:
#   File "<ipython-input-50-9c3e8b244753>", line 6
#     'Linear Regression on the Southern Hemisphere \n
#                                                     ^
# SyntaxError: EOL while scanning string literal

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n
                        for % Cloudiness', '% Cloudiness',(-50,60))
# Out:
#   File "<ipython-input-51-3dc99b339452>", line 6
#     'Linear Regression on the Southern Hemisphere \n
#                                                     ^
# SyntaxError: EOL while scanning string literal

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n
                        for Wind Speed', 'Wind Speed',(-50,35))

# %%
 ##START dataframe creation here  

# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

#organize the columns in the DataFrame.  ###????
city_data_df = city_data_df[['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
                             'Wind Speed', ]]
city_data_df.head(10)

# Create the output file (CSV).   this is not working   
#output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
#city_data_df.to_csv(output_data_file, index_label="City_ID")

#START PLOTTING CODE 
#1st get data 

# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today

# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()



# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()
 



# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()



# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

#Practice Using Linear Regression

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# Create an equal number of latitudes and temperatures.
lats = [42.5, 43.9, 8.1, 36.8, 79.9, 69.1, 25.7, 15.3, 12.7, 64.5]
temps = [80.5, 75.3, 90.9, 90.0, 40.4, 62.3, 85.4, 79.6, 72.5, 72.0]

# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(lats, temps)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")

# Calculate the regression line "y values" from the slope and intercept.
regress_values = [(lat * slope + intercept) for lat in lats]

# Import Matplotlib.
import matplotlib.pyplot as plt
# Create a scatter plot of the x and y values.
plt.scatter(lats,temps)
# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
plt.plot(lats,regress_values,"r")
# Annotate the text for the line equation and add its coordinates.
plt.annotate(line_eq, (10,40), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Temp')
plt.show()

# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

# Calculate the regression line "y values" from the slope and intercept.
regress_values = x_values * slope + intercept

# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create a scatter plot of the x and y values.
plt.scatter(x_values,y_values)
# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
plt.plot(x_values,regress_values,"r")
# Annotate the text for the line equation and add its coordinates.
plt.annotate(line_eq, (10,40), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Temp')
plt.show()



# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

city_data_df.loc[(city_data_df["Lat"] >= 0)]

city_data_df.loc[(city_data_df["Lat"] >= 0)].head()

# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))



# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))

# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n
                        for % Humidity', '% Humidity',(-50,15))

# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n
                        for % Cloudiness', '% Cloudiness',(-50,60))

# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n
                        for Wind Speed', 'Wind Speed',(40,35))

# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n
                        for Wind Speed', 'Wind Speed',(-50,35))

# %%
#MAYBE EXTRA but keep til sure starting mod 626

#starting mod 626
# Import the datetime module from the datetime library.
from datetime import datetime

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
  
#Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
        # Parse out the needed data.
            city_lat = city_weather["coord"]["lat"]
            city_lng = city_weather["coord"]["lon"]
            city_max_temp = city_weather["main"]["temp_max"]
            city_humidity = city_weather["main"]["humidity"]
            city_clouds = city_weather["clouds"]["all"]
            city_wind = city_weather["wind"]["speed"]
            city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
            city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
            city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
# If an error is experienced, skip the city.
    except:
            print("City not found. Skipping...")
    pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
record_count += 1
