# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
#Challenge part 3  - create a travel itinerary map

# %%
#Challenge part 3
#Start here with Justin

# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps

#Import API key 
from config import g_key

#Configure gmaps
gmaps.configure(api_key=g_key)

#Use the citipy module to determine city based on latitude and longitude.
#%pip install citipy
from citipy import citipy

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head()

cities = vacation_df["City"]
cities
# Out:
# 0       Pozoblanco
# 1            Manta
# 2      Bandarbeyla
# 3          Ternate
# 4        Jamestown
#           ...
# 237       Monrovia
# 238      Martapura
# 239         Lingao
# 240        Abdanan
# 241     Alamogordo
# Name: City, Length: 242, dtype: object

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]
vacation_df.count()
# Out:
# City_ID                242
# City                   242
# Country                242
# Max Temp               242
# Current Description    242
# Lat                    242
# Lng                    242
# Hotel Name             242
# dtype: int64

# %%
# 4a. Add a marker layer for each city to the map.
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
###ASK justin - work on this with him    

# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.
#vacation_start = vacation_df.loc[vacation_df["City"] = cities[0]  

vacation_start = vacation_df.loc[vacation_df['Hotel Name'] == "Lidera", :]
vacation_end = vacation_df.loc[vacation_df['Hotel Name'] == "Lidera", :]
vacation_stop1 = vacation_df.loc[vacation_df['Hotel Name'] == "Casa Amarela", :]
vacation_stop2= vacation_df.loc[vacation_df['Hotel Name'] == "Vivant Residence", :] 
vacation_stop3 = vacation_df.loc[vacation_df['Hotel Name'] == "Sea Lounge! Bar, Club & Restaurant", :]

vacation_start
# Out:
#     City_ID        City Country  Max Temp Current Description    Lat    Lng  \
# 35      111  Carutapera      BR     80.19       broken clouds -1.195 -46.02
#
#    Hotel Name
# 35     Lidera

# %%
itinerary_df = vacation_df.loc[vacation_df["Country"] =="BR"]
itinerary_df.head(20)
# Out:
#      City_ID                       City Country  Max Temp Current Description  \
# 8         19                    Itarema      BR     81.77       broken clouds
# 9         39                     Vicosa      BR     79.18     overcast clouds
# 26        88                     Touros      BR     79.70    scattered clouds
# 35       111                 Carutapera      BR     80.19       broken clouds
# 45       135                    Itirucu      BR     75.97           clear sky
# 51       166          Sao Joao Da Barra      BR     75.29           clear sky
# 58       190                  Marapanim      BR     80.13    scattered clouds
# 78       236                      Natal      BR     79.45       broken clouds
# 106      319                      Conde      BR     76.46           clear sky
# 117      359                    Aquiraz      BR     85.21     overcast clouds
# 118      361                Salinopolis      BR     82.20           clear sky
# 134      394  Santa Isabel Do Rio Negro      BR     84.63     overcast clouds
# 136      401                   Nhamunda      BR     88.25     overcast clouds
# 152      446                Santa Luzia      BR     81.50          few clouds
# 171      498                     Maceio      BR     80.04    scattered clouds
# 177      519                   Maragogi      BR     76.46           clear sky
# 198      571                   Cururupu      BR     81.45       broken clouds
# 202      582         Humberto De Campos      BR     82.26          few clouds
# 227      644                    Caucaia      BR     85.06          few clouds
#
#          Lat      Lng                                Hotel Name
# 8    -2.9248 -39.9167        Sea Lounge! Bar, Club & Restaurant
# 9   -20.7539 -42.8819                          Vivant Residence
# 26   -5.1989 -35.4608                           INN NEW HORIZON
# 35   -1.1950 -46.0200                                    Lidera
# 45  -13.5317 -40.1503                              Casa Amarela
# 51  -21.6403 -41.0511                   Pousada Porto De Canoas
# 58   -0.7175 -47.6997                         Ecomangue Pousada
# 78   -5.7950 -35.2094                  Villa Park Hotel | Natal
# 106  -7.2597 -34.9075                        Pousada Beija Flor
# 117  -3.9014 -38.3911                     Pousada Rua Camurupim
# 118  -0.6136 -47.3561        Salinas Park Resort Maçarico AP101
# 134  -0.4139 -65.0192                                 Hotel GSA
# 136  -2.1861 -56.7131                          Pousada Da Praia
# 152 -19.7697 -43.8514                        Pousada Chao Earth
# 171  -9.6658 -35.7353                            Poutur Pousada
# 177  -9.0122 -35.2225  Salinas do Maragogi All Inclusive Resort
# 198  -1.8283 -44.8683                        POUSADA TRAVÉS'CIA
# 202  -2.5983 -43.4611                         Pousada do Cabeça
# 227  -3.7361 -38.6531       M.O.S. Logística - Filial Fortaleza

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
 

start = vacation_start['Lat'].to_numpy()[0] , vacation_start['Lng'].to_numpy()[0]
end = vacation_end['Lat'].to_numpy()[0] , vacation_end['Lng'].to_numpy()[0]
stop1 = vacation_stop1['Lat'].to_numpy()[0] , vacation_stop1['Lng'].to_numpy()[0]
stop2 = vacation_stop2['Lat'].to_numpy()[0] , vacation_stop2['Lng'].to_numpy()[0]
stop3 = vacation_stop3['Lat'].to_numpy()[0] , vacation_stop3['Lng'].to_numpy()[0]

stop3
# Out:
# (-20.7539, -42.8819)

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

#Latitude-longitude pairs:
import gmaps
import gmaps.datasets

fig = gmaps.figure()
start2end_via_stops = gmaps.directions_layer(
        start, end, waypoints=[stop1, stop2, stop3],
        travel_mode='DRIVING')
fig.add_layer(start2end_via_stops)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1, vacation_stop2, vacation_stop3, vacation_end],ignore_index=True)
itinerary_df
# Out:
#    City_ID        City Country  Max Temp Current Description      Lat  \
# 0      111  Carutapera      BR     80.19       broken clouds  -1.1950
# 1      135     Itirucu      BR     75.97           clear sky -13.5317
# 2       19     Itarema      BR     81.77       broken clouds  -2.9248
# 3       39      Vicosa      BR     79.18     overcast clouds -20.7539
# 4      111  Carutapera      BR     80.19       broken clouds  -1.1950
#
#        Lng                          Hotel Name
# 0 -46.0200                              Lidera
# 1 -40.1503                        Casa Amarela
# 2 -39.9167  Sea Lounge! Bar, Club & Restaurant
# 3 -42.8819                    Vivant Residence
# 4 -46.0200                              Lidera

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
max_temp = itinerary_df["Max Temp"]
center = (-14.2350, -51.9253)
#center = (30.0, 31.0)
fig = gmaps.figure(center=center, zoom_level=4)
#heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
#             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
#fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
