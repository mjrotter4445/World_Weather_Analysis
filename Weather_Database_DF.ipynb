# %%
#Challenge part 1 pull the l and l info make a place for cities, count em, 
#Start here with Justin

# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#Use the citipy module to determine city based on latitude and longitude.
# %pip install citipy
from citipy import citipy
# Out:
# Requirement already satisfied: citipy in c:\users\mjrot\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\mjrot\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
 # Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 634

# %%
#starting mod 626
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
#Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
  
#Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
            city_weather = requests.get(city_url).json()
        # Parse out the needed data.
            city_lat = city_weather["coord"]["lat"]
            city_lng = city_weather["coord"]["lon"]
            city_max_temp = city_weather["main"]["temp_max"]
            city_humidity = city_weather["main"]["humidity"]
            city_clouds = city_weather["clouds"]["all"]
            city_wind = city_weather["wind"]["speed"]
            city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
            city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
            city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
# If an error is experienced, skip the city.
    except:
            print("City not found. Skipping...")
    pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
record_count += 1
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | aksu
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | upernavik
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | naze
# Processing Record 8 of Set 1 | lavrentiya
# Processing Record 9 of Set 1 | coihaique
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | ordzhonikidze
# Processing Record 12 of Set 1 | acari
# Processing Record 13 of Set 1 | thompson
# Processing Record 14 of Set 1 | tutoia
# Processing Record 15 of Set 1 | lac du bonnet
# Processing Record 16 of Set 1 | chokurdakh
# Processing Record 17 of Set 1 | kitimat
# Processing Record 18 of Set 1 | male
# Processing Record 19 of Set 1 | iquique
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | camacha
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | paidha
# Processing Record 24 of Set 1 | barrow
# Processing Record 25 of Set 1 | cherskiy
# Processing Record 26 of Set 1 | mount gambier
# Processing Record 27 of Set 1 | half moon bay
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 1 | nikolskoye
# Processing Record 32 of Set 1 | tuktoyaktuk
# Processing Record 33 of Set 1 | san felipe
# Processing Record 34 of Set 1 | okhotsk
# Processing Record 35 of Set 1 | george town
# Processing Record 36 of Set 1 | villazon
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | bengkulu
# Processing Record 39 of Set 1 | mehamn
# Processing Record 40 of Set 1 | aykhal
# Processing Record 41 of Set 1 | salym
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | hilo
# Processing Record 44 of Set 1 | katsuura
# Processing Record 45 of Set 1 | qaanaaq
# Processing Record 46 of Set 1 | yellowknife
# Processing Record 47 of Set 1 | chernyshevskiy
# Processing Record 48 of Set 1 | vaini
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | ushuaia
# Processing Record 1 of Set 2 | kibre mengist
# Processing Record 2 of Set 2 | atar
# Processing Record 3 of Set 2 | airai
# Processing Record 4 of Set 2 | hobart
# Processing Record 5 of Set 2 | sola
# Processing Record 6 of Set 2 | nanortalik
# Processing Record 7 of Set 2 | gigmoto
# Processing Record 8 of Set 2 | san quintin
# Processing Record 9 of Set 2 | ciudad bolivar
# Processing Record 10 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 2 | bambous virieux
# Processing Record 12 of Set 2 | yumen
# Processing Record 13 of Set 2 | kodiak
# Processing Record 14 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 2 | ballina
# Processing Record 16 of Set 2 | moelv
# Processing Record 17 of Set 2 | port alfred
# Processing Record 18 of Set 2 | saskylakh
# Processing Record 19 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 2 | beringovskiy
# Processing Record 21 of Set 2 | zhigansk
# Processing Record 22 of Set 2 | le marin
# Processing Record 23 of Set 2 | norman wells
# Processing Record 24 of Set 2 | perehonivka
# Processing Record 25 of Set 2 | kalanguy
# Processing Record 26 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 2 | ilulissat
# Processing Record 28 of Set 2 | pevek
# Processing Record 29 of Set 2 | dubrovnik
# Processing Record 30 of Set 2 | kamenka
# Processing Record 31 of Set 2 | dingle
# Processing Record 32 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 2 | sao joao da barra
# Processing Record 34 of Set 2 | nhulunbuy
# Processing Record 35 of Set 2 | dingtao
# Processing Record 36 of Set 2 | hithadhoo
# Processing Record 37 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 2 | provideniya
# Processing Record 39 of Set 2 | qafsah
# City not found. Skipping...
# Processing Record 40 of Set 2 | gurskoye
# City not found. Skipping...
# Processing Record 41 of Set 2 | port lincoln
# Processing Record 42 of Set 2 | kaitangata
# Processing Record 43 of Set 2 | pocatello
# Processing Record 44 of Set 2 | egvekinot
# Processing Record 45 of Set 2 | challapata
# Processing Record 46 of Set 2 | iwaki
# Processing Record 47 of Set 2 | kurchum
# Processing Record 48 of Set 2 | new norfolk
# Processing Record 49 of Set 2 | toamasina
# Processing Record 50 of Set 2 | laguna
# Processing Record 1 of Set 3 | lompoc
# Processing Record 2 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 3 of Set 3 | pacifica
# Processing Record 4 of Set 3 | luanda
# Processing Record 5 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 3 | honningsvag
# Processing Record 7 of Set 3 | saint-philippe
# Processing Record 8 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 9 of Set 3 | saint-augustin
# Processing Record 10 of Set 3 | santiago
# Processing Record 11 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 3 | vila
# Processing Record 13 of Set 3 | muros
# Processing Record 14 of Set 3 | rikitea
# Processing Record 15 of Set 3 | chuy
# Processing Record 16 of Set 3 | bintulu
# Processing Record 17 of Set 3 | victoria
# Processing Record 18 of Set 3 | atuona
# Processing Record 19 of Set 3 | gboko
# Processing Record 20 of Set 3 | henties bay
# Processing Record 21 of Set 3 | broome
# Processing Record 22 of Set 3 | taltal
# Processing Record 23 of Set 3 | vao
# Processing Record 24 of Set 3 | mar del plata
# Processing Record 25 of Set 3 | maragogi
# Processing Record 26 of Set 3 | avarua
# Processing Record 27 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 3 | alice springs
# Processing Record 29 of Set 3 | pilibanga
# Processing Record 30 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 3 | middelkerke
# Processing Record 32 of Set 3 | lesnoy
# Processing Record 33 of Set 3 | kirakira
# Processing Record 34 of Set 3 | margate
# Processing Record 35 of Set 3 | vila franca do campo
# Processing Record 36 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 3 | sofiysk
# City not found. Skipping...
# Processing Record 38 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 39 of Set 3 | mahebourg
# Processing Record 40 of Set 3 | touros
# Processing Record 41 of Set 3 | albany
# Processing Record 42 of Set 3 | sechura
# Processing Record 43 of Set 3 | vardo
# Processing Record 44 of Set 3 | dobryanka
# Processing Record 45 of Set 3 | lebu
# Processing Record 46 of Set 3 | fortuna
# Processing Record 47 of Set 3 | faya
# Processing Record 48 of Set 3 | arraial do cabo
# Processing Record 49 of Set 3 | georgetown
# Processing Record 50 of Set 3 | bonavista
# Processing Record 1 of Set 4 | ribeira grande
# Processing Record 2 of Set 4 | poum
# Processing Record 3 of Set 4 | shenjiamen
# Processing Record 4 of Set 4 | longyearbyen
# Processing Record 5 of Set 4 | flin flon
# Processing Record 6 of Set 4 | saint george
# Processing Record 7 of Set 4 | berlevag
# Processing Record 8 of Set 4 | sitka
# Processing Record 9 of Set 4 | castro
# Processing Record 10 of Set 4 | yulara
# Processing Record 11 of Set 4 | gidole
# Processing Record 12 of Set 4 | santa rosa
# Processing Record 13 of Set 4 | dubbo
# Processing Record 14 of Set 4 | alyangula
# Processing Record 15 of Set 4 | saldanha
# Processing Record 16 of Set 4 | san patricio
# Processing Record 17 of Set 4 | lagoa
# Processing Record 18 of Set 4 | along
# Processing Record 19 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 20 of Set 4 | magole
# Processing Record 21 of Set 4 | guerrero negro
# Processing Record 22 of Set 4 | linda
# Processing Record 23 of Set 4 | iqaluit
# Processing Record 24 of Set 4 | tasiilaq
# Processing Record 25 of Set 4 | ponta do sol
# Processing Record 26 of Set 4 | san ramon
# Processing Record 27 of Set 4 | aden
# Processing Record 28 of Set 4 | narsaq
# Processing Record 29 of Set 4 | kadykchan
# City not found. Skipping...
# Processing Record 30 of Set 4 | huanren
# Processing Record 31 of Set 4 | qaqortoq
# Processing Record 32 of Set 4 | gayny
# Processing Record 33 of Set 4 | souillac
# Processing Record 34 of Set 4 | tobol
# Processing Record 35 of Set 4 | puerto escondido
# Processing Record 36 of Set 4 | bubaque
# Processing Record 37 of Set 4 | faanui
# Processing Record 38 of Set 4 | locri
# Processing Record 39 of Set 4 | kadhan
# Processing Record 40 of Set 4 | garissa
# Processing Record 41 of Set 4 | bethel
# Processing Record 42 of Set 4 | parabel
# Processing Record 43 of Set 4 | tiksi
# Processing Record 44 of Set 4 | inyonga
# Processing Record 45 of Set 4 | sierra vista
# Processing Record 46 of Set 4 | oranjemund
# Processing Record 47 of Set 4 | kavieng
# Processing Record 48 of Set 4 | huarmey
# Processing Record 49 of Set 4 | flinders
# Processing Record 50 of Set 4 | sao filipe
# Processing Record 1 of Set 5 | trapani
# Processing Record 2 of Set 5 | martil
# Processing Record 3 of Set 5 | tautira
# Processing Record 4 of Set 5 | macau
# Processing Record 5 of Set 5 | fairbanks
# Processing Record 6 of Set 5 | leirvik
# Processing Record 7 of Set 5 | itoman
# Processing Record 8 of Set 5 | baykit
# Processing Record 9 of Set 5 | karamea
# City not found. Skipping...
# Processing Record 10 of Set 5 | kupang
# Processing Record 11 of Set 5 | ayan
# Processing Record 12 of Set 5 | san buenaventura
# Processing Record 13 of Set 5 | kaniama
# Processing Record 14 of Set 5 | omachi
# Processing Record 15 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 16 of Set 5 | collie
# Processing Record 17 of Set 5 | glubokoe
# City not found. Skipping...
# Processing Record 18 of Set 5 | astana
# Processing Record 19 of Set 5 | owensboro
# Processing Record 20 of Set 5 | evensk
# Processing Record 21 of Set 5 | talnakh
# Processing Record 22 of Set 5 | wuwei
# Processing Record 23 of Set 5 | nicoya
# Processing Record 24 of Set 5 | acapulco
# Processing Record 25 of Set 5 | nebug
# Processing Record 26 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 5 | klaksvik
# Processing Record 28 of Set 5 | auki
# Processing Record 29 of Set 5 | raga
# Processing Record 30 of Set 5 | astoria
# Processing Record 31 of Set 5 | shieli
# Processing Record 32 of Set 5 | porbandar
# Processing Record 33 of Set 5 | kenai
# Processing Record 34 of Set 5 | burns lake
# Processing Record 35 of Set 5 | ponta delgada
# Processing Record 36 of Set 5 | sterling
# Processing Record 37 of Set 5 | aklavik
# Processing Record 38 of Set 5 | rawson
# Processing Record 39 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 5 | coos bay
# Processing Record 41 of Set 5 | clyde river
# Processing Record 42 of Set 5 | kjopsvik
# Processing Record 43 of Set 5 | orzu
# Processing Record 44 of Set 5 | denpasar
# Processing Record 45 of Set 5 | basco
# Processing Record 46 of Set 5 | port-cartier
# Processing Record 47 of Set 5 | carnarvon
# Processing Record 48 of Set 5 | sandwick
# Processing Record 49 of Set 5 | palaikastron
# Processing Record 50 of Set 5 | dunedin
# Processing Record 1 of Set 6 | severo-kurilsk
# Processing Record 2 of Set 6 | tianpeng
# Processing Record 3 of Set 6 | san cristobal
# Processing Record 4 of Set 6 | port elizabeth
# Processing Record 5 of Set 6 | hofn
# Processing Record 6 of Set 6 | cidreira
# Processing Record 7 of Set 6 | tera
# Processing Record 8 of Set 6 | clyde
# Processing Record 9 of Set 6 | panaba
# Processing Record 10 of Set 6 | portland
# Processing Record 11 of Set 6 | pafos
# Processing Record 12 of Set 6 | wildberg
# Processing Record 13 of Set 6 | caxito
# Processing Record 14 of Set 6 | inhambane
# Processing Record 15 of Set 6 | ugep
# Processing Record 16 of Set 6 | tazovskiy
# Processing Record 17 of Set 6 | wanning
# Processing Record 18 of Set 6 | neiafu
# Processing Record 19 of Set 6 | kapoeta
# Processing Record 20 of Set 6 | daru
# Processing Record 21 of Set 6 | tecoanapa
# Processing Record 22 of Set 6 | beaufort
# Processing Record 23 of Set 6 | fare
# Processing Record 24 of Set 6 | miri
# Processing Record 25 of Set 6 | pemba
# Processing Record 26 of Set 6 | tshikapa
# Processing Record 27 of Set 6 | abu dhabi
# Processing Record 28 of Set 6 | mitsamiouli
# Processing Record 29 of Set 6 | sisophon
# Processing Record 30 of Set 6 | namibe
# Processing Record 31 of Set 6 | shimoda
# Processing Record 32 of Set 6 | westport
# Processing Record 33 of Set 6 | santa isabel
# Processing Record 34 of Set 6 | seymchan
# Processing Record 35 of Set 6 | ano mera
# Processing Record 36 of Set 6 | mezen
# Processing Record 37 of Set 6 | muyezerskiy
# Processing Record 38 of Set 6 | sept-iles
# Processing Record 39 of Set 6 | hamilton
# Processing Record 40 of Set 6 | bathurst
# Processing Record 41 of Set 6 | christchurch
# Processing Record 42 of Set 6 | east london
# Processing Record 43 of Set 6 | tome-acu
# City not found. Skipping...
# Processing Record 44 of Set 6 | cabatuan
# Processing Record 45 of Set 6 | shihezi
# Processing Record 46 of Set 6 | homer
# Processing Record 47 of Set 6 | azul
# Processing Record 48 of Set 6 | mandalgovi
# Processing Record 49 of Set 6 | aguimes
# Processing Record 50 of Set 6 | bambanglipuro
# Processing Record 1 of Set 7 | sur
# Processing Record 2 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 3 of Set 7 | kabo
# Processing Record 4 of Set 7 | griffith
# Processing Record 5 of Set 7 | saryg-sep
# Processing Record 6 of Set 7 | ostrovnoy
# Processing Record 7 of Set 7 | avesta
# Processing Record 8 of Set 7 | buarcos
# Processing Record 9 of Set 7 | mendahara
# City not found. Skipping...
# Processing Record 10 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 7 | poros
# Processing Record 12 of Set 7 | haines junction
# Processing Record 13 of Set 7 | magadan
# Processing Record 14 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 7 | mitu
# Processing Record 16 of Set 7 | ambilobe
# Processing Record 17 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 7 | port hawkesbury
# Processing Record 19 of Set 7 | port blair
# Processing Record 20 of Set 7 | sibolga
# Processing Record 21 of Set 7 | tabas
# Processing Record 22 of Set 7 | bathsheba
# Processing Record 23 of Set 7 | cabo san lucas
# Processing Record 24 of Set 7 | padang
# Processing Record 25 of Set 7 | neustadt
# Processing Record 26 of Set 7 | phalaborwa
# Processing Record 27 of Set 7 | kruisfontein
# Processing Record 28 of Set 7 | canon city
# Processing Record 29 of Set 7 | eldorado
# Processing Record 30 of Set 7 | hualmay
# Processing Record 31 of Set 7 | isangel
# Processing Record 32 of Set 7 | tuatapere
# Processing Record 33 of Set 7 | palana
# Processing Record 34 of Set 7 | vostok
# Processing Record 35 of Set 7 | pisco
# Processing Record 36 of Set 7 | nurota
# Processing Record 37 of Set 7 | chapais
# Processing Record 38 of Set 7 | ovalle
# Processing Record 39 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 40 of Set 7 | luderitz
# Processing Record 41 of Set 7 | novoagansk
# Processing Record 42 of Set 7 | dubreka
# Processing Record 43 of Set 7 | yushala
# Processing Record 44 of Set 7 | mehran
# Processing Record 45 of Set 7 | port hardy
# Processing Record 46 of Set 7 | north bend
# Processing Record 47 of Set 7 | rocha
# Processing Record 48 of Set 7 | kilindoni
# Processing Record 49 of Set 7 | emilio carranza
# Processing Record 50 of Set 7 | lalmohan
# Processing Record 1 of Set 8 | joao pinheiro
# Processing Record 2 of Set 8 | bitung
# Processing Record 3 of Set 8 | mohan
# Processing Record 4 of Set 8 | felidhoo
# City not found. Skipping...
# Processing Record 5 of Set 8 | codrington
# Processing Record 6 of Set 8 | aripuana
# Processing Record 7 of Set 8 | port moresby
# Processing Record 8 of Set 8 | turukhansk
# Processing Record 9 of Set 8 | ternate
# Processing Record 10 of Set 8 | bani
# Processing Record 11 of Set 8 | le port
# Processing Record 12 of Set 8 | sindgi
# Processing Record 13 of Set 8 | naryan-mar
# Processing Record 14 of Set 8 | kaman
# Processing Record 15 of Set 8 | behshahr
# Processing Record 16 of Set 8 | mwinilunga
# Processing Record 17 of Set 8 | coquimbo
# Processing Record 18 of Set 8 | nantucket
# Processing Record 19 of Set 8 | te anau
# Processing Record 20 of Set 8 | puerto madryn
# Processing Record 21 of Set 8 | pangody
# Processing Record 22 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 23 of Set 8 | gimbi
# Processing Record 24 of Set 8 | ola
# Processing Record 25 of Set 8 | danielskuil
# Processing Record 26 of Set 8 | mana
# Processing Record 27 of Set 8 | grindavik
# Processing Record 28 of Set 8 | constitucion
# Processing Record 29 of Set 8 | zadar
# Processing Record 30 of Set 8 | matara
# Processing Record 31 of Set 8 | esperance
# Processing Record 32 of Set 8 | innisfail
# Processing Record 33 of Set 8 | adrar
# Processing Record 34 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 35 of Set 8 | tabora
# Processing Record 36 of Set 8 | taywarah
# Processing Record 37 of Set 8 | krasnogorsk
# Processing Record 38 of Set 8 | pakokku
# Processing Record 39 of Set 8 | kodinsk
# Processing Record 40 of Set 8 | ardakan
# Processing Record 41 of Set 8 | marzuq
# Processing Record 42 of Set 8 | rio cuarto
# Processing Record 43 of Set 8 | lasa
# Processing Record 44 of Set 8 | davila
# Processing Record 45 of Set 8 | segezha
# Processing Record 46 of Set 8 | khani
# Processing Record 47 of Set 8 | vila velha
# Processing Record 48 of Set 8 | necochea
# Processing Record 49 of Set 8 | kamaishi
# Processing Record 50 of Set 8 | nome
# Processing Record 1 of Set 9 | cookeville
# Processing Record 2 of Set 9 | brae
# Processing Record 3 of Set 9 | kangaatsiaq
# Processing Record 4 of Set 9 | klyuchi
# Processing Record 5 of Set 9 | bandarbeyla
# Processing Record 6 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 7 of Set 9 | geghamasar
# Processing Record 8 of Set 9 | ust-ilimsk
# Processing Record 9 of Set 9 | buchanan
# Processing Record 10 of Set 9 | erenhot
# Processing Record 11 of Set 9 | dikson
# Processing Record 12 of Set 9 | mackay
# Processing Record 13 of Set 9 | manggar
# Processing Record 14 of Set 9 | wad madani
# Processing Record 15 of Set 9 | cayenne
# Processing Record 16 of Set 9 | vanimo
# Processing Record 17 of Set 9 | muzhi
# Processing Record 18 of Set 9 | gwadar
# Processing Record 19 of Set 9 | camana
# Processing Record 20 of Set 9 | caravelas
# Processing Record 21 of Set 9 | malanje
# Processing Record 22 of Set 9 | mentok
# City not found. Skipping...
# Processing Record 23 of Set 9 | wabag
# Processing Record 24 of Set 9 | hobyo
# Processing Record 25 of Set 9 | yarkovo
# Processing Record 26 of Set 9 | san ciro de acosta
# Processing Record 27 of Set 9 | nyurba
# Processing Record 28 of Set 9 | gornopravdinsk
# Processing Record 29 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 9 | bijeljina
# Processing Record 31 of Set 9 | whyalla
# Processing Record 32 of Set 9 | nongan
# Processing Record 33 of Set 9 | unity
# Processing Record 34 of Set 9 | boende
# Processing Record 35 of Set 9 | yendi
# Processing Record 36 of Set 9 | carbonia
# Processing Record 37 of Set 9 | gravdal
# Processing Record 38 of Set 9 | qui nhon
# Processing Record 39 of Set 9 | badiraguato
# Processing Record 40 of Set 9 | sinegorye
# Processing Record 41 of Set 9 | mareeba
# Processing Record 42 of Set 9 | mahuva
# Processing Record 43 of Set 9 | carinhanha
# Processing Record 44 of Set 9 | kyabe
# Processing Record 45 of Set 9 | plettenberg bay
# Processing Record 46 of Set 9 | imeni poliny osipenko
# Processing Record 47 of Set 9 | goure
# Processing Record 48 of Set 9 | pahrump
# Processing Record 49 of Set 9 | torbay
# Processing Record 50 of Set 9 | coleraine
# Processing Record 1 of Set 10 | brza palanka
# Processing Record 2 of Set 10 | camopi
# Processing Record 3 of Set 10 | malartic
# Processing Record 4 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 5 of Set 10 | te horo
# Processing Record 6 of Set 10 | hagere hiywet
# Processing Record 7 of Set 10 | wajir
# Processing Record 8 of Set 10 | maine-soroa
# Processing Record 9 of Set 10 | bali
# Processing Record 10 of Set 10 | hasaki
# Processing Record 11 of Set 10 | pemangkat
# Processing Record 12 of Set 10 | havre-saint-pierre
# Processing Record 13 of Set 10 | luena
# Processing Record 14 of Set 10 | sinnamary
# Processing Record 15 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 16 of Set 10 | cubuk
# Processing Record 17 of Set 10 | williston
# Processing Record 18 of Set 10 | karamay
# City not found. Skipping...
# Processing Record 19 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 10 | martapura
# Processing Record 21 of Set 10 | andenes
# Processing Record 22 of Set 10 | vestmannaeyjar
# Processing Record 23 of Set 10 | adwa
# Processing Record 24 of Set 10 | cairns
# Processing Record 25 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 26 of Set 10 | gopalganj
# Processing Record 27 of Set 10 | los llanos de aridane
# Processing Record 28 of Set 10 | fandriana
# Processing Record 29 of Set 10 | saiha
# Processing Record 30 of Set 10 | makakilo city
# Processing Record 31 of Set 10 | namie
# Processing Record 32 of Set 10 | inndyr
# Processing Record 33 of Set 10 | kristiansund
# Processing Record 34 of Set 10 | altay
# Processing Record 35 of Set 10 | merrill
# Processing Record 36 of Set 10 | santa vitoria do palmar
# Processing Record 37 of Set 10 | tocopilla
# Processing Record 38 of Set 10 | ulladulla
# Processing Record 39 of Set 10 | rio gallegos
# Processing Record 40 of Set 10 | rezh
# Processing Record 41 of Set 10 | benghazi
# Processing Record 42 of Set 10 | avanigadda
# Processing Record 43 of Set 10 | port macquarie
# Processing Record 44 of Set 10 | pandan
# Processing Record 45 of Set 10 | tomohon
# Processing Record 46 of Set 10 | maracacume
# Processing Record 47 of Set 10 | tokur
# Processing Record 48 of Set 10 | strezhevoy
# Processing Record 49 of Set 10 | ancud
# Processing Record 50 of Set 10 | odweyne
# Processing Record 1 of Set 11 | revda
# Processing Record 2 of Set 11 | celendin
# Processing Record 3 of Set 11 | khatanga
# Processing Record 4 of Set 11 | tilichiki
# Processing Record 5 of Set 11 | krasnyy chikoy
# Processing Record 6 of Set 11 | port hedland
# Processing Record 7 of Set 11 | labuan
# Processing Record 8 of Set 11 | ugoofaaru
# Processing Record 9 of Set 11 | la romana
# Processing Record 10 of Set 11 | kalmunai
# Processing Record 11 of Set 11 | teguldet
# Processing Record 12 of Set 11 | stromness
# Processing Record 13 of Set 11 | ghogha
# Processing Record 14 of Set 11 | hakvik
# City not found. Skipping...
# Processing Record 15 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 16 of Set 11 | lannion
# Processing Record 17 of Set 11 | luebo
# Processing Record 18 of Set 11 | port augusta
# Processing Record 19 of Set 11 | harrisonville
# Processing Record 20 of Set 11 | newport
# Processing Record 21 of Set 11 | batemans bay
# Processing Record 22 of Set 11 | sarangani
# Processing Record 23 of Set 11 | bilibino
# Processing Record 24 of Set 11 | college
# Processing Record 25 of Set 11 | sabang
# Processing Record 26 of Set 11 | elko
# Processing Record 27 of Set 11 | portsmouth
# Processing Record 28 of Set 11 | shiyan
# Processing Record 29 of Set 11 | ahipara
# Processing Record 30 of Set 11 | geraldton
# Processing Record 31 of Set 11 | haapiti
# Processing Record 32 of Set 11 | karaton
# Processing Record 33 of Set 11 | huatulco
# Processing Record 34 of Set 11 | paamiut
# Processing Record 35 of Set 11 | riyadh
# Processing Record 36 of Set 11 | ialibu
# Processing Record 37 of Set 11 | pangnirtung
# Processing Record 38 of Set 11 | natal
# Processing Record 39 of Set 11 | port pirie
# Processing Record 40 of Set 11 | radyvyliv
# Processing Record 41 of Set 11 | varnavino
# Processing Record 42 of Set 11 | topolobampo
# Processing Record 43 of Set 11 | lorengau
# Processing Record 44 of Set 11 | mackenzie
# Processing Record 45 of Set 11 | kirkwall
# Processing Record 46 of Set 11 | sol-iletsk
# Processing Record 47 of Set 11 | lebanon
# Processing Record 48 of Set 11 | salalah
# Processing Record 49 of Set 11 | suntar
# Processing Record 50 of Set 11 | kitangari
# Processing Record 1 of Set 12 | dickinson
# Processing Record 2 of Set 12 | komsomolskiy
# Processing Record 3 of Set 12 | ryabovo
# Processing Record 4 of Set 12 | burnie
# Processing Record 5 of Set 12 | dubrovka
# Processing Record 6 of Set 12 | mishelevka
# Processing Record 7 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 8 of Set 12 | ketchikan
# Processing Record 9 of Set 12 | dolores
# Processing Record 10 of Set 12 | usinsk
# Processing Record 11 of Set 12 | montes altos
# Processing Record 12 of Set 12 | lipin bor
# Processing Record 13 of Set 12 | tigil
# Processing Record 14 of Set 12 | bosaso
# Processing Record 15 of Set 12 | tatawin
# Processing Record 16 of Set 12 | cao bang
# Processing Record 17 of Set 12 | solnechnyy
# Processing Record 18 of Set 12 | korla
# Processing Record 19 of Set 12 | broken hill
# Processing Record 20 of Set 12 | lazo
# Processing Record 21 of Set 12 | west wendover
# Processing Record 22 of Set 12 | road town
# Processing Record 23 of Set 12 | kindu
# Processing Record 24 of Set 12 | jinchang
# Processing Record 25 of Set 12 | udachnyy
# Processing Record 26 of Set 12 | ericeira
# Processing Record 27 of Set 12 | lukovetskiy
# Processing Record 28 of Set 12 | torre-pacheco
# Processing Record 29 of Set 12 | kutum
# Processing Record 30 of Set 12 | soe
# Processing Record 31 of Set 12 | marienburg
# Processing Record 32 of Set 12 | hirara
# Processing Record 33 of Set 12 | maniitsoq
# Processing Record 34 of Set 12 | erzin
# Processing Record 35 of Set 12 | les cayes
# Processing Record 36 of Set 12 | gold coast
# Processing Record 37 of Set 12 | doka
# Processing Record 38 of Set 12 | taoudenni
# Processing Record 39 of Set 12 | ajdabiya
# Processing Record 40 of Set 12 | salme
# Processing Record 41 of Set 12 | douglas
# Processing Record 42 of Set 12 | mabaruma
# Processing Record 43 of Set 12 | fort nelson
# Processing Record 44 of Set 12 | olafsvik
# Processing Record 45 of Set 12 | srinivaspur
# Processing Record 46 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 47 of Set 12 | igarka
# Processing Record 48 of Set 12 | kemi
# Processing Record 49 of Set 12 | tokzar
# City not found. Skipping...
# Processing Record 50 of Set 12 | tabuk
# Processing Record 1 of Set 13 | comodoro rivadavia
# Processing Record 2 of Set 13 | moussoro
# Processing Record 3 of Set 13 | sydney
# Processing Record 4 of Set 13 | nishihara
# Processing Record 5 of Set 13 | birjand
# Processing Record 6 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 13 | illapel
# Processing Record 8 of Set 13 | champerico
# Processing Record 9 of Set 13 | kermanshah
# Processing Record 10 of Set 13 | sao lourenco do oeste
# Processing Record 11 of Set 13 | mayo
# Processing Record 12 of Set 13 | volax
# Processing Record 13 of Set 13 | tavai
# City not found. Skipping...
# Processing Record 14 of Set 13 | konya
# Processing Record 15 of Set 13 | lake city
# Processing Record 16 of Set 13 | pacific grove
# Processing Record 17 of Set 13 | forio
# Processing Record 18 of Set 13 | indramayu
# Processing Record 19 of Set 13 | srednekolymsk
# Processing Record 20 of Set 13 | roanoke rapids
# Processing Record 21 of Set 13 | blagoveshchenka
# Processing Record 22 of Set 13 | camacupa
# Processing Record 23 of Set 13 | yaan
# Processing Record 24 of Set 13 | sioux lookout
# Processing Record 25 of Set 13 | bilma
# Processing Record 26 of Set 13 | shu
# Processing Record 27 of Set 13 | santa isabel do rio negro
# Processing Record 28 of Set 13 | sangar
# Processing Record 29 of Set 13 | nakasongola
# Processing Record 30 of Set 13 | emerald
# Processing Record 31 of Set 13 | amapa
# Processing Record 32 of Set 13 | deputatskiy
# Processing Record 33 of Set 13 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 34 of Set 13 | kulhudhuffushi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Get the number of the cities
len(city_data)
# Out:
# 583

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Aksu  41.1231   80.2644     76.75        33          89
# 1     Cape Town -33.9258   18.4232     51.12        62          40
# 2    Bredasdorp -34.5322   20.0403     47.52        76          88
# 3     Upernavik  72.7868  -56.1549     42.13        67           4
# 4  Punta Arenas -53.1500  -70.9167     37.42        86          75
# 5      Hermanus -34.4187   19.2345     47.89        68          93
# 6          Naze  28.3667  129.4833     77.67        86          99
# 7    Lavrentiya  65.5833 -171.0000     45.59        90          76
# 8     Coihaique -45.5752  -72.0662     48.15        49          75
# 9       Mataura -46.1927  168.8643     39.78        97         100
#
#    Wind Speed Country                 Date
# 0        1.95      CN  2021-07-12 18:29:38
# 1        8.05      ZA  2021-07-12 18:27:15
# 2       16.11      ZA  2021-07-12 18:29:38
# 3        9.82      GL  2021-07-12 18:29:39
# 4       32.21      CL  2021-07-12 18:29:40
# 5       26.62      ZA  2021-07-12 18:29:40
# 6        5.32      JP  2021-07-12 18:29:41
# 7        6.53      RU  2021-07-12 18:29:41
# 8        4.61      CL  2021-07-12 18:29:41
# 9        1.95      NZ  2021-07-12 18:29:42

# %%
#have a sytax error here  to fix still  
#Organize the columns in the DataFrame.
city_data__no_date_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed','Current Description']]
city_data__no_date_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-eb8751eaa8ce> in <module>
#       1 #have a sytax error here  to fix still
#       2 #Organize the columns in the DataFrame.
# ----> 3 city_data__no_date_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed','Current Description']]
#       4 city_data__no_date_df.head(10)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1314             if raise_missing:
#    1315                 not_found = list(set(key) - set(ax))
# -> 1316                 raise KeyError(f"{not_found} not in index")
#    1317
#    1318             not_found = key[missing_mask]
#
# KeyError: "['Current Description'] not in index"

# %%
#make this active after sure I know where it's going and its' right 
# Create and export the final Data Frame into a CSV
##city_data__no_date_df.to_csv("WeatherPy_Database.csv", index_label="City_ID")
