# %%
#Challenge part 1 pull the l and l info make a place for cities, count em, 
#Start here with Justin

# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#Use the citipy module to determine city based on latitude and longitude.
# %pip install citipy
from citipy import citipy
# Out:
# Requirement already satisfied: citipy in c:\users\mjrot\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\mjrot\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
 # Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 604

# %%
#starting mod 626
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
#Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list using enumerate function.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]['description']
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hasaki
# Processing Record 2 of Set 1 | samarai
# Processing Record 3 of Set 1 | price
# Processing Record 4 of Set 1 | hervey bay
# Processing Record 5 of Set 1 | faanui
# Processing Record 6 of Set 1 | chakia
# Processing Record 7 of Set 1 | balabac
# Processing Record 8 of Set 1 | new norfolk
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | la ronge
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | severo-kurilsk
# Processing Record 13 of Set 1 | padang
# Processing Record 14 of Set 1 | rognan
# Processing Record 15 of Set 1 | luanda
# Processing Record 16 of Set 1 | sao jose da coroa grande
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 1 | yerbogachen
# Processing Record 20 of Set 1 | saint-philippe
# Processing Record 21 of Set 1 | san patricio
# Processing Record 22 of Set 1 | nha trang
# Processing Record 23 of Set 1 | wanxian
# Processing Record 24 of Set 1 | geraldton
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | panaba
# Processing Record 27 of Set 1 | mahebourg
# Processing Record 28 of Set 1 | kirovskiy
# Processing Record 29 of Set 1 | ambunti
# Processing Record 30 of Set 1 | torbay
# Processing Record 31 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 32 of Set 1 | three hills
# Processing Record 33 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 1 | dikson
# Processing Record 35 of Set 1 | tuktoyaktuk
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 1 | ust-maya
# Processing Record 39 of Set 1 | ndola
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | hilo
# Processing Record 42 of Set 1 | hithadhoo
# Processing Record 43 of Set 1 | mar del plata
# Processing Record 44 of Set 1 | rikitea
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 1 | port elizabeth
# Processing Record 48 of Set 1 | cubuk
# Processing Record 49 of Set 1 | ribeira grande
# Processing Record 50 of Set 1 | paamiut
# Processing Record 1 of Set 2 | nikolskoye
# Processing Record 2 of Set 2 | carnarvon
# Processing Record 3 of Set 2 | anloga
# Processing Record 4 of Set 2 | albany
# Processing Record 5 of Set 2 | pinega
# Processing Record 6 of Set 2 | lorengau
# Processing Record 7 of Set 2 | leh
# Processing Record 8 of Set 2 | babanusah
# City not found. Skipping...
# Processing Record 9 of Set 2 | hovd
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | cayenne
# Processing Record 12 of Set 2 | micheweni
# Processing Record 13 of Set 2 | tuatapere
# Processing Record 14 of Set 2 | ushtobe
# Processing Record 15 of Set 2 | boulsa
# Processing Record 16 of Set 2 | srednekolymsk
# Processing Record 17 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 2 | lavrentiya
# Processing Record 19 of Set 2 | epitalion
# Processing Record 20 of Set 2 | tigre
# Processing Record 21 of Set 2 | longyearbyen
# Processing Record 22 of Set 2 | butaritari
# Processing Record 23 of Set 2 | san ramon
# Processing Record 24 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 2 | barrow
# Processing Record 26 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 27 of Set 2 | kryvyy rih
# Processing Record 28 of Set 2 | cilegon
# Processing Record 29 of Set 2 | karratha
# Processing Record 30 of Set 2 | phrai bung
# City not found. Skipping...
# Processing Record 31 of Set 2 | cape town
# Processing Record 32 of Set 2 | puerto ayora
# Processing Record 33 of Set 2 | henties bay
# Processing Record 34 of Set 2 | biak
# Processing Record 35 of Set 2 | bredasdorp
# Processing Record 36 of Set 2 | sinnamary
# Processing Record 37 of Set 2 | souillac
# Processing Record 38 of Set 2 | erzin
# Processing Record 39 of Set 2 | saskylakh
# Processing Record 40 of Set 2 | houma
# Processing Record 41 of Set 2 | lasa
# Processing Record 42 of Set 2 | hami
# Processing Record 43 of Set 2 | haines junction
# Processing Record 44 of Set 2 | uppsala
# Processing Record 45 of Set 2 | hobyo
# Processing Record 46 of Set 2 | chapais
# Processing Record 47 of Set 2 | tromso
# Processing Record 48 of Set 2 | mathathane
# Processing Record 49 of Set 2 | zhezkazgan
# Processing Record 50 of Set 2 | qaanaaq
# Processing Record 1 of Set 3 | port alfred
# Processing Record 2 of Set 3 | ahipara
# Processing Record 3 of Set 3 | beinamar
# Processing Record 4 of Set 3 | pisco
# Processing Record 5 of Set 3 | baruun-urt
# Processing Record 6 of Set 3 | puerto lempira
# Processing Record 7 of Set 3 | bethel
# Processing Record 8 of Set 3 | tarakan
# Processing Record 9 of Set 3 | bluff
# Processing Record 10 of Set 3 | amuntai
# Processing Record 11 of Set 3 | acarau
# Processing Record 12 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 3 | margate
# Processing Record 14 of Set 3 | chokurdakh
# Processing Record 15 of Set 3 | iqaluit
# Processing Record 16 of Set 3 | hofn
# Processing Record 17 of Set 3 | narsaq
# Processing Record 18 of Set 3 | santa rosa
# Processing Record 19 of Set 3 | klaksvik
# Processing Record 20 of Set 3 | jamestown
# Processing Record 21 of Set 3 | alice springs
# Processing Record 22 of Set 3 | sao filipe
# Processing Record 23 of Set 3 | bandarbeyla
# Processing Record 24 of Set 3 | cidreira
# Processing Record 25 of Set 3 | kapaa
# Processing Record 26 of Set 3 | grand-santi
# Processing Record 27 of Set 3 | odessa
# Processing Record 28 of Set 3 | salalah
# Processing Record 29 of Set 3 | svetlaya
# Processing Record 30 of Set 3 | abalak
# Processing Record 31 of Set 3 | egvekinot
# Processing Record 32 of Set 3 | honiara
# Processing Record 33 of Set 3 | hermanus
# Processing Record 34 of Set 3 | bengkulu
# Processing Record 35 of Set 3 | praia
# Processing Record 36 of Set 3 | novokuznetsk
# Processing Record 37 of Set 3 | castro
# Processing Record 38 of Set 3 | ajaccio
# Processing Record 39 of Set 3 | hanzhong
# Processing Record 40 of Set 3 | sabang
# Processing Record 41 of Set 3 | susanville
# Processing Record 42 of Set 3 | vredendal
# Processing Record 43 of Set 3 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 44 of Set 3 | soyo
# Processing Record 45 of Set 3 | carlsbad
# Processing Record 46 of Set 3 | saldanha
# Processing Record 47 of Set 3 | cirpan
# City not found. Skipping...
# Processing Record 48 of Set 3 | boddam
# Processing Record 49 of Set 3 | pevek
# Processing Record 50 of Set 3 | norman wells
# Processing Record 1 of Set 4 | talaya
# Processing Record 2 of Set 4 | datong
# Processing Record 3 of Set 4 | sovetskiy
# Processing Record 4 of Set 4 | vila franca do campo
# Processing Record 5 of Set 4 | santa cruz
# Processing Record 6 of Set 4 | tasiilaq
# Processing Record 7 of Set 4 | saint anthony
# Processing Record 8 of Set 4 | osmena
# Processing Record 9 of Set 4 | sao francisco de paula
# Processing Record 10 of Set 4 | turukhansk
# Processing Record 11 of Set 4 | esik
# Processing Record 12 of Set 4 | kahului
# Processing Record 13 of Set 4 | nouadhibou
# Processing Record 14 of Set 4 | khatanga
# Processing Record 15 of Set 4 | manaus
# Processing Record 16 of Set 4 | krasnodar
# Processing Record 17 of Set 4 | crotone
# Processing Record 18 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 4 | victoria
# Processing Record 20 of Set 4 | mehamn
# Processing Record 21 of Set 4 | ulladulla
# Processing Record 22 of Set 4 | saint-francois
# Processing Record 23 of Set 4 | ancud
# Processing Record 24 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 4 | cherskiy
# Processing Record 26 of Set 4 | vao
# Processing Record 27 of Set 4 | dwarka
# Processing Record 28 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 4 | phalaborwa
# Processing Record 30 of Set 4 | izumo
# Processing Record 31 of Set 4 | nantucket
# Processing Record 32 of Set 4 | moindou
# Processing Record 33 of Set 4 | isangel
# Processing Record 34 of Set 4 | pilar
# Processing Record 35 of Set 4 | bambous virieux
# Processing Record 36 of Set 4 | constitucion
# Processing Record 37 of Set 4 | peace river
# Processing Record 38 of Set 4 | nikolayevsk-na-amure
# Processing Record 39 of Set 4 | boende
# Processing Record 40 of Set 4 | provideniya
# Processing Record 41 of Set 4 | kilindoni
# Processing Record 42 of Set 4 | jacareacanga
# Processing Record 43 of Set 4 | guerrero negro
# Processing Record 44 of Set 4 | saint george
# Processing Record 45 of Set 4 | pacific grove
# Processing Record 46 of Set 4 | caravelas
# Processing Record 47 of Set 4 | clyde river
# Processing Record 48 of Set 4 | kaitangata
# Processing Record 49 of Set 4 | fortuna
# Processing Record 50 of Set 4 | lagoa
# Processing Record 1 of Set 5 | dinsor
# City not found. Skipping...
# Processing Record 2 of Set 5 | saint-pierre
# Processing Record 3 of Set 5 | banswara
# Processing Record 4 of Set 5 | cabo san lucas
# Processing Record 5 of Set 5 | progreso
# Processing Record 6 of Set 5 | warrington
# Processing Record 7 of Set 5 | sobolevo
# Processing Record 8 of Set 5 | diffa
# Processing Record 9 of Set 5 | kindu
# Processing Record 10 of Set 5 | demba
# Processing Record 11 of Set 5 | kembe
# Processing Record 12 of Set 5 | rorvik
# Processing Record 13 of Set 5 | charagua
# Processing Record 14 of Set 5 | berlevag
# Processing Record 15 of Set 5 | roald
# Processing Record 16 of Set 5 | aklavik
# Processing Record 17 of Set 5 | newport
# Processing Record 18 of Set 5 | busselton
# Processing Record 19 of Set 5 | katobu
# Processing Record 20 of Set 5 | asau
# Processing Record 21 of Set 5 | kirakira
# Processing Record 22 of Set 5 | porto walter
# Processing Record 23 of Set 5 | east london
# Processing Record 24 of Set 5 | fairbanks
# Processing Record 25 of Set 5 | murree
# Processing Record 26 of Set 5 | sabha
# Processing Record 27 of Set 5 | yumen
# Processing Record 28 of Set 5 | kavieng
# Processing Record 29 of Set 5 | tilichiki
# Processing Record 30 of Set 5 | bonavista
# Processing Record 31 of Set 5 | vardo
# Processing Record 32 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 5 | sorland
# Processing Record 34 of Set 5 | honggang
# Processing Record 35 of Set 5 | kruisfontein
# Processing Record 36 of Set 5 | kerema
# Processing Record 37 of Set 5 | thinadhoo
# Processing Record 38 of Set 5 | talnakh
# Processing Record 39 of Set 5 | luderitz
# Processing Record 40 of Set 5 | chara
# Processing Record 41 of Set 5 | kenai
# Processing Record 42 of Set 5 | fort nelson
# Processing Record 43 of Set 5 | chiang khong
# Processing Record 44 of Set 5 | solone
# Processing Record 45 of Set 5 | korla
# Processing Record 46 of Set 5 | manta
# Processing Record 47 of Set 5 | comodoro rivadavia
# Processing Record 48 of Set 5 | kaka
# Processing Record 49 of Set 5 | esperance
# Processing Record 50 of Set 5 | paramonga
# Processing Record 1 of Set 6 | fontem
# Processing Record 2 of Set 6 | rasra
# Processing Record 3 of Set 6 | beringovskiy
# Processing Record 4 of Set 6 | san quintin
# Processing Record 5 of Set 6 | shubarkuduk
# Processing Record 6 of Set 6 | kodiak
# Processing Record 7 of Set 6 | natal
# Processing Record 8 of Set 6 | kirkuk
# Processing Record 9 of Set 6 | georgetown
# Processing Record 10 of Set 6 | codrington
# Processing Record 11 of Set 6 | klyuchi
# Processing Record 12 of Set 6 | sangar
# Processing Record 13 of Set 6 | zarubino
# Processing Record 14 of Set 6 | grand forks
# Processing Record 15 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 6 | selma
# Processing Record 17 of Set 6 | arica
# Processing Record 18 of Set 6 | angoche
# Processing Record 19 of Set 6 | camacha
# Processing Record 20 of Set 6 | lompoc
# Processing Record 21 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 6 | half moon bay
# Processing Record 23 of Set 6 | gusau
# Processing Record 24 of Set 6 | coquimbo
# Processing Record 25 of Set 6 | ponta do sol
# Processing Record 26 of Set 6 | esso
# Processing Record 27 of Set 6 | naifaru
# Processing Record 28 of Set 6 | yuci
# Processing Record 29 of Set 6 | jijiga
# Processing Record 30 of Set 6 | general roca
# Processing Record 31 of Set 6 | byron bay
# Processing Record 32 of Set 6 | charleston
# Processing Record 33 of Set 6 | uglovka
# Processing Record 34 of Set 6 | yellandu
# Processing Record 35 of Set 6 | tawala
# Processing Record 36 of Set 6 | ponta delgada
# Processing Record 37 of Set 6 | nanortalik
# Processing Record 38 of Set 6 | sao joao da barra
# Processing Record 39 of Set 6 | batagay
# Processing Record 40 of Set 6 | qaqortoq
# Processing Record 41 of Set 6 | elk city
# Processing Record 42 of Set 6 | unye
# City not found. Skipping...
# Processing Record 43 of Set 6 | yulara
# Processing Record 44 of Set 6 | venado tuerto
# Processing Record 45 of Set 6 | port-gentil
# Processing Record 46 of Set 6 | hamilton
# Processing Record 47 of Set 6 | syracuse
# Processing Record 48 of Set 6 | nagua
# Processing Record 49 of Set 6 | osinki
# Processing Record 50 of Set 6 | sept-iles
# Processing Record 1 of Set 7 | bathsheba
# Processing Record 2 of Set 7 | abha
# Processing Record 3 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 7 | cap malheureux
# Processing Record 5 of Set 7 | port-cartier
# Processing Record 6 of Set 7 | thompson
# Processing Record 7 of Set 7 | prescott
# Processing Record 8 of Set 7 | januaria
# Processing Record 9 of Set 7 | namatanai
# Processing Record 10 of Set 7 | alofi
# Processing Record 11 of Set 7 | arraial do cabo
# Processing Record 12 of Set 7 | great yarmouth
# Processing Record 13 of Set 7 | morant bay
# Processing Record 14 of Set 7 | moerai
# Processing Record 15 of Set 7 | vanavara
# Processing Record 16 of Set 7 | mirnyy
# Processing Record 17 of Set 7 | pitkyaranta
# Processing Record 18 of Set 7 | faya
# Processing Record 19 of Set 7 | nemuro
# Processing Record 20 of Set 7 | tawang
# Processing Record 21 of Set 7 | cascais
# Processing Record 22 of Set 7 | kavaratti
# Processing Record 23 of Set 7 | kitui
# Processing Record 24 of Set 7 | bamako
# Processing Record 25 of Set 7 | aksu
# Processing Record 26 of Set 7 | lata
# Processing Record 27 of Set 7 | khanapur
# Processing Record 28 of Set 7 | boyolangu
# Processing Record 29 of Set 7 | chuy
# Processing Record 30 of Set 7 | kaeo
# Processing Record 31 of Set 7 | yuryev-polskiy
# Processing Record 32 of Set 7 | san cristobal
# Processing Record 33 of Set 7 | chernyshevskiy
# Processing Record 34 of Set 7 | walvis bay
# Processing Record 35 of Set 7 | axim
# Processing Record 36 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 37 of Set 7 | karabulak
# Processing Record 38 of Set 7 | hualmay
# Processing Record 39 of Set 7 | suntar
# Processing Record 40 of Set 7 | grand island
# Processing Record 41 of Set 7 | balikpapan
# Processing Record 42 of Set 7 | berwick
# Processing Record 43 of Set 7 | meulaboh
# Processing Record 44 of Set 7 | macomb
# Processing Record 45 of Set 7 | kifri
# Processing Record 46 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 7 | arteaga
# Processing Record 48 of Set 7 | mandalgovi
# Processing Record 49 of Set 7 | bereda
# Processing Record 50 of Set 7 | buala
# Processing Record 1 of Set 8 | dzerzhinskoye
# Processing Record 2 of Set 8 | bungu
# Processing Record 3 of Set 8 | pontes e lacerda
# Processing Record 4 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 8 | soto la marina
# Processing Record 6 of Set 8 | sorsk
# Processing Record 7 of Set 8 | jurm
# Processing Record 8 of Set 8 | coihaique
# Processing Record 9 of Set 8 | banda aceh
# Processing Record 10 of Set 8 | chebsara
# Processing Record 11 of Set 8 | souris
# Processing Record 12 of Set 8 | matagami
# Processing Record 13 of Set 8 | pedernales
# Processing Record 14 of Set 8 | cockburn town
# Processing Record 15 of Set 8 | aiken
# Processing Record 16 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 8 | hay river
# Processing Record 18 of Set 8 | ust-omchug
# Processing Record 19 of Set 8 | cartagena
# Processing Record 20 of Set 8 | herrin
# Processing Record 21 of Set 8 | manaure
# Processing Record 22 of Set 8 | martapura
# Processing Record 23 of Set 8 | grand gaube
# Processing Record 24 of Set 8 | langham
# Processing Record 25 of Set 8 | vung tau
# Processing Record 26 of Set 8 | novo aripuana
# Processing Record 27 of Set 8 | husavik
# Processing Record 28 of Set 8 | elko
# Processing Record 29 of Set 8 | ornskoldsvik
# Processing Record 30 of Set 8 | tarko-sale
# Processing Record 31 of Set 8 | fenoarivo
# Processing Record 32 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 8 | mandal
# Processing Record 34 of Set 8 | batagay-alyta
# Processing Record 35 of Set 8 | tual
# Processing Record 36 of Set 8 | westpunt
# City not found. Skipping...
# Processing Record 37 of Set 8 | beni suef
# Processing Record 38 of Set 8 | tchamba
# Processing Record 39 of Set 8 | hvammstangi
# City not found. Skipping...
# Processing Record 40 of Set 8 | santa helena de goias
# Processing Record 41 of Set 8 | whitefish
# Processing Record 42 of Set 8 | avera
# Processing Record 43 of Set 8 | muroto
# Processing Record 44 of Set 8 | chimbarongo
# Processing Record 45 of Set 8 | meiganga
# Processing Record 46 of Set 8 | komsomolskiy
# Processing Record 47 of Set 8 | roma
# Processing Record 48 of Set 8 | brigantine
# Processing Record 49 of Set 8 | rocha
# Processing Record 50 of Set 8 | daliao
# Processing Record 1 of Set 9 | xining
# Processing Record 2 of Set 9 | karpathos
# Processing Record 3 of Set 9 | zhoucheng
# Processing Record 4 of Set 9 | avarua
# Processing Record 5 of Set 9 | te anau
# Processing Record 6 of Set 9 | tashtyp
# Processing Record 7 of Set 9 | hambantota
# Processing Record 8 of Set 9 | ketchikan
# Processing Record 9 of Set 9 | mount gambier
# Processing Record 10 of Set 9 | marsh harbour
# Processing Record 11 of Set 9 | batemans bay
# Processing Record 12 of Set 9 | grong
# Processing Record 13 of Set 9 | hohhot
# Processing Record 14 of Set 9 | orange
# Processing Record 15 of Set 9 | marinette
# Processing Record 16 of Set 9 | zhigansk
# Processing Record 17 of Set 9 | nabire
# Processing Record 18 of Set 9 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 19 of Set 9 | viljoenskroon
# Processing Record 20 of Set 9 | haicheng
# Processing Record 21 of Set 9 | bonthe
# Processing Record 22 of Set 9 | port blair
# Processing Record 23 of Set 9 | laguna
# Processing Record 24 of Set 9 | high level
# Processing Record 25 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 26 of Set 9 | kargasok
# Processing Record 27 of Set 9 | vila velha
# Processing Record 28 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 9 | kegayli
# City not found. Skipping...
# Processing Record 30 of Set 9 | newburn
# Processing Record 31 of Set 9 | malangali
# Processing Record 32 of Set 9 | meadow lake
# Processing Record 33 of Set 9 | mangrol
# Processing Record 34 of Set 9 | bonham
# Processing Record 35 of Set 9 | asfi
# Processing Record 36 of Set 9 | sioux lookout
# Processing Record 37 of Set 9 | kendari
# Processing Record 38 of Set 9 | shamsabad
# Processing Record 39 of Set 9 | yar-sale
# Processing Record 40 of Set 9 | jequie
# Processing Record 41 of Set 9 | panama city
# Processing Record 42 of Set 9 | saint-georges
# Processing Record 43 of Set 9 | tixtla
# City not found. Skipping...
# Processing Record 44 of Set 9 | pochutla
# Processing Record 45 of Set 9 | dingle
# Processing Record 46 of Set 9 | wilmington
# Processing Record 47 of Set 9 | mbeya
# Processing Record 48 of Set 9 | tiksi
# Processing Record 49 of Set 9 | nyirmada
# Processing Record 50 of Set 9 | camana
# Processing Record 1 of Set 10 | shizuishan
# Processing Record 2 of Set 10 | nuuk
# Processing Record 3 of Set 10 | airai
# Processing Record 4 of Set 10 | kolosovka
# Processing Record 5 of Set 10 | sola
# Processing Record 6 of Set 10 | labuhan
# Processing Record 7 of Set 10 | litoral del san juan
# City not found. Skipping...
# Processing Record 8 of Set 10 | conceicao do araguaia
# Processing Record 9 of Set 10 | anchorage
# Processing Record 10 of Set 10 | kurumkan
# Processing Record 11 of Set 10 | sheridan
# Processing Record 12 of Set 10 | najran
# Processing Record 13 of Set 10 | fukue
# Processing Record 14 of Set 10 | kangaatsiaq
# Processing Record 15 of Set 10 | ilulissat
# Processing Record 16 of Set 10 | vieux-habitants
# Processing Record 17 of Set 10 | ust-nera
# Processing Record 18 of Set 10 | palo alto
# Processing Record 19 of Set 10 | ostrovnoy
# Processing Record 20 of Set 10 | harnosand
# Processing Record 21 of Set 10 | muktsar
# Processing Record 22 of Set 10 | leningradskiy
# Processing Record 23 of Set 10 | horta
# Processing Record 24 of Set 10 | chachoengsao
# Processing Record 25 of Set 10 | presidencia roque saenz pena
# Processing Record 26 of Set 10 | oranjestad
# Processing Record 27 of Set 10 | nyurba
# Processing Record 28 of Set 10 | catuday
# Processing Record 29 of Set 10 | vestmanna
# Processing Record 30 of Set 10 | sitka
# Processing Record 31 of Set 10 | evensk
# Processing Record 32 of Set 10 | tura
# Processing Record 33 of Set 10 | misratah
# Processing Record 34 of Set 10 | velyka pysarivka
# Processing Record 35 of Set 10 | vitimskiy
# City not found. Skipping...
# Processing Record 36 of Set 10 | machaneng
# Processing Record 37 of Set 10 | ayia marina
# Processing Record 38 of Set 10 | poltavskaya
# Processing Record 39 of Set 10 | santiago del estero
# Processing Record 40 of Set 10 | alyangula
# Processing Record 41 of Set 10 | charters towers
# Processing Record 42 of Set 10 | nishihara
# Processing Record 43 of Set 10 | port lincoln
# Processing Record 44 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 10 | keetmanshoop
# Processing Record 46 of Set 10 | gurskoye
# City not found. Skipping...
# Processing Record 47 of Set 10 | kathu
# Processing Record 48 of Set 10 | raudeberg
# Processing Record 49 of Set 10 | partizanskoye
# Processing Record 50 of Set 10 | yelizovo
# Processing Record 1 of Set 11 | kaseda
# Processing Record 2 of Set 11 | kourou
# Processing Record 3 of Set 11 | harper
# Processing Record 4 of Set 11 | kudinovo
# Processing Record 5 of Set 11 | teya
# Processing Record 6 of Set 11 | ayan
# Processing Record 7 of Set 11 | aleksandrovsk
# Processing Record 8 of Set 11 | port hardy
# Processing Record 9 of Set 11 | tawnat
# City not found. Skipping...
# Processing Record 10 of Set 11 | puerto escondido
# Processing Record 11 of Set 11 | mitsamiouli
# Processing Record 12 of Set 11 | poum
# Processing Record 13 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 14 of Set 11 | khandyga
# Processing Record 15 of Set 11 | paraiso
# Processing Record 16 of Set 11 | touros
# Processing Record 17 of Set 11 | coahuayana
# Processing Record 18 of Set 11 | taywarah
# Processing Record 19 of Set 11 | phalombe
# Processing Record 20 of Set 11 | mareeba
# Processing Record 21 of Set 11 | dubbo
# Processing Record 22 of Set 11 | vanimo
# Processing Record 23 of Set 11 | umm kaddadah
# Processing Record 24 of Set 11 | vestmannaeyjar
# Processing Record 25 of Set 11 | powell river
# Processing Record 26 of Set 11 | varzob
# Processing Record 27 of Set 11 | gandu
# Processing Record 28 of Set 11 | nara
# Processing Record 29 of Set 11 | bireun
# Processing Record 30 of Set 11 | mount isa
# Processing Record 31 of Set 11 | muzhi
# Processing Record 32 of Set 11 | rawson
# Processing Record 33 of Set 11 | teacapan
# Processing Record 34 of Set 11 | cururupu
# Processing Record 35 of Set 11 | honningsvag
# Processing Record 36 of Set 11 | aasiaat
# Processing Record 37 of Set 11 | naze
# Processing Record 38 of Set 11 | college
# Processing Record 39 of Set 11 | mogadishu
# Processing Record 40 of Set 11 | waingapu
# Processing Record 41 of Set 11 | khokhryaki
# Processing Record 42 of Set 11 | bubaque
# Processing Record 43 of Set 11 | verkhoyansk
# Processing Record 44 of Set 11 | dabakala
# Processing Record 45 of Set 11 | mouzakion
# City not found. Skipping...
# Processing Record 46 of Set 11 | meghri
# Processing Record 47 of Set 11 | poretskoye
# Processing Record 48 of Set 11 | kyzyl-suu
# Processing Record 49 of Set 11 | lembeni
# Processing Record 50 of Set 11 | bose
# Processing Record 1 of Set 12 | morro bay
# Processing Record 2 of Set 12 | lebu
# Processing Record 3 of Set 12 | poya
# Processing Record 4 of Set 12 | stornoway
# Processing Record 5 of Set 12 | guisa
# Processing Record 6 of Set 12 | kyshtovka
# Processing Record 7 of Set 12 | rossland
# Processing Record 8 of Set 12 | nokaneng
# Processing Record 9 of Set 12 | grindavik
# Processing Record 10 of Set 12 | turangi
# Processing Record 11 of Set 12 | vallenar
# Processing Record 12 of Set 12 | copiapo
# Processing Record 13 of Set 12 | nouakchott
# Processing Record 14 of Set 12 | san cosme y damian
# Processing Record 15 of Set 12 | stubbekobing
# Processing Record 16 of Set 12 | ixtapa
# Processing Record 17 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 18 of Set 12 | zabol
# Processing Record 19 of Set 12 | armizonskoye
# Processing Record 20 of Set 12 | aitape
# Processing Record 21 of Set 12 | auki
# Processing Record 22 of Set 12 | maceio
# Processing Record 23 of Set 12 | richards bay
# Processing Record 24 of Set 12 | hellvik
# Processing Record 25 of Set 12 | bay roberts
# Processing Record 26 of Set 12 | gasa
# Processing Record 27 of Set 12 | acapulco
# Processing Record 28 of Set 12 | mahibadhoo
# Processing Record 29 of Set 12 | north bend
# Processing Record 30 of Set 12 | quelimane
# Processing Record 31 of Set 12 | karasjok
# Processing Record 32 of Set 12 | mitu
# Processing Record 33 of Set 12 | kuytun
# Processing Record 34 of Set 12 | pakxan
# Processing Record 35 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 36 of Set 12 | dawlatabad
# Processing Record 37 of Set 12 | san marco in lamis
# Processing Record 38 of Set 12 | ilo
# Processing Record 39 of Set 12 | merrill
# Processing Record 40 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 41 of Set 12 | plettenberg bay
# Processing Record 42 of Set 12 | poplar bluff
# Processing Record 43 of Set 12 | bria
# Processing Record 44 of Set 12 | rongcheng
# Processing Record 45 of Set 12 | bara
# Processing Record 46 of Set 12 | sydney
# Processing Record 47 of Set 12 | xichang
# Processing Record 48 of Set 12 | kambove
# Processing Record 49 of Set 12 | kisangani
# Processing Record 50 of Set 12 | danville
# Processing Record 1 of Set 13 | san jeronimo
# Processing Record 2 of Set 13 | yinchuan
# Processing Record 3 of Set 13 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 13 | smithers
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Get the number of the cities
len(city_data)
# Out:
# 559

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Hasaki  35.7333  140.8333     73.80        92         100        5.73
# 1      Samarai -10.6167  150.6667     78.91        83          61       12.50
# 2        Price  39.5994 -110.8107     93.72        12          72        6.44
# 3   Hervey Bay -25.2986  152.8535     58.03        83          11        7.49
# 4       Faanui -16.4833 -151.7500     79.70        73           4       21.39
# 5       Chakia  26.4167   85.0500     86.14        70          13        5.88
# 6      Balabac   7.9868  117.0645     81.27        75          77        3.06
# 7  New Norfolk -42.7826  147.0587     48.92        81          94        1.99
# 8  Yellowknife  62.4560 -114.3525     75.33        38          60        8.99
# 9     La Ronge  55.1001 -105.2842     71.44        41          81        8.52
#
#   Current Description Country                 Date
# 0     overcast clouds      JP  2021-07-12 20:00:43
# 1       broken clouds      PG  2021-07-12 19:57:47
# 2       broken clouds      US  2021-07-12 20:00:44
# 3          few clouds      AU  2021-07-12 20:00:45
# 4           clear sky      PF  2021-07-12 19:58:16
# 5          few clouds      IN  2021-07-12 20:00:45
# 6       broken clouds      PH  2021-07-12 20:00:45
# 7     overcast clouds      AU  2021-07-12 20:00:46
# 8       broken clouds      CA  2021-07-12 20:00:47
# 9       broken clouds      CA  2021-07-12 20:00:47

# %%
#have a sytax error here  to fix still  
#Organize the columns in the DataFrame.
city_data__no_date_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed','Current Description']]
city_data__no_date_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Hasaki      JP  35.7333  140.8333     73.80        92         100
# 1      Samarai      PG -10.6167  150.6667     78.91        83          61
# 2        Price      US  39.5994 -110.8107     93.72        12          72
# 3   Hervey Bay      AU -25.2986  152.8535     58.03        83          11
# 4       Faanui      PF -16.4833 -151.7500     79.70        73           4
# 5       Chakia      IN  26.4167   85.0500     86.14        70          13
# 6      Balabac      PH   7.9868  117.0645     81.27        75          77
# 7  New Norfolk      AU -42.7826  147.0587     48.92        81          94
# 8  Yellowknife      CA  62.4560 -114.3525     75.33        38          60
# 9     La Ronge      CA  55.1001 -105.2842     71.44        41          81
#
#    Wind Speed Current Description
# 0        5.73     overcast clouds
# 1       12.50       broken clouds
# 2        6.44       broken clouds
# 3        7.49          few clouds
# 4       21.39           clear sky
# 5        5.88          few clouds
# 6        3.06       broken clouds
# 7        1.99     overcast clouds
# 8        8.99       broken clouds
# 9        8.52       broken clouds

# %%
#make this active after sure I know where it's going and its' right 
# Create and export the final Data Frame into a CSV
##city_data__no_date_df.to_csv("WeatherPy_Database.csv", index_label="City_ID")
