# %%
#Challenge part 1 pull the l and l info make a place for cities, count em, 
#Start here with Justin

# Import the dependencies.
import pandas as pd
#import matplotlib.pyplot as plt
import numpy as np

#Use the citipy module to determine city based on latitude and longitude.
#%pip install citipy
from citipy import citipy

# %%
# Create a set of random 2000 latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

#Zipping the pairs in a tuple with zip() function.
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
#Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3a5c22543e7db7978b522be236b0a831'

# %%
#cut from starting mod 626
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list using enumerate function.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]['description']
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kautokeino
# Processing Record 2 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 1 | bolobo
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | nikolskoye
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | avarua
# Processing Record 9 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | klaksvik
# Processing Record 12 of Set 1 | saint george
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | chokurdakh
# Processing Record 15 of Set 1 | lebu
# Processing Record 16 of Set 1 | dikson
# Processing Record 17 of Set 1 | codrington
# Processing Record 18 of Set 1 | khatanga
# Processing Record 19 of Set 1 | constitucion
# Processing Record 20 of Set 1 | carangola
# Processing Record 21 of Set 1 | yermakovskoye
# Processing Record 22 of Set 1 | paris
# Processing Record 23 of Set 1 | qaanaaq
# Processing Record 24 of Set 1 | trincomalee
# Processing Record 25 of Set 1 | pevek
# Processing Record 26 of Set 1 | dovers
# Processing Record 27 of Set 1 | derzhavinsk
# Processing Record 28 of Set 1 | tibati
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | cherskiy
# Processing Record 31 of Set 1 | rikitea
# Processing Record 32 of Set 1 | ponta do sol
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | vychegodskiy
# Processing Record 35 of Set 1 | pangnirtung
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | carnarvon
# Processing Record 38 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 1 | yulara
# Processing Record 40 of Set 1 | murgab
# Processing Record 41 of Set 1 | willowmore
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | torbay
# Processing Record 44 of Set 1 | miles city
# Processing Record 45 of Set 1 | hilo
# Processing Record 46 of Set 1 | bredasdorp
# Processing Record 47 of Set 1 | rocha
# Processing Record 48 of Set 1 | tilichiki
# Processing Record 49 of Set 1 | port elizabeth
# Processing Record 50 of Set 1 | bluff
# Processing Record 1 of Set 2 | geraldton
# Processing Record 2 of Set 2 | castro
# Processing Record 3 of Set 2 | hasaki
# Processing Record 4 of Set 2 | ushuaia
# Processing Record 5 of Set 2 | butaritari
# Processing Record 6 of Set 2 | souillac
# Processing Record 7 of Set 2 | galle
# Processing Record 8 of Set 2 | toccoa
# Processing Record 9 of Set 2 | port-gentil
# Processing Record 10 of Set 2 | busselton
# Processing Record 11 of Set 2 | erenhot
# Processing Record 12 of Set 2 | fairbanks
# Processing Record 13 of Set 2 | new norfolk
# Processing Record 14 of Set 2 | te anau
# Processing Record 15 of Set 2 | kapaa
# Processing Record 16 of Set 2 | gorontalo
# Processing Record 17 of Set 2 | fez
# Processing Record 18 of Set 2 | yellowknife
# Processing Record 19 of Set 2 | great falls
# Processing Record 20 of Set 2 | kahului
# Processing Record 21 of Set 2 | chuy
# Processing Record 22 of Set 2 | blackwater
# Processing Record 23 of Set 2 | akyab
# Processing Record 24 of Set 2 | mitu
# Processing Record 25 of Set 2 | vao
# Processing Record 26 of Set 2 | upernavik
# Processing Record 27 of Set 2 | east london
# Processing Record 28 of Set 2 | orlik
# Processing Record 29 of Set 2 | lagoa
# Processing Record 30 of Set 2 | lasa
# Processing Record 31 of Set 2 | bhimunipatnam
# Processing Record 32 of Set 2 | tuktoyaktuk
# Processing Record 33 of Set 2 | albany
# Processing Record 34 of Set 2 | nome
# Processing Record 35 of Set 2 | valparaiso
# Processing Record 36 of Set 2 | byron bay
# Processing Record 37 of Set 2 | petropavlovka
# Processing Record 38 of Set 2 | amga
# Processing Record 39 of Set 2 | ust-maya
# Processing Record 40 of Set 2 | tolaga bay
# Processing Record 41 of Set 2 | togur
# Processing Record 42 of Set 2 | dunedin
# Processing Record 43 of Set 2 | sao joao da barra
# Processing Record 44 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 2 | fort nelson
# Processing Record 46 of Set 2 | taoudenni
# Processing Record 47 of Set 2 | georgetown
# Processing Record 48 of Set 2 | barrow
# Processing Record 49 of Set 2 | bilibino
# Processing Record 50 of Set 2 | nokaneng
# Processing Record 1 of Set 3 | banda aceh
# Processing Record 2 of Set 3 | cranbourne
# Processing Record 3 of Set 3 | mogadishu
# Processing Record 4 of Set 3 | comodoro rivadavia
# Processing Record 5 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 3 | tirano
# Processing Record 7 of Set 3 | rorvik
# Processing Record 8 of Set 3 | bengkulu
# Processing Record 9 of Set 3 | ribeira grande
# Processing Record 10 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 3 | manjacaze
# Processing Record 12 of Set 3 | calvia
# Processing Record 13 of Set 3 | lipany
# Processing Record 14 of Set 3 | mehamn
# Processing Record 15 of Set 3 | moissala
# Processing Record 16 of Set 3 | sao filipe
# Processing Record 17 of Set 3 | qui nhon
# Processing Record 18 of Set 3 | hamilton
# Processing Record 19 of Set 3 | palmer
# Processing Record 20 of Set 3 | praya
# Processing Record 21 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 3 | inirida
# Processing Record 23 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 3 | sungairaya
# Processing Record 25 of Set 3 | rancharia
# Processing Record 26 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 3 | provideniya
# Processing Record 28 of Set 3 | hithadhoo
# Processing Record 29 of Set 3 | lompoc
# Processing Record 30 of Set 3 | lillesand
# Processing Record 31 of Set 3 | karauzyak
# City not found. Skipping...
# Processing Record 32 of Set 3 | kandrian
# Processing Record 33 of Set 3 | quatre cocos
# Processing Record 34 of Set 3 | forrest city
# Processing Record 35 of Set 3 | la ronge
# Processing Record 36 of Set 3 | fortuna
# Processing Record 37 of Set 3 | oranjemund
# Processing Record 38 of Set 3 | pacific grove
# Processing Record 39 of Set 3 | jahrom
# City not found. Skipping...
# Processing Record 40 of Set 3 | tasiilaq
# Processing Record 41 of Set 3 | zhigansk
# Processing Record 42 of Set 3 | severo-kurilsk
# Processing Record 43 of Set 3 | scarborough
# Processing Record 44 of Set 3 | puerto baquerizo moreno
# Processing Record 45 of Set 3 | dumas
# Processing Record 46 of Set 3 | broken hill
# Processing Record 47 of Set 3 | ahipara
# Processing Record 48 of Set 3 | bathsheba
# Processing Record 49 of Set 3 | moba
# Processing Record 50 of Set 3 | adrar
# Processing Record 1 of Set 4 | general roca
# Processing Record 2 of Set 4 | basco
# Processing Record 3 of Set 4 | vila franca do campo
# Processing Record 4 of Set 4 | acajutla
# Processing Record 5 of Set 4 | pangai
# Processing Record 6 of Set 4 | mar del plata
# Processing Record 7 of Set 4 | vuktyl
# Processing Record 8 of Set 4 | hermanus
# Processing Record 9 of Set 4 | pinotepa de don luis
# Processing Record 10 of Set 4 | nanortalik
# Processing Record 11 of Set 4 | murovani kurylivtsi
# Processing Record 12 of Set 4 | bambous virieux
# Processing Record 13 of Set 4 | merauke
# Processing Record 14 of Set 4 | ulladulla
# Processing Record 15 of Set 4 | belmonte
# Processing Record 16 of Set 4 | darnah
# Processing Record 17 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 4 | airai
# Processing Record 19 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 4 | narsaq
# Processing Record 21 of Set 4 | verkhnyaya inta
# Processing Record 22 of Set 4 | teguldet
# Processing Record 23 of Set 4 | bilma
# Processing Record 24 of Set 4 | bowmore
# Processing Record 25 of Set 4 | hay river
# Processing Record 26 of Set 4 | touros
# Processing Record 27 of Set 4 | avera
# Processing Record 28 of Set 4 | zambezi
# Processing Record 29 of Set 4 | kaitangata
# Processing Record 30 of Set 4 | coahuayana
# Processing Record 31 of Set 4 | cidreira
# Processing Record 32 of Set 4 | kostroma
# Processing Record 33 of Set 4 | thompson
# Processing Record 34 of Set 4 | umm lajj
# Processing Record 35 of Set 4 | afmadu
# City not found. Skipping...
# Processing Record 36 of Set 4 | chokwe
# Processing Record 37 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 4 | nizhniy ingash
# Processing Record 39 of Set 4 | kampot
# Processing Record 40 of Set 4 | hendek
# Processing Record 41 of Set 4 | chumikan
# Processing Record 42 of Set 4 | dudinka
# Processing Record 43 of Set 4 | mergui
# City not found. Skipping...
# Processing Record 44 of Set 4 | kruisfontein
# Processing Record 45 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 4 | vardo
# Processing Record 47 of Set 4 | phalaborwa
# Processing Record 48 of Set 4 | madisonville
# Processing Record 49 of Set 4 | suzun
# Processing Record 50 of Set 4 | circleville
# Processing Record 1 of Set 5 | victoria
# Processing Record 2 of Set 5 | camargo
# Processing Record 3 of Set 5 | yerbogachen
# Processing Record 4 of Set 5 | bollnas
# Processing Record 5 of Set 5 | skovorodino
# Processing Record 6 of Set 5 | rawson
# Processing Record 7 of Set 5 | hukuntsi
# Processing Record 8 of Set 5 | salalah
# Processing Record 9 of Set 5 | kaohsiung
# Processing Record 10 of Set 5 | soe
# Processing Record 11 of Set 5 | paamiut
# Processing Record 12 of Set 5 | opopeo
# Processing Record 13 of Set 5 | naze
# Processing Record 14 of Set 5 | emba
# Processing Record 15 of Set 5 | araceli
# Processing Record 16 of Set 5 | kazachinskoye
# Processing Record 17 of Set 5 | katsuura
# Processing Record 18 of Set 5 | saint-philippe
# Processing Record 19 of Set 5 | san cristobal
# Processing Record 20 of Set 5 | asfi
# Processing Record 21 of Set 5 | upata
# Processing Record 22 of Set 5 | jaicos
# Processing Record 23 of Set 5 | kharian
# Processing Record 24 of Set 5 | zalaegerszeg
# Processing Record 25 of Set 5 | vanimo
# Processing Record 26 of Set 5 | burica
# City not found. Skipping...
# Processing Record 27 of Set 5 | loandjili
# Processing Record 28 of Set 5 | ostrogozhsk
# Processing Record 29 of Set 5 | guerrero negro
# Processing Record 30 of Set 5 | povenets
# Processing Record 31 of Set 5 | arraial do cabo
# Processing Record 32 of Set 5 | usakos
# Processing Record 33 of Set 5 | shieli
# Processing Record 34 of Set 5 | jabiru
# City not found. Skipping...
# Processing Record 35 of Set 5 | brae
# Processing Record 36 of Set 5 | jabinyanah
# Processing Record 37 of Set 5 | bria
# Processing Record 38 of Set 5 | saskylakh
# Processing Record 39 of Set 5 | eqbaliyeh
# Processing Record 40 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 41 of Set 5 | iskateley
# Processing Record 42 of Set 5 | bassila
# Processing Record 43 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 44 of Set 5 | boueni
# Processing Record 45 of Set 5 | mareeba
# Processing Record 46 of Set 5 | durban
# Processing Record 47 of Set 5 | pocri
# Processing Record 48 of Set 5 | beisfjord
# Processing Record 49 of Set 5 | santander
# Processing Record 50 of Set 5 | labuhan
# Processing Record 1 of Set 6 | acarau
# Processing Record 2 of Set 6 | olafsvik
# Processing Record 3 of Set 6 | beringovskiy
# Processing Record 4 of Set 6 | ballina
# Processing Record 5 of Set 6 | venado tuerto
# Processing Record 6 of Set 6 | poplar bluff
# Processing Record 7 of Set 6 | kinsale
# Processing Record 8 of Set 6 | maykain
# City not found. Skipping...
# Processing Record 9 of Set 6 | esperance
# Processing Record 10 of Set 6 | trairi
# Processing Record 11 of Set 6 | kaura namoda
# Processing Record 12 of Set 6 | port augusta
# Processing Record 13 of Set 6 | lavrentiya
# Processing Record 14 of Set 6 | carutapera
# Processing Record 15 of Set 6 | ahuimanu
# Processing Record 16 of Set 6 | ancud
# Processing Record 17 of Set 6 | kodiak
# Processing Record 18 of Set 6 | vincennes
# Processing Record 19 of Set 6 | jiuquan
# Processing Record 20 of Set 6 | camalu
# Processing Record 21 of Set 6 | treinta y tres
# Processing Record 22 of Set 6 | san patricio
# Processing Record 23 of Set 6 | skibbereen
# Processing Record 24 of Set 6 | rio gallegos
# Processing Record 25 of Set 6 | whitianga
# Processing Record 26 of Set 6 | puerto del rosario
# Processing Record 27 of Set 6 | faanui
# Processing Record 28 of Set 6 | samarai
# Processing Record 29 of Set 6 | lindi
# Processing Record 30 of Set 6 | basar
# Processing Record 31 of Set 6 | kirakira
# Processing Record 32 of Set 6 | maragogi
# Processing Record 33 of Set 6 | aykhal
# Processing Record 34 of Set 6 | dongsheng
# Processing Record 35 of Set 6 | portland
# Processing Record 36 of Set 6 | shingu
# Processing Record 37 of Set 6 | gari
# Processing Record 38 of Set 6 | abapo
# Processing Record 39 of Set 6 | abrau-dyurso
# Processing Record 40 of Set 6 | gravelbourg
# Processing Record 41 of Set 6 | biak
# Processing Record 42 of Set 6 | jiangyou
# Processing Record 43 of Set 6 | damietta
# Processing Record 44 of Set 6 | bam
# Processing Record 45 of Set 6 | tessalit
# Processing Record 46 of Set 6 | talnakh
# Processing Record 47 of Set 6 | le port
# Processing Record 48 of Set 6 | deputatskiy
# Processing Record 49 of Set 6 | karamay
# City not found. Skipping...
# Processing Record 50 of Set 6 | mansa
# Processing Record 1 of Set 7 | tayu
# Processing Record 2 of Set 7 | patacamaya
# Processing Record 3 of Set 7 | leningradskiy
# Processing Record 4 of Set 7 | peniche
# Processing Record 5 of Set 7 | angra
# City not found. Skipping...
# Processing Record 6 of Set 7 | dengzhou
# Processing Record 7 of Set 7 | mount gambier
# Processing Record 8 of Set 7 | boa esperanca
# Processing Record 9 of Set 7 | sohag
# Processing Record 10 of Set 7 | lodja
# Processing Record 11 of Set 7 | bethel
# Processing Record 12 of Set 7 | loviisa
# Processing Record 13 of Set 7 | pangody
# Processing Record 14 of Set 7 | midland
# Processing Record 15 of Set 7 | batemans bay
# Processing Record 16 of Set 7 | zonguldak
# Processing Record 17 of Set 7 | sindand
# City not found. Skipping...
# Processing Record 18 of Set 7 | tornio
# Processing Record 19 of Set 7 | kungurtug
# Processing Record 20 of Set 7 | uyuni
# Processing Record 21 of Set 7 | sitka
# Processing Record 22 of Set 7 | alice springs
# Processing Record 23 of Set 7 | camacha
# Processing Record 24 of Set 7 | gisborne
# Processing Record 25 of Set 7 | sitniki
# Processing Record 26 of Set 7 | opuwo
# Processing Record 27 of Set 7 | okhotsk
# Processing Record 28 of Set 7 | vestmannaeyjar
# Processing Record 29 of Set 7 | iqaluit
# Processing Record 30 of Set 7 | mathathane
# Processing Record 31 of Set 7 | zhaoqing
# Processing Record 32 of Set 7 | nizhneudinsk
# Processing Record 33 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 34 of Set 7 | williams lake
# Processing Record 35 of Set 7 | christchurch
# Processing Record 36 of Set 7 | narasannapeta
# Processing Record 37 of Set 7 | sistranda
# Processing Record 38 of Set 7 | varhaug
# Processing Record 39 of Set 7 | talaja
# Processing Record 40 of Set 7 | canyon
# Processing Record 41 of Set 7 | gamba
# Processing Record 42 of Set 7 | kharitonovo
# Processing Record 43 of Set 7 | neiafu
# Processing Record 44 of Set 7 | longyearbyen
# Processing Record 45 of Set 7 | mahebourg
# Processing Record 46 of Set 7 | sioux lookout
# Processing Record 47 of Set 7 | kut chap
# Processing Record 48 of Set 7 | mucurapo
# Processing Record 49 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 50 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 1 of Set 8 | iralaya
# Processing Record 2 of Set 8 | the valley
# Processing Record 3 of Set 8 | norman wells
# Processing Record 4 of Set 8 | pisco
# Processing Record 5 of Set 8 | katha
# City not found. Skipping...
# Processing Record 6 of Set 8 | zhigalovo
# Processing Record 7 of Set 8 | mitsamiouli
# Processing Record 8 of Set 8 | blagodatnoye
# Processing Record 9 of Set 8 | havre-saint-pierre
# Processing Record 10 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 8 | susehri
# Processing Record 13 of Set 8 | gombe
# Processing Record 14 of Set 8 | kailua
# Processing Record 15 of Set 8 | nishihara
# Processing Record 16 of Set 8 | demba
# Processing Record 17 of Set 8 | zhanatas
# City not found. Skipping...
# Processing Record 18 of Set 8 | saint-georges
# Processing Record 19 of Set 8 | cabo san lucas
# Processing Record 20 of Set 8 | evensk
# Processing Record 21 of Set 8 | santa engracia
# Processing Record 22 of Set 8 | grimari
# City not found. Skipping...
# Processing Record 23 of Set 8 | soligalich
# Processing Record 24 of Set 8 | goderich
# Processing Record 25 of Set 8 | mazsalaca
# Processing Record 26 of Set 8 | zapolyarnyy
# Processing Record 27 of Set 8 | mapiri
# Processing Record 28 of Set 8 | nurmijarvi
# Processing Record 29 of Set 8 | port lincoln
# Processing Record 30 of Set 8 | vostok
# Processing Record 31 of Set 8 | praia
# Processing Record 32 of Set 8 | buzmeyin
# Processing Record 33 of Set 8 | adelaide
# Processing Record 34 of Set 8 | freital
# Processing Record 35 of Set 8 | kavaratti
# Processing Record 36 of Set 8 | maridi
# Processing Record 37 of Set 8 | baturaja
# Processing Record 38 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 8 | huarmey
# Processing Record 40 of Set 8 | nim ka thana
# City not found. Skipping...
# Processing Record 41 of Set 8 | de-kastri
# Processing Record 42 of Set 8 | kasongo-lunda
# Processing Record 43 of Set 8 | eureka
# Processing Record 44 of Set 8 | buala
# Processing Record 45 of Set 8 | juneau
# Processing Record 46 of Set 8 | tuatapere
# Processing Record 47 of Set 8 | puerto madryn
# Processing Record 48 of Set 8 | rabo de peixe
# Processing Record 49 of Set 8 | fuling
# Processing Record 50 of Set 8 | westport
# Processing Record 1 of Set 9 | waipawa
# Processing Record 2 of Set 9 | moose factory
# Processing Record 3 of Set 9 | severo-yeniseyskiy
# Processing Record 4 of Set 9 | nyurba
# Processing Record 5 of Set 9 | imbituba
# Processing Record 6 of Set 9 | tigre
# Processing Record 7 of Set 9 | haines junction
# Processing Record 8 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 9 of Set 9 | makokou
# Processing Record 10 of Set 9 | port hedland
# Processing Record 11 of Set 9 | isangel
# Processing Record 12 of Set 9 | coquimbo
# Processing Record 13 of Set 9 | garm
# City not found. Skipping...
# Processing Record 14 of Set 9 | chapais
# Processing Record 15 of Set 9 | tiksi
# Processing Record 16 of Set 9 | vung tau
# Processing Record 17 of Set 9 | shakhtinsk
# Processing Record 18 of Set 9 | komsomolskiy
# Processing Record 19 of Set 9 | hofn
# Processing Record 20 of Set 9 | palauig
# Processing Record 21 of Set 9 | ormara
# Processing Record 22 of Set 9 | cayenne
# Processing Record 23 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 9 | saldanha
# Processing Record 25 of Set 9 | kenai
# Processing Record 26 of Set 9 | sanmenxia
# Processing Record 27 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 28 of Set 9 | straumen
# Processing Record 29 of Set 9 | bokaro
# Processing Record 30 of Set 9 | dingle
# Processing Record 31 of Set 9 | mahaicony
# City not found. Skipping...
# Processing Record 32 of Set 9 | dwarka
# Processing Record 33 of Set 9 | alofi
# Processing Record 34 of Set 9 | marawi
# Processing Record 35 of Set 9 | aswan
# Processing Record 36 of Set 9 | morro bay
# Processing Record 37 of Set 9 | jambi
# Processing Record 38 of Set 9 | aksarka
# Processing Record 39 of Set 9 | husavik
# Processing Record 40 of Set 9 | sobolevo
# Processing Record 41 of Set 9 | bodaybo
# Processing Record 42 of Set 9 | esso
# Processing Record 43 of Set 9 | turukhansk
# Processing Record 44 of Set 9 | mecca
# Processing Record 45 of Set 9 | bojaya
# City not found. Skipping...
# Processing Record 46 of Set 9 | sisimiut
# Processing Record 47 of Set 9 | ola
# Processing Record 48 of Set 9 | betare oya
# Processing Record 49 of Set 9 | albanel
# Processing Record 50 of Set 9 | saint-pierre
# Processing Record 1 of Set 10 | santa cruz
# Processing Record 2 of Set 10 | svetlyy
# Processing Record 3 of Set 10 | marana
# Processing Record 4 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 10 | saurimo
# Processing Record 6 of Set 10 | flinders
# Processing Record 7 of Set 10 | tiznit
# Processing Record 8 of Set 10 | miranorte
# City not found. Skipping...
# Processing Record 9 of Set 10 | rantepao
# Processing Record 10 of Set 10 | carndonagh
# Processing Record 11 of Set 10 | oyama
# Processing Record 12 of Set 10 | praia da vitoria
# Processing Record 13 of Set 10 | kaeo
# Processing Record 14 of Set 10 | drochia
# Processing Record 15 of Set 10 | kropotkin
# Processing Record 16 of Set 10 | russell
# Processing Record 17 of Set 10 | ejura
# Processing Record 18 of Set 10 | hami
# Processing Record 19 of Set 10 | sabha
# Processing Record 20 of Set 10 | muzhi
# Processing Record 21 of Set 10 | grindavik
# Processing Record 22 of Set 10 | cazones
# Processing Record 23 of Set 10 | cabedelo
# Processing Record 24 of Set 10 | atchison
# Processing Record 25 of Set 10 | divnogorsk
# Processing Record 26 of Set 10 | amethi
# Processing Record 27 of Set 10 | suhbaatar
# Processing Record 28 of Set 10 | jaguey grande
# Processing Record 29 of Set 10 | agstafa
# City not found. Skipping...
# Processing Record 30 of Set 10 | rairangpur
# Processing Record 31 of Set 10 | aguimes
# Processing Record 32 of Set 10 | guadalupe victoria
# Processing Record 33 of Set 10 | pochutla
# Processing Record 34 of Set 10 | sao lourenco do sul
# Processing Record 35 of Set 10 | itarema
# Processing Record 36 of Set 10 | saint-francois
# Processing Record 37 of Set 10 | agropoli
# Processing Record 38 of Set 10 | najran
# Processing Record 39 of Set 10 | dormidontovka
# Processing Record 40 of Set 10 | buon me thuot
# City not found. Skipping...
# Processing Record 41 of Set 10 | perepravnaya
# Processing Record 42 of Set 10 | caravelas
# Processing Record 43 of Set 10 | taksimo
# Processing Record 44 of Set 10 | mabaruma
# Processing Record 45 of Set 10 | maasin
# Processing Record 46 of Set 10 | alexandria
# Processing Record 47 of Set 10 | filadelfia
# Processing Record 48 of Set 10 | wagga wagga
# Processing Record 49 of Set 10 | srednekolymsk
# Processing Record 50 of Set 10 | turbat
# Processing Record 1 of Set 11 | haimen
# Processing Record 2 of Set 11 | bonavista
# Processing Record 3 of Set 11 | bodden town
# Processing Record 4 of Set 11 | bandarbeyla
# Processing Record 5 of Set 11 | vila velha
# Processing Record 6 of Set 11 | bairnsdale
# Processing Record 7 of Set 11 | paramonga
# Processing Record 8 of Set 11 | sibolga
# Processing Record 9 of Set 11 | clyde river
# Processing Record 10 of Set 11 | chatham
# Processing Record 11 of Set 11 | smithers
# Processing Record 12 of Set 11 | presidencia roque saenz pena
# Processing Record 13 of Set 11 | ilhabela
# Processing Record 14 of Set 11 | trapani
# Processing Record 15 of Set 11 | belle fourche
# Processing Record 16 of Set 11 | hudson bay
# Processing Record 17 of Set 11 | cockburn town
# Processing Record 18 of Set 11 | opaka
# Processing Record 19 of Set 11 | hinton
# Processing Record 20 of Set 11 | berezanskaya
# Processing Record 21 of Set 11 | san policarpo
# Processing Record 22 of Set 11 | ojinaga
# Processing Record 23 of Set 11 | baoqing
# Processing Record 24 of Set 11 | tapaua
# City not found. Skipping...
# Processing Record 25 of Set 11 | dali
# Processing Record 26 of Set 11 | usinsk
# Processing Record 27 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 28 of Set 11 | penzance
# Processing Record 29 of Set 11 | snezhnogorsk
# Processing Record 30 of Set 11 | bakhmach
# Processing Record 31 of Set 11 | omboue
# Processing Record 32 of Set 11 | malinovoye ozero
# Processing Record 33 of Set 11 | chegdomyn
# Processing Record 34 of Set 11 | san quintin
# Processing Record 35 of Set 11 | pagatin
# Processing Record 36 of Set 11 | leleasca
# Processing Record 37 of Set 11 | eldorado
# Processing Record 38 of Set 11 | semirom
# Processing Record 39 of Set 11 | krasnoselkup
# Processing Record 40 of Set 11 | jining
# Processing Record 41 of Set 11 | villanueva de la serena
# Processing Record 42 of Set 11 | kamina
# Processing Record 43 of Set 11 | namatanai
# Processing Record 44 of Set 11 | chaihe
# Processing Record 45 of Set 11 | debno
# Processing Record 46 of Set 11 | aklavik
# Processing Record 47 of Set 11 | mercedes
# Processing Record 48 of Set 11 | port blair
# Processing Record 49 of Set 11 | henties bay
# Processing Record 50 of Set 11 | raudeberg
# Processing Record 1 of Set 12 | taburao
# City not found. Skipping...
# Processing Record 2 of Set 12 | russellville
# Processing Record 3 of Set 12 | havoysund
# Processing Record 4 of Set 12 | atlantic beach
# Processing Record 5 of Set 12 | ankara
# Processing Record 6 of Set 12 | krasnyy kut
# Processing Record 7 of Set 12 | rock sound
# Processing Record 8 of Set 12 | waingapu
# Processing Record 9 of Set 12 | antofagasta
# Processing Record 10 of Set 12 | jalingo
# Processing Record 11 of Set 12 | linxia
# Processing Record 12 of Set 12 | aleksandrov gay
# Processing Record 13 of Set 12 | chikoy
# City not found. Skipping...
# Processing Record 14 of Set 12 | otradnoye
# Processing Record 15 of Set 12 | horodnytsya
# Processing Record 16 of Set 12 | tucuman
# Processing Record 17 of Set 12 | tautira
# Processing Record 18 of Set 12 | lata
# Processing Record 19 of Set 12 | houma
# Processing Record 20 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 21 of Set 12 | viking
# Processing Record 22 of Set 12 | kuah
# Processing Record 23 of Set 12 | luderitz
# Processing Record 24 of Set 12 | tual
# Processing Record 25 of Set 12 | dafeng
# Processing Record 26 of Set 12 | ponta delgada
# Processing Record 27 of Set 12 | mityana
# Processing Record 28 of Set 12 | bloemfontein
# Processing Record 29 of Set 12 | rotifunk
# Processing Record 30 of Set 12 | marzuq
# Processing Record 31 of Set 12 | carauari
# Processing Record 32 of Set 12 | graciano sanchez
# Processing Record 33 of Set 12 | sampit
# Processing Record 34 of Set 12 | ust-barguzin
# Processing Record 35 of Set 12 | ninh binh
# Processing Record 36 of Set 12 | vilhena
# Processing Record 37 of Set 12 | bryan
# Processing Record 38 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 12 | baruun-urt
# Processing Record 40 of Set 12 | andapa
# Processing Record 41 of Set 12 | rio sereno
# Processing Record 42 of Set 12 | salvador
# Processing Record 43 of Set 12 | beian
# Processing Record 44 of Set 12 | sungaipenuh
# Processing Record 45 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 12 | higuey
# City not found. Skipping...
# Processing Record 47 of Set 12 | dangriga
# Processing Record 48 of Set 12 | jinchang
# Processing Record 49 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 50 of Set 12 | ibanda
# Processing Record 1 of Set 13 | tagusao
# Processing Record 2 of Set 13 | altay
# Processing Record 3 of Set 13 | mount isa
# Processing Record 4 of Set 13 | alugan
# Processing Record 5 of Set 13 | urumqi
# Processing Record 6 of Set 13 | kijang
# Processing Record 7 of Set 13 | korla
# Processing Record 8 of Set 13 | jacareacanga
# Processing Record 9 of Set 13 | rupert
# Processing Record 10 of Set 13 | tura
# Processing Record 11 of Set 13 | egvekinot
# Processing Record 12 of Set 13 | pihuamo
# Processing Record 13 of Set 13 | stilfontein
# Processing Record 14 of Set 13 | blagoyevo
# Processing Record 15 of Set 13 | buenos aires
# Processing Record 16 of Set 13 | shache
# Processing Record 17 of Set 13 | bubaque
# Processing Record 18 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 13 | svatove
# Processing Record 20 of Set 13 | khasan
# Processing Record 21 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 22 of Set 13 | shibarghan
# City not found. Skipping...
# Processing Record 23 of Set 13 | mezhdurechensk
# Processing Record 24 of Set 13 | kokstad
# Processing Record 25 of Set 13 | peace river
# Processing Record 26 of Set 13 | netivot
# Processing Record 27 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 28 of Set 13 | shahr-e babak
# Processing Record 29 of Set 13 | tabriz
# Processing Record 30 of Set 13 | fort frances
# Processing Record 31 of Set 13 | gijon
# Processing Record 32 of Set 13 | koungou
# Processing Record 33 of Set 13 | tezu
# Processing Record 34 of Set 13 | malanje
# Processing Record 35 of Set 13 | amapa
# Processing Record 36 of Set 13 | lollar
# Processing Record 37 of Set 13 | wamba
# Processing Record 38 of Set 13 | vangaindrano
# Processing Record 39 of Set 13 | muros
# Processing Record 40 of Set 13 | port macquarie
# Processing Record 41 of Set 13 | bairiki
# Processing Record 42 of Set 13 | cabrero
# Processing Record 43 of Set 13 | ambilobe
# Processing Record 44 of Set 13 | mandalgovi
# Processing Record 45 of Set 13 | sadiqabad
# Processing Record 46 of Set 13 | winslow
# Processing Record 47 of Set 13 | carbonia
# Processing Record 48 of Set 13 | jamame
# Processing Record 49 of Set 13 | worgl
# Processing Record 50 of Set 13 | bataipora
# Processing Record 1 of Set 14 | los llanos de aridane
# Processing Record 2 of Set 14 | hervey bay
# Processing Record 3 of Set 14 | brownsville
# Processing Record 4 of Set 14 | puerto escondido
# Processing Record 5 of Set 14 | campbell river
# Processing Record 6 of Set 14 | maba
# Processing Record 7 of Set 14 | verkhnevilyuysk
# Processing Record 8 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 9 of Set 14 | severnoye
# Processing Record 10 of Set 14 | lapeer
# Processing Record 11 of Set 14 | kieta
# Processing Record 12 of Set 14 | ygatimi
# Processing Record 13 of Set 14 | roebourne
# Processing Record 14 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 14 | richards bay
# Processing Record 16 of Set 14 | asau
# Processing Record 17 of Set 14 | meulaboh
# Processing Record 18 of Set 14 | matara
# Processing Record 19 of Set 14 | saint combs
# City not found. Skipping...
# Processing Record 20 of Set 14 | yumen
# Processing Record 21 of Set 14 | santiago
# Processing Record 22 of Set 14 | port hardy
# Processing Record 23 of Set 14 | arman
# Processing Record 24 of Set 14 | la asuncion
# Processing Record 25 of Set 14 | nakama
# Processing Record 26 of Set 14 | kavieng
# Processing Record 27 of Set 14 | eskasem
# City not found. Skipping...
# Processing Record 28 of Set 14 | akdepe
# Processing Record 29 of Set 14 | ostrovnoy
# Processing Record 30 of Set 14 | northam
# Processing Record 31 of Set 14 | rio grande
# Processing Record 32 of Set 14 | abha
# Processing Record 33 of Set 14 | miquelon
# Processing Record 34 of Set 14 | roma
# Processing Record 35 of Set 14 | sinnamary
# Processing Record 36 of Set 14 | khani
# Processing Record 37 of Set 14 | gazanjyk
# Processing Record 38 of Set 14 | bac can
# City not found. Skipping...
# Processing Record 39 of Set 14 | jacqueville
# Processing Record 40 of Set 14 | sambava
# Processing Record 41 of Set 14 | gazli
# Processing Record 42 of Set 14 | akniste
# Processing Record 43 of Set 14 | balikpapan
# Processing Record 44 of Set 14 | nouadhibou
# Processing Record 45 of Set 14 | mazatlan
# Processing Record 46 of Set 14 | chiredzi
# Processing Record 47 of Set 14 | ilulissat
# Processing Record 48 of Set 14 | monrovia
# Processing Record 49 of Set 14 | kuching
# Processing Record 50 of Set 14 | mondlo
# Processing Record 1 of Set 15 | sassandra
# Processing Record 2 of Set 15 | beira
# Processing Record 3 of Set 15 | haftoni
# Processing Record 4 of Set 15 | farah
# Processing Record 5 of Set 15 | pecos
# Processing Record 6 of Set 15 | port keats
# Processing Record 7 of Set 15 | swellendam
# Processing Record 8 of Set 15 | south lake tahoe
# Processing Record 9 of Set 15 | bjornevatn
# Processing Record 10 of Set 15 | bandipur
# Processing Record 11 of Set 15 | khor
# Processing Record 12 of Set 15 | likasi
# Processing Record 13 of Set 15 | denia
# Processing Record 14 of Set 15 | el dorado
# Processing Record 15 of Set 15 | kilindoni
# Processing Record 16 of Set 15 | remedios
# Processing Record 17 of Set 15 | chavakkad
# Processing Record 18 of Set 15 | sayat
# Processing Record 19 of Set 15 | rockhampton
# Processing Record 20 of Set 15 | karratha
# Processing Record 21 of Set 15 | kalmunai
# Processing Record 22 of Set 15 | wajir
# Processing Record 23 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 24 of Set 15 | haapiti
# Processing Record 25 of Set 15 | prince rupert
# Processing Record 26 of Set 15 | hauterive
# Processing Record 27 of Set 15 | washington
# Processing Record 28 of Set 15 | padang
# Processing Record 29 of Set 15 | laguna
# Processing Record 30 of Set 15 | khorion
# City not found. Skipping...
# Processing Record 31 of Set 15 | riyadh
# Processing Record 32 of Set 15 | tucurui
# Processing Record 33 of Set 15 | senj
# Processing Record 34 of Set 15 | ada
# Processing Record 35 of Set 15 | halifax
# Processing Record 36 of Set 15 | sunds
# Processing Record 37 of Set 15 | kuryk
# Processing Record 38 of Set 15 | virginia beach
# Processing Record 39 of Set 15 | satellite beach
# Processing Record 40 of Set 15 | machaneng
# Processing Record 41 of Set 15 | tadine
# Processing Record 42 of Set 15 | benguela
# Processing Record 43 of Set 15 | ketchikan
# Processing Record 44 of Set 15 | mindelo
# Processing Record 45 of Set 15 | gap
# Processing Record 46 of Set 15 | cardonal
# Processing Record 47 of Set 15 | saint anthony
# Processing Record 48 of Set 15 | honningsvag
# Processing Record 49 of Set 15 | bagotville
# Processing Record 50 of Set 15 | bandrele
# Processing Record 1 of Set 16 | kulhudhuffushi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Get the number of the cities
len(city_data)
# Out:
# 686

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Kautokeino  69.0125   23.0412     52.00        74         100
# 1        Bolobo  -2.1667   16.2333     97.14        21          14
# 2     Cape Town -33.9258   18.4232     77.41        26           0
# 3        Hobart -42.8794  147.3294     50.92        81          75
# 4    Nikolskoye  59.7035   30.7861     82.29        27           7
# 5     Jamestown  42.0970  -79.2353     70.18        86          94
# 6        Avarua -21.2078 -159.7750     75.25        83          20
# 7        Atuona  -9.8000 -139.0333     77.32        75          23
# 8      Klaksvik  62.2266   -6.5890     52.72        85          10
# 9  Saint George  37.1041 -113.5841     85.35        47           1
#
#    Wind Speed Current Description Country                 Date
# 0       15.66          light rain      NO  2021-07-18 14:03:39
# 1        3.51          few clouds      CD  2021-07-18 14:03:39
# 2       18.41           clear sky      ZA  2021-07-18 13:58:44
# 3        1.99       broken clouds      AU  2021-07-18 14:00:27
# 4        9.17           clear sky      RU  2021-07-18 14:03:40
# 5        7.00     overcast clouds      US  2021-07-18 14:00:29
# 6        9.22          few clouds      CK  2021-07-18 14:03:40
# 7       28.74          few clouds      PF  2021-07-18 14:03:41
# 8        4.52           clear sky      FO  2021-07-18 14:03:41
# 9        4.61           clear sky      US  2021-07-18 14:00:38

# %%
#have a sytax error here  to fix still  
#Organize the columns in the DataFrame.
city_data__no_date_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']]
city_data__no_date_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Kautokeino      NO  69.0125   23.0412     52.00        74         100
# 1        Bolobo      CD  -2.1667   16.2333     97.14        21          14
# 2     Cape Town      ZA -33.9258   18.4232     77.41        26           0
# 3        Hobart      AU -42.8794  147.3294     50.92        81          75
# 4    Nikolskoye      RU  59.7035   30.7861     82.29        27           7
# 5     Jamestown      US  42.0970  -79.2353     70.18        86          94
# 6        Avarua      CK -21.2078 -159.7750     75.25        83          20
# 7        Atuona      PF  -9.8000 -139.0333     77.32        75          23
# 8      Klaksvik      FO  62.2266   -6.5890     52.72        85          10
# 9  Saint George      US  37.1041 -113.5841     85.35        47           1
#
#    Wind Speed Current Description
# 0       15.66          light rain
# 1        3.51          few clouds
# 2       18.41           clear sky
# 3        1.99       broken clouds
# 4        9.17           clear sky
# 5        7.00     overcast clouds
# 6        9.22          few clouds
# 7       28.74          few clouds
# 8        4.52           clear sky
# 9        4.61           clear sky

# %%
#make this active after sure I know where it's going and its' right  I have not run this yet. check with JUSTIn first
# Create and export the final Data Frame into a CSV
city_data__no_date_df.to_csv("WeatherPy_Database.csv", index_label="City_ID")

# %%
#csv files feeds into activity 2 and 3 - working well, and creating the db
