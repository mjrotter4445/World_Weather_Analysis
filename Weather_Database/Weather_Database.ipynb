# %%
#Challenge part 1 pull the l and l info make a place for cities, count em, 
#Start here with Justin

# Import the dependencies.
import pandas as pd
#import matplotlib.pyplot as plt
import numpy as np

#Use the citipy module to determine city based on latitude and longitude.
#%pip install citipy
from citipy import citipy

# %%
# Create a set of random 2000 latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

#Zipping the pairs in a tuple with zip() function.
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 739

# %%
#Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3a5c22543e7db7978b522be236b0a831'

# %%
#cut from starting mod 626
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list using enumerate function.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]['description']
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pozoblanco
# Processing Record 2 of Set 1 | manta
# Processing Record 3 of Set 1 | bandarbeyla
# Processing Record 4 of Set 1 | dawson creek
# Processing Record 5 of Set 1 | ternate
# Processing Record 6 of Set 1 | castro
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | lompoc
# Processing Record 10 of Set 1 | mahebourg
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | killarney
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | bone
# Processing Record 15 of Set 1 | bathsheba
# Processing Record 16 of Set 1 | baykit
# Processing Record 17 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 1 | ribeira grande
# Processing Record 19 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 1 | udachnyy
# Processing Record 21 of Set 1 | amapa
# Processing Record 22 of Set 1 | itarema
# Processing Record 23 of Set 1 | fayaoue
# Processing Record 24 of Set 1 | east london
# Processing Record 25 of Set 1 | taltal
# Processing Record 26 of Set 1 | asau
# Processing Record 27 of Set 1 | namtsy
# Processing Record 28 of Set 1 | peniche
# Processing Record 29 of Set 1 | cape town
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | barrow
# Processing Record 32 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 1 | cherskiy
# Processing Record 34 of Set 1 | awjilah
# Processing Record 35 of Set 1 | winnemucca
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | saint george
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 1 | thiadiaye
# Processing Record 43 of Set 1 | soligalich
# Processing Record 44 of Set 1 | kodiak
# Processing Record 45 of Set 1 | vicosa
# Processing Record 46 of Set 1 | artyk
# City not found. Skipping...
# Processing Record 47 of Set 1 | new norfolk
# Processing Record 48 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 49 of Set 1 | atuona
# Processing Record 50 of Set 1 | funadhoo
# Processing Record 1 of Set 2 | solnechnyy
# Processing Record 2 of Set 2 | hermanus
# Processing Record 3 of Set 2 | ushuaia
# Processing Record 4 of Set 2 | severo-kurilsk
# Processing Record 5 of Set 2 | ponta do sol
# Processing Record 6 of Set 2 | panacan
# Processing Record 7 of Set 2 | kapaa
# Processing Record 8 of Set 2 | rikitea
# Processing Record 9 of Set 2 | anadyr
# Processing Record 10 of Set 2 | dikson
# Processing Record 11 of Set 2 | puerto el triunfo
# Processing Record 12 of Set 2 | maarianhamina
# Processing Record 13 of Set 2 | mecca
# Processing Record 14 of Set 2 | parry sound
# Processing Record 15 of Set 2 | cabo san lucas
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | stryn
# Processing Record 18 of Set 2 | mezen
# Processing Record 19 of Set 2 | pacific grove
# Processing Record 20 of Set 2 | klaksvik
# Processing Record 21 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 2 | hithadhoo
# Processing Record 23 of Set 2 | mananara
# Processing Record 24 of Set 2 | kavaratti
# Processing Record 25 of Set 2 | hobart
# Processing Record 26 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 2 | san patricio
# Processing Record 29 of Set 2 | saba
# Processing Record 30 of Set 2 | airai
# Processing Record 31 of Set 2 | tiksi
# Processing Record 32 of Set 2 | port hedland
# Processing Record 33 of Set 2 | yellowknife
# Processing Record 34 of Set 2 | grande-riviere
# City not found. Skipping...
# Processing Record 35 of Set 2 | chumikan
# Processing Record 36 of Set 2 | isangel
# Processing Record 37 of Set 2 | vanimo
# Processing Record 38 of Set 2 | mount isa
# Processing Record 39 of Set 2 | moshenskoye
# Processing Record 40 of Set 2 | fort nelson
# Processing Record 41 of Set 2 | denpasar
# Processing Record 42 of Set 2 | san lorenzo
# Processing Record 43 of Set 2 | viedma
# Processing Record 44 of Set 2 | pombia
# Processing Record 45 of Set 2 | carnarvon
# Processing Record 46 of Set 2 | mastung
# Processing Record 47 of Set 2 | port elizabeth
# Processing Record 48 of Set 2 | bethel
# Processing Record 49 of Set 2 | muzhi
# Processing Record 50 of Set 2 | touros
# Processing Record 1 of Set 3 | kholodnyy
# Processing Record 2 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 3 | sistranda
# Processing Record 4 of Set 3 | bubaque
# Processing Record 5 of Set 3 | chokurdakh
# Processing Record 6 of Set 3 | hami
# Processing Record 7 of Set 3 | kaitangata
# Processing Record 8 of Set 3 | victoria
# Processing Record 9 of Set 3 | pisco
# Processing Record 10 of Set 3 | batemans bay
# Processing Record 11 of Set 3 | xinqing
# Processing Record 12 of Set 3 | huarmey
# Processing Record 13 of Set 3 | shingu
# Processing Record 14 of Set 3 | avarua
# Processing Record 15 of Set 3 | arraial do cabo
# Processing Record 16 of Set 3 | bosaso
# Processing Record 17 of Set 3 | sinnamary
# Processing Record 18 of Set 3 | chuy
# Processing Record 19 of Set 3 | khatanga
# Processing Record 20 of Set 3 | nautla
# Processing Record 21 of Set 3 | lebu
# Processing Record 22 of Set 3 | havelock
# Processing Record 23 of Set 3 | abbeville
# Processing Record 24 of Set 3 | carutapera
# Processing Record 25 of Set 3 | mocorito
# Processing Record 26 of Set 3 | tasiilaq
# Processing Record 27 of Set 3 | muli
# Processing Record 28 of Set 3 | champerico
# Processing Record 29 of Set 3 | hilo
# Processing Record 30 of Set 3 | lorengau
# Processing Record 31 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 3 | hegra
# Processing Record 33 of Set 3 | namatanai
# Processing Record 34 of Set 3 | bundaberg
# Processing Record 35 of Set 3 | saskylakh
# Processing Record 36 of Set 3 | georgetown
# Processing Record 37 of Set 3 | jahazpur
# Processing Record 38 of Set 3 | lara
# Processing Record 39 of Set 3 | pundaguitan
# Processing Record 40 of Set 3 | miesbach
# Processing Record 41 of Set 3 | port lincoln
# Processing Record 42 of Set 3 | santa cruz de tenerife
# Processing Record 43 of Set 3 | beloha
# Processing Record 44 of Set 3 | puerto ayora
# Processing Record 45 of Set 3 | namibe
# Processing Record 46 of Set 3 | ancud
# Processing Record 47 of Set 3 | novaya zaimka
# Processing Record 48 of Set 3 | amurzet
# Processing Record 49 of Set 3 | itirucu
# Processing Record 50 of Set 3 | esperance
# Processing Record 1 of Set 4 | nanortalik
# Processing Record 2 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 4 | porto santo
# Processing Record 4 of Set 4 | saint-philippe
# Processing Record 5 of Set 4 | simao
# Processing Record 6 of Set 4 | emba
# Processing Record 7 of Set 4 | hasaki
# Processing Record 8 of Set 4 | nanpara
# Processing Record 9 of Set 4 | mount gambier
# Processing Record 10 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 4 | adrar
# Processing Record 12 of Set 4 | luoyang
# Processing Record 13 of Set 4 | bengkulu
# Processing Record 14 of Set 4 | bredasdorp
# Processing Record 15 of Set 4 | inirida
# Processing Record 16 of Set 4 | sept-iles
# Processing Record 17 of Set 4 | bambous virieux
# Processing Record 18 of Set 4 | soe
# Processing Record 19 of Set 4 | loncoche
# Processing Record 20 of Set 4 | camana
# Processing Record 21 of Set 4 | houma
# Processing Record 22 of Set 4 | fortuna
# Processing Record 23 of Set 4 | polunochnoye
# Processing Record 24 of Set 4 | kathmandu
# Processing Record 25 of Set 4 | half moon bay
# Processing Record 26 of Set 4 | mackenzie
# Processing Record 27 of Set 4 | iranshahr
# Processing Record 28 of Set 4 | verkhnyaya inta
# Processing Record 29 of Set 4 | komsomolskiy
# Processing Record 30 of Set 4 | cascavel
# Processing Record 31 of Set 4 | laguna
# Processing Record 32 of Set 4 | sao joao da barra
# Processing Record 33 of Set 4 | norman wells
# Processing Record 34 of Set 4 | provideniya
# Processing Record 35 of Set 4 | muravlenko
# Processing Record 36 of Set 4 | qaanaaq
# Processing Record 37 of Set 4 | samarai
# Processing Record 38 of Set 4 | astoria
# Processing Record 39 of Set 4 | porosozero
# Processing Record 40 of Set 4 | tuktoyaktuk
# Processing Record 41 of Set 4 | turukhansk
# Processing Record 42 of Set 4 | ishigaki
# Processing Record 43 of Set 4 | upernavik
# Processing Record 44 of Set 4 | thompson
# Processing Record 45 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 46 of Set 4 | kailua
# Processing Record 47 of Set 4 | yerbogachen
# Processing Record 48 of Set 4 | vao
# Processing Record 49 of Set 4 | tavricheskoye
# Processing Record 50 of Set 4 | azacualpa
# Processing Record 1 of Set 5 | umea
# Processing Record 2 of Set 5 | changli
# Processing Record 3 of Set 5 | shahr-e babak
# Processing Record 4 of Set 5 | alghero
# Processing Record 5 of Set 5 | aksarka
# Processing Record 6 of Set 5 | batagay
# Processing Record 7 of Set 5 | marapanim
# Processing Record 8 of Set 5 | talara
# Processing Record 9 of Set 5 | salalah
# Processing Record 10 of Set 5 | svobodnyy
# Processing Record 11 of Set 5 | cheremkhovo
# Processing Record 12 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 13 of Set 5 | katsuura
# Processing Record 14 of Set 5 | tuatapere
# Processing Record 15 of Set 5 | rocha
# Processing Record 16 of Set 5 | san policarpo
# Processing Record 17 of Set 5 | luderitz
# Processing Record 18 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 5 | boende
# Processing Record 20 of Set 5 | mar del plata
# Processing Record 21 of Set 5 | lacey
# Processing Record 22 of Set 5 | leshukonskoye
# Processing Record 23 of Set 5 | valle de allende
# Processing Record 24 of Set 5 | eyl
# Processing Record 25 of Set 5 | longyearbyen
# Processing Record 26 of Set 5 | naze
# Processing Record 27 of Set 5 | mayo
# Processing Record 28 of Set 5 | okhotsk
# Processing Record 29 of Set 5 | post falls
# Processing Record 30 of Set 5 | tautira
# Processing Record 31 of Set 5 | gariaband
# Processing Record 32 of Set 5 | angangxi
# City not found. Skipping...
# Processing Record 33 of Set 5 | margate
# Processing Record 34 of Set 5 | constitucion
# Processing Record 35 of Set 5 | mizdah
# Processing Record 36 of Set 5 | grindavik
# Processing Record 37 of Set 5 | arlit
# Processing Record 38 of Set 5 | cidreira
# Processing Record 39 of Set 5 | cayenne
# Processing Record 40 of Set 5 | praia
# Processing Record 41 of Set 5 | florencia
# Processing Record 42 of Set 5 | christiansburg
# Processing Record 43 of Set 5 | formosa do rio preto
# Processing Record 44 of Set 5 | raudeberg
# Processing Record 45 of Set 5 | buraydah
# Processing Record 46 of Set 5 | hamilton
# Processing Record 47 of Set 5 | kavieng
# Processing Record 48 of Set 5 | haines junction
# Processing Record 49 of Set 5 | ambilobe
# Processing Record 50 of Set 5 | faanui
# Processing Record 1 of Set 6 | gaurnadi
# Processing Record 2 of Set 6 | vega de alatorre
# Processing Record 3 of Set 6 | rohnert park
# Processing Record 4 of Set 6 | atar
# Processing Record 5 of Set 6 | araouane
# Processing Record 6 of Set 6 | natal
# Processing Record 7 of Set 6 | husavik
# Processing Record 8 of Set 6 | golden
# Processing Record 9 of Set 6 | inuvik
# Processing Record 10 of Set 6 | cochrane
# Processing Record 11 of Set 6 | ankara
# Processing Record 12 of Set 6 | pitsunda
# Processing Record 13 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 6 | bitung
# Processing Record 15 of Set 6 | narsaq
# Processing Record 16 of Set 6 | padang
# Processing Record 17 of Set 6 | manggar
# Processing Record 18 of Set 6 | akureyri
# Processing Record 19 of Set 6 | samana
# Processing Record 20 of Set 6 | berlevag
# Processing Record 21 of Set 6 | soyo
# Processing Record 22 of Set 6 | chifeng
# Processing Record 23 of Set 6 | kalmunai
# Processing Record 24 of Set 6 | kilindoni
# Processing Record 25 of Set 6 | bad liebenwerda
# Processing Record 26 of Set 6 | harper
# Processing Record 27 of Set 6 | zhigansk
# Processing Record 28 of Set 6 | coro
# Processing Record 29 of Set 6 | kamskiye polyany
# Processing Record 30 of Set 6 | zyryanka
# Processing Record 31 of Set 6 | robertsport
# Processing Record 32 of Set 6 | moerai
# Processing Record 33 of Set 6 | nemuro
# Processing Record 34 of Set 6 | alta floresta
# Processing Record 35 of Set 6 | gigmoto
# Processing Record 36 of Set 6 | necochea
# Processing Record 37 of Set 6 | nabire
# Processing Record 38 of Set 6 | quimper
# Processing Record 39 of Set 6 | ravar
# Processing Record 40 of Set 6 | linguere
# Processing Record 41 of Set 6 | saint-francois
# Processing Record 42 of Set 6 | angra
# City not found. Skipping...
# Processing Record 43 of Set 6 | libreville
# Processing Record 44 of Set 6 | krasnoselkup
# Processing Record 45 of Set 6 | dinguiraye
# Processing Record 46 of Set 6 | jumla
# Processing Record 47 of Set 6 | point pedro
# Processing Record 48 of Set 6 | sakakah
# Processing Record 49 of Set 6 | kuandian
# Processing Record 50 of Set 6 | bocas del toro
# Processing Record 1 of Set 7 | sao miguel do araguaia
# Processing Record 2 of Set 7 | leningradskiy
# Processing Record 3 of Set 7 | imeni poliny osipenko
# Processing Record 4 of Set 7 | calvinia
# Processing Record 5 of Set 7 | pevek
# Processing Record 6 of Set 7 | petrozavodsk
# Processing Record 7 of Set 7 | belur
# Processing Record 8 of Set 7 | yako
# Processing Record 9 of Set 7 | belluno
# Processing Record 10 of Set 7 | kuytun
# Processing Record 11 of Set 7 | ambatondrazaka
# Processing Record 12 of Set 7 | deep river
# Processing Record 13 of Set 7 | churumuco
# City not found. Skipping...
# Processing Record 14 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 7 | cognac
# Processing Record 16 of Set 7 | sri aman
# Processing Record 17 of Set 7 | yenagoa
# Processing Record 18 of Set 7 | fenoarivo
# Processing Record 19 of Set 7 | kardla
# Processing Record 20 of Set 7 | huaral
# Processing Record 21 of Set 7 | lander
# Processing Record 22 of Set 7 | krasnoarmeysk
# Processing Record 23 of Set 7 | severnoye
# Processing Record 24 of Set 7 | mackay
# Processing Record 25 of Set 7 | jacqueville
# Processing Record 26 of Set 7 | berdigestyakh
# Processing Record 27 of Set 7 | turbiv
# Processing Record 28 of Set 7 | minudasht
# Processing Record 29 of Set 7 | altay
# Processing Record 30 of Set 7 | straumen
# Processing Record 31 of Set 7 | mangrol
# Processing Record 32 of Set 7 | lagunas
# Processing Record 33 of Set 7 | san juan de abajo
# Processing Record 34 of Set 7 | ust-ishim
# Processing Record 35 of Set 7 | presidencia roque saenz pena
# Processing Record 36 of Set 7 | erdaojiang
# Processing Record 37 of Set 7 | mahibadhoo
# Processing Record 38 of Set 7 | suluktu
# Processing Record 39 of Set 7 | balkhash
# Processing Record 40 of Set 7 | beringovskiy
# Processing Record 41 of Set 7 | cockburn town
# Processing Record 42 of Set 7 | dragomiresti
# Processing Record 43 of Set 7 | conde
# Processing Record 44 of Set 7 | geraldton
# Processing Record 45 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 46 of Set 7 | iqaluit
# Processing Record 47 of Set 7 | pangkalanbuun
# Processing Record 48 of Set 7 | koygorodok
# Processing Record 49 of Set 7 | ostrovnoy
# Processing Record 50 of Set 7 | mgandu
# Processing Record 1 of Set 8 | mankono
# Processing Record 2 of Set 8 | clyde river
# Processing Record 3 of Set 8 | klyuchi
# Processing Record 4 of Set 8 | polaniec
# Processing Record 5 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 8 | ilulissat
# Processing Record 7 of Set 8 | lasa
# Processing Record 8 of Set 8 | codrington
# Processing Record 9 of Set 8 | paamiut
# Processing Record 10 of Set 8 | tocopilla
# Processing Record 11 of Set 8 | fairbanks
# Processing Record 12 of Set 8 | valleyview
# Processing Record 13 of Set 8 | bonavista
# Processing Record 14 of Set 8 | ahumada
# City not found. Skipping...
# Processing Record 15 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 17 of Set 8 | souillac
# Processing Record 18 of Set 8 | torbay
# Processing Record 19 of Set 8 | fereydunshahr
# Processing Record 20 of Set 8 | abalak
# Processing Record 21 of Set 8 | geelong
# Processing Record 22 of Set 8 | kruisfontein
# Processing Record 23 of Set 8 | axim
# Processing Record 24 of Set 8 | nishihara
# Processing Record 25 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 26 of Set 8 | buta
# Processing Record 27 of Set 8 | alofi
# Processing Record 28 of Set 8 | cidahu
# Processing Record 29 of Set 8 | duluth
# Processing Record 30 of Set 8 | veraval
# Processing Record 31 of Set 8 | coquimbo
# Processing Record 32 of Set 8 | hadejia
# Processing Record 33 of Set 8 | bhag
# Processing Record 34 of Set 8 | puerto escondido
# Processing Record 35 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 8 | sao felix do xingu
# Processing Record 37 of Set 8 | mehamn
# Processing Record 38 of Set 8 | sisimiut
# Processing Record 39 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 40 of Set 8 | turhal
# Processing Record 41 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 42 of Set 8 | aquiraz
# Processing Record 43 of Set 8 | vryburg
# Processing Record 44 of Set 8 | salinopolis
# Processing Record 45 of Set 8 | raton
# Processing Record 46 of Set 8 | onalaska
# Processing Record 47 of Set 8 | cedar city
# Processing Record 48 of Set 8 | port hardy
# Processing Record 49 of Set 8 | aklavik
# Processing Record 50 of Set 8 | royal tunbridge wells
# Processing Record 1 of Set 9 | lazaro cardenas
# Processing Record 2 of Set 9 | grants
# Processing Record 3 of Set 9 | mareeba
# Processing Record 4 of Set 9 | tongren
# Processing Record 5 of Set 9 | jalu
# Processing Record 6 of Set 9 | tura
# Processing Record 7 of Set 9 | poya
# Processing Record 8 of Set 9 | sangar
# Processing Record 9 of Set 9 | prince rupert
# Processing Record 10 of Set 9 | churapcha
# Processing Record 11 of Set 9 | helena
# Processing Record 12 of Set 9 | tarata
# Processing Record 13 of Set 9 | fomboni
# Processing Record 14 of Set 9 | san quintin
# Processing Record 15 of Set 9 | kushima
# Processing Record 16 of Set 9 | surt
# Processing Record 17 of Set 9 | manga
# Processing Record 18 of Set 9 | nikolskoye
# Processing Record 19 of Set 9 | puerto madryn
# Processing Record 20 of Set 9 | ketchikan
# Processing Record 21 of Set 9 | gat
# Processing Record 22 of Set 9 | yima
# Processing Record 23 of Set 9 | saint anthony
# Processing Record 24 of Set 9 | machilipatnam
# Processing Record 25 of Set 9 | naberera
# Processing Record 26 of Set 9 | tonj
# Processing Record 27 of Set 9 | santa isabel do rio negro
# Processing Record 28 of Set 9 | gold coast
# Processing Record 29 of Set 9 | karakol
# Processing Record 30 of Set 9 | iringa
# Processing Record 31 of Set 9 | zalantun
# Processing Record 32 of Set 9 | madison
# Processing Record 33 of Set 9 | ilinskiy
# Processing Record 34 of Set 9 | nhamunda
# Processing Record 35 of Set 9 | huaicheng
# Processing Record 36 of Set 9 | brazzaville
# Processing Record 37 of Set 9 | thano bula khan
# City not found. Skipping...
# Processing Record 38 of Set 9 | hailin
# Processing Record 39 of Set 9 | san javier
# Processing Record 40 of Set 9 | mao
# Processing Record 41 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 42 of Set 9 | kununurra
# Processing Record 43 of Set 9 | coahuayana
# Processing Record 44 of Set 9 | xiamen
# Processing Record 45 of Set 9 | othonoi
# City not found. Skipping...
# Processing Record 46 of Set 9 | waingapu
# Processing Record 47 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 9 | mizan teferi
# Processing Record 49 of Set 9 | bria
# Processing Record 50 of Set 9 | chapeco
# Processing Record 1 of Set 10 | nome
# Processing Record 2 of Set 10 | mingguang
# Processing Record 3 of Set 10 | mikhaylovka
# Processing Record 4 of Set 10 | saurimo
# Processing Record 5 of Set 10 | tabou
# Processing Record 6 of Set 10 | dingle
# Processing Record 7 of Set 10 | pareora
# Processing Record 8 of Set 10 | nazas
# Processing Record 9 of Set 10 | deer lake
# Processing Record 10 of Set 10 | muros
# Processing Record 11 of Set 10 | changying
# Processing Record 12 of Set 10 | tiznit
# Processing Record 13 of Set 10 | katangli
# Processing Record 14 of Set 10 | wanning
# Processing Record 15 of Set 10 | tangzhai
# Processing Record 16 of Set 10 | horsham
# Processing Record 17 of Set 10 | rawson
# Processing Record 18 of Set 10 | merrill
# Processing Record 19 of Set 10 | college
# Processing Record 20 of Set 10 | chimoio
# Processing Record 21 of Set 10 | pangnirtung
# Processing Record 22 of Set 10 | makat
# Processing Record 23 of Set 10 | hranice
# Processing Record 24 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 25 of Set 10 | marathon
# Processing Record 26 of Set 10 | alice springs
# Processing Record 27 of Set 10 | belaya gora
# Processing Record 28 of Set 10 | vargem alta
# Processing Record 29 of Set 10 | skeldon
# Processing Record 30 of Set 10 | aranos
# Processing Record 31 of Set 10 | bossangoa
# Processing Record 32 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 10 | taihe
# Processing Record 34 of Set 10 | port augusta
# Processing Record 35 of Set 10 | santa luzia
# Processing Record 36 of Set 10 | barentu
# Processing Record 37 of Set 10 | batamshinskiy
# Processing Record 38 of Set 10 | hetauda
# Processing Record 39 of Set 10 | andarab
# City not found. Skipping...
# Processing Record 40 of Set 10 | kemin
# Processing Record 41 of Set 10 | ahipara
# Processing Record 42 of Set 10 | cabo rojo
# Processing Record 43 of Set 10 | pathein
# Processing Record 44 of Set 10 | yichang
# Processing Record 45 of Set 10 | roald
# Processing Record 46 of Set 10 | ilheus
# Processing Record 47 of Set 10 | sanford
# Processing Record 48 of Set 10 | yar-sale
# Processing Record 49 of Set 10 | ulan-ude
# Processing Record 50 of Set 10 | progreso
# Processing Record 1 of Set 11 | shymkent
# Processing Record 2 of Set 11 | ivanjica
# Processing Record 3 of Set 11 | canutama
# Processing Record 4 of Set 11 | la presa
# Processing Record 5 of Set 11 | atlantic beach
# Processing Record 6 of Set 11 | mullaitivu
# City not found. Skipping...
# Processing Record 7 of Set 11 | nago
# Processing Record 8 of Set 11 | hualmay
# Processing Record 9 of Set 11 | tanout
# Processing Record 10 of Set 11 | rancho palos verdes
# Processing Record 11 of Set 11 | bilibino
# Processing Record 12 of Set 11 | nouadhibou
# Processing Record 13 of Set 11 | panguiranan
# Processing Record 14 of Set 11 | caravelas
# Processing Record 15 of Set 11 | dumas
# Processing Record 16 of Set 11 | warrington
# Processing Record 17 of Set 11 | carroll
# Processing Record 18 of Set 11 | santa fe
# Processing Record 19 of Set 11 | cabinda
# Processing Record 20 of Set 11 | quatre cocos
# Processing Record 21 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 22 of Set 11 | hovd
# Processing Record 23 of Set 11 | malampaka
# Processing Record 24 of Set 11 | poltsamaa
# Processing Record 25 of Set 11 | lata
# Processing Record 26 of Set 11 | kashmor
# Processing Record 27 of Set 11 | bandiagara
# Processing Record 28 of Set 11 | puri
# Processing Record 29 of Set 11 | wajid
# Processing Record 30 of Set 11 | ntoum
# Processing Record 31 of Set 11 | katobu
# Processing Record 32 of Set 11 | pringsewu
# Processing Record 33 of Set 11 | umm lajj
# Processing Record 34 of Set 11 | karratha
# Processing Record 35 of Set 11 | sur
# Processing Record 36 of Set 11 | vardo
# Processing Record 37 of Set 11 | djambala
# Processing Record 38 of Set 11 | mogadishu
# Processing Record 39 of Set 11 | myra
# Processing Record 40 of Set 11 | maceio
# Processing Record 41 of Set 11 | mimongo
# Processing Record 42 of Set 11 | north platte
# Processing Record 43 of Set 11 | qaqortoq
# Processing Record 44 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 45 of Set 11 | agadir
# Processing Record 46 of Set 11 | port-gentil
# Processing Record 47 of Set 11 | eqbaliyeh
# Processing Record 48 of Set 11 | bodden town
# Processing Record 49 of Set 11 | astana
# Processing Record 50 of Set 11 | uromi
# Processing Record 1 of Set 12 | san juan del sur
# Processing Record 2 of Set 12 | nyazepetrovsk
# Processing Record 3 of Set 12 | general escobedo
# Processing Record 4 of Set 12 | yumen
# Processing Record 5 of Set 12 | terrace
# Processing Record 6 of Set 12 | marathopolis
# City not found. Skipping...
# Processing Record 7 of Set 12 | malanje
# Processing Record 8 of Set 12 | comodoro rivadavia
# Processing Record 9 of Set 12 | evensk
# Processing Record 10 of Set 12 | sampit
# Processing Record 11 of Set 12 | xunchang
# Processing Record 12 of Set 12 | talnakh
# Processing Record 13 of Set 12 | maragogi
# Processing Record 14 of Set 12 | vila
# Processing Record 15 of Set 12 | zhicheng
# Processing Record 16 of Set 12 | mariakani
# Processing Record 17 of Set 12 | saint-joseph
# Processing Record 18 of Set 12 | muscat
# Processing Record 19 of Set 12 | kizema
# Processing Record 20 of Set 12 | jacareacanga
# Processing Record 21 of Set 12 | faya
# Processing Record 22 of Set 12 | nyurba
# Processing Record 23 of Set 12 | itacurubi del rosario
# Processing Record 24 of Set 12 | zhangye
# Processing Record 25 of Set 12 | kerman
# Processing Record 26 of Set 12 | volchansk
# Processing Record 27 of Set 12 | palu
# Processing Record 28 of Set 12 | arkhara
# Processing Record 29 of Set 12 | luwuk
# Processing Record 30 of Set 12 | kuah
# Processing Record 31 of Set 12 | walvis bay
# Processing Record 32 of Set 12 | oytal
# Processing Record 33 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 12 | maniitsoq
# Processing Record 35 of Set 12 | warragul
# Processing Record 36 of Set 12 | vila franca do campo
# Processing Record 37 of Set 12 | antananarivo
# Processing Record 38 of Set 12 | teneguiban
# City not found. Skipping...
# Processing Record 39 of Set 12 | tres arroyos
# Processing Record 40 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 41 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 42 of Set 12 | skjervoy
# Processing Record 43 of Set 12 | boke
# Processing Record 44 of Set 12 | orlovskiy
# Processing Record 45 of Set 12 | diapaga
# Processing Record 46 of Set 12 | rabaul
# Processing Record 47 of Set 12 | freeport
# Processing Record 48 of Set 12 | bezopasnoye
# Processing Record 49 of Set 12 | ukiah
# Processing Record 50 of Set 12 | alassio
# Processing Record 1 of Set 13 | meulaboh
# Processing Record 2 of Set 13 | awbari
# Processing Record 3 of Set 13 | foix
# Processing Record 4 of Set 13 | te anau
# Processing Record 5 of Set 13 | barranca
# Processing Record 6 of Set 13 | tashigang
# Processing Record 7 of Set 13 | wajir
# Processing Record 8 of Set 13 | thai binh
# Processing Record 9 of Set 13 | derzhavinsk
# Processing Record 10 of Set 13 | kokopo
# Processing Record 11 of Set 13 | rulenge
# Processing Record 12 of Set 13 | kieta
# Processing Record 13 of Set 13 | culebra
# Processing Record 14 of Set 13 | quezon
# Processing Record 15 of Set 13 | parrita
# Processing Record 16 of Set 13 | waitati
# Processing Record 17 of Set 13 | plouzane
# Processing Record 18 of Set 13 | wysokie mazowieckie
# Processing Record 19 of Set 13 | cururupu
# Processing Record 20 of Set 13 | booue
# Processing Record 21 of Set 13 | zafra
# Processing Record 22 of Set 13 | conceicao do araguaia
# Processing Record 23 of Set 13 | ponta delgada
# Processing Record 24 of Set 13 | macau
# Processing Record 25 of Set 13 | kuusankoski
# Processing Record 26 of Set 13 | sidrolandia
# Processing Record 27 of Set 13 | marsa matruh
# Processing Record 28 of Set 13 | moron
# Processing Record 29 of Set 13 | la ronge
# Processing Record 30 of Set 13 | arkhangelos
# City not found. Skipping...
# Processing Record 31 of Set 13 | humberto de campos
# Processing Record 32 of Set 13 | joshimath
# Processing Record 33 of Set 13 | dunedin
# Processing Record 34 of Set 13 | barra do garcas
# Processing Record 35 of Set 13 | banjarmasin
# Processing Record 36 of Set 13 | suisun city
# Processing Record 37 of Set 13 | wangdiphodrang
# City not found. Skipping...
# Processing Record 38 of Set 13 | malmesbury
# Processing Record 39 of Set 13 | miri
# Processing Record 40 of Set 13 | saint-paul
# Processing Record 41 of Set 13 | toora-khem
# Processing Record 42 of Set 13 | mukhen
# Processing Record 43 of Set 13 | mango
# Processing Record 44 of Set 13 | kalininsk
# Processing Record 45 of Set 13 | ndjole
# Processing Record 46 of Set 13 | vigrestad
# Processing Record 47 of Set 13 | vestmannaeyjar
# Processing Record 48 of Set 13 | lewistown
# Processing Record 49 of Set 13 | itupiranga
# Processing Record 50 of Set 13 | marienburg
# Processing Record 1 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 14 | camacupa
# Processing Record 3 of Set 14 | lufilufi
# Processing Record 4 of Set 14 | kousseri
# Processing Record 5 of Set 14 | troitsko-pechorsk
# Processing Record 6 of Set 14 | samut songkhram
# Processing Record 7 of Set 14 | bereda
# Processing Record 8 of Set 14 | peleduy
# Processing Record 9 of Set 14 | bamiantong
# Processing Record 10 of Set 14 | lagoa
# Processing Record 11 of Set 14 | ati
# Processing Record 12 of Set 14 | flinders
# Processing Record 13 of Set 14 | praya
# Processing Record 14 of Set 14 | pitea
# Processing Record 15 of Set 14 | bhatkal
# Processing Record 16 of Set 14 | buenaventura
# Processing Record 17 of Set 14 | pemangkat
# Processing Record 18 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 19 of Set 14 | nanzhou
# Processing Record 20 of Set 14 | gazanjyk
# Processing Record 21 of Set 14 | kaeo
# Processing Record 22 of Set 14 | garoua
# Processing Record 23 of Set 14 | sola
# Processing Record 24 of Set 14 | enfield
# Processing Record 25 of Set 14 | jujuy
# City not found. Skipping...
# Processing Record 26 of Set 14 | tchollire
# Processing Record 27 of Set 14 | skaerbaek
# Processing Record 28 of Set 14 | broome
# Processing Record 29 of Set 14 | yonago
# Processing Record 30 of Set 14 | chandbali
# Processing Record 31 of Set 14 | grants pass
# Processing Record 32 of Set 14 | nizwa
# Processing Record 33 of Set 14 | saldanha
# Processing Record 34 of Set 14 | ust-ilimsk
# Processing Record 35 of Set 14 | bali chak
# Processing Record 36 of Set 14 | hofn
# Processing Record 37 of Set 14 | santa rosa
# Processing Record 38 of Set 14 | korla
# Processing Record 39 of Set 14 | fernie
# Processing Record 40 of Set 14 | vondrozo
# Processing Record 41 of Set 14 | jardim
# Processing Record 42 of Set 14 | hammond
# Processing Record 43 of Set 14 | omboue
# Processing Record 44 of Set 14 | pullman
# Processing Record 45 of Set 14 | san cristobal
# Processing Record 46 of Set 14 | thanh hoa
# Processing Record 47 of Set 14 | caucaia
# Processing Record 48 of Set 14 | cruzeiro do sul
# Processing Record 49 of Set 14 | kabompo
# Processing Record 50 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 1 of Set 15 | toguchin
# Processing Record 2 of Set 15 | el tigre
# Processing Record 3 of Set 15 | labuhan
# Processing Record 4 of Set 15 | the valley
# Processing Record 5 of Set 15 | egvekinot
# Processing Record 6 of Set 15 | olafsvik
# Processing Record 7 of Set 15 | vendas novas
# Processing Record 8 of Set 15 | tazovskiy
# Processing Record 9 of Set 15 | shaker heights
# Processing Record 10 of Set 15 | vershino-shakhtaminskiy
# Processing Record 11 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 12 of Set 15 | tubuala
# Processing Record 13 of Set 15 | bolitoc
# Processing Record 14 of Set 15 | fort saint james
# Processing Record 15 of Set 15 | gasa
# Processing Record 16 of Set 15 | saint-louis
# Processing Record 17 of Set 15 | san juan
# Processing Record 18 of Set 15 | susanville
# Processing Record 19 of Set 15 | pozo colorado
# Processing Record 20 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 21 of Set 15 | westport
# Processing Record 22 of Set 15 | carnot
# Processing Record 23 of Set 15 | lock haven
# Processing Record 24 of Set 15 | monrovia
# Processing Record 25 of Set 15 | tel mond
# Processing Record 26 of Set 15 | martapura
# Processing Record 27 of Set 15 | great yarmouth
# Processing Record 28 of Set 15 | lingao
# Processing Record 29 of Set 15 | konskie
# Processing Record 30 of Set 15 | safaga
# Processing Record 31 of Set 15 | abdanan
# Processing Record 32 of Set 15 | abu samrah
# Processing Record 33 of Set 15 | eureka
# Processing Record 34 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 35 of Set 15 | le port
# Processing Record 36 of Set 15 | roebourne
# Processing Record 37 of Set 15 | sibu
# Processing Record 38 of Set 15 | alamogordo
# Processing Record 39 of Set 15 | arequipa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Get the number of the cities
len(city_data)
# Out:
# 683

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Pozoblanco  38.3791   -4.8483     82.98        20           0
# 1         Manta  -0.9500  -80.7333     76.50        75          98
# 2   Bandarbeyla   9.4942   50.8122     76.82        84         100
# 3  Dawson Creek  55.7666 -120.2362     51.10        95         100
# 4       Ternate   0.8000  127.4000     79.70        78         100
# 5        Castro -24.7911  -50.0119     48.31        53           0
# 6   Port Alfred -33.5906   26.8910     61.66        59           0
# 7     Jamestown  42.0970  -79.2353     78.12        65           1
# 8        Lompoc  34.6391 -120.4579     87.01        79           1
# 9     Mahebourg -20.4081   57.7000     71.26        64           2
#
#    Wind Speed Current Description Country                 Date
# 0        6.02           clear sky      ES  2021-07-18 20:07:52
# 1       10.83     overcast clouds      EC  2021-07-18 20:07:09
# 2       29.37     overcast clouds      SO  2021-07-18 20:07:52
# 3        4.47     overcast clouds      CA  2021-07-18 20:07:53
# 4        4.38       moderate rain      ID  2021-07-18 20:07:53
# 5       10.40           clear sky      BR  2021-07-18 20:07:53
# 6       11.81           clear sky      ZA  2021-07-18 20:07:54
# 7        4.00           clear sky      US  2021-07-18 20:07:54
# 8       11.50           clear sky      US  2021-07-18 20:07:54
# 9       15.37           clear sky      MU  2021-07-18 20:07:55

# %%
#have a sytax error here  to fix still  
#Organize the columns in the DataFrame.
city_data__no_date_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']]
city_data__no_date_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Pozoblanco      ES  38.3791   -4.8483     82.98        20           0
# 1         Manta      EC  -0.9500  -80.7333     76.50        75          98
# 2   Bandarbeyla      SO   9.4942   50.8122     76.82        84         100
# 3  Dawson Creek      CA  55.7666 -120.2362     51.10        95         100
# 4       Ternate      ID   0.8000  127.4000     79.70        78         100
# 5        Castro      BR -24.7911  -50.0119     48.31        53           0
# 6   Port Alfred      ZA -33.5906   26.8910     61.66        59           0
# 7     Jamestown      US  42.0970  -79.2353     78.12        65           1
# 8        Lompoc      US  34.6391 -120.4579     87.01        79           1
# 9     Mahebourg      MU -20.4081   57.7000     71.26        64           2
#
#    Wind Speed Current Description
# 0        6.02           clear sky
# 1       10.83     overcast clouds
# 2       29.37     overcast clouds
# 3        4.47     overcast clouds
# 4        4.38       moderate rain
# 5       10.40           clear sky
# 6       11.81           clear sky
# 7        4.00           clear sky
# 8       11.50           clear sky
# 9       15.37           clear sky

# %%
#make this active after sure I know where it's going and its' right  I have not run this yet. check with JUSTIn first
# Create and export the final Data Frame into a CSV
city_data__no_date_df.to_csv("WeatherPy_Database.csv", index_label="City_ID")

# %%
#csv files feeds into activity 2 and 3 - working well, and creating the db
