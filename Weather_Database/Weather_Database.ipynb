# %%
#Challenge part 1 pull the l and l info make a place for cities, count em, 
#Start here with Justin

# Import the dependencies.
import pandas as pd
#import matplotlib.pyplot as plt
import numpy as np

#Use the citipy module to determine city based on latitude and longitude.
#%pip install citipy
from citipy import citipy

# %%
# Create a set of random 2000 latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

#Zipping the pairs in a tuple with zip() function.
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 769

# %%
#Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3a5c22543e7db7978b522be236b0a831'

# %%
#cut from starting mod 626
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list using enumerate function.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]['description']
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | conceicao do araguaia
# Processing Record 3 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 1 | carpinteria
# Processing Record 5 of Set 1 | mahebourg
# Processing Record 6 of Set 1 | kegayli
# City not found. Skipping...
# Processing Record 7 of Set 1 | yar-sale
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | beira
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | newala
# Processing Record 12 of Set 1 | sorland
# Processing Record 13 of Set 1 | yellowknife
# Processing Record 14 of Set 1 | salinopolis
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | sibolga
# Processing Record 18 of Set 1 | codrington
# Processing Record 19 of Set 1 | avera
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | ribeira grande
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | krasnoarmeysk
# Processing Record 24 of Set 1 | praxedis guerrero
# Processing Record 25 of Set 1 | sitka
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | thompson
# Processing Record 28 of Set 1 | kirakira
# Processing Record 29 of Set 1 | yavaros
# Processing Record 30 of Set 1 | te anau
# Processing Record 31 of Set 1 | nikologory
# Processing Record 32 of Set 1 | tuatapere
# Processing Record 33 of Set 1 | mamallapuram
# Processing Record 34 of Set 1 | caravelas
# Processing Record 35 of Set 1 | port blair
# Processing Record 36 of Set 1 | sao joao da barra
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | loksa
# Processing Record 39 of Set 1 | starozhilovo
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | san ramon
# Processing Record 42 of Set 1 | komsomolskiy
# Processing Record 43 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 1 | vaini
# Processing Record 45 of Set 1 | saint anthony
# Processing Record 46 of Set 1 | fairbanks
# Processing Record 47 of Set 1 | tecoanapa
# Processing Record 48 of Set 1 | dibulla
# Processing Record 49 of Set 1 | arroio grande
# Processing Record 50 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 2 | busselton
# Processing Record 2 of Set 2 | pandan
# Processing Record 3 of Set 2 | narsaq
# Processing Record 4 of Set 2 | san jose
# Processing Record 5 of Set 2 | kodiak
# Processing Record 6 of Set 2 | aklavik
# Processing Record 7 of Set 2 | cabo san lucas
# Processing Record 8 of Set 2 | joshimath
# Processing Record 9 of Set 2 | kapaa
# Processing Record 10 of Set 2 | faanui
# Processing Record 11 of Set 2 | ushuaia
# Processing Record 12 of Set 2 | arman
# Processing Record 13 of Set 2 | luba
# Processing Record 14 of Set 2 | kruisfontein
# Processing Record 15 of Set 2 | puerto ayora
# Processing Record 16 of Set 2 | guangyuan
# Processing Record 17 of Set 2 | cidreira
# Processing Record 18 of Set 2 | tigil
# Processing Record 19 of Set 2 | ondjiva
# Processing Record 20 of Set 2 | khatanga
# Processing Record 21 of Set 2 | new norfolk
# Processing Record 22 of Set 2 | shingu
# Processing Record 23 of Set 2 | pevek
# Processing Record 24 of Set 2 | aksu
# Processing Record 25 of Set 2 | atuona
# Processing Record 26 of Set 2 | rach gia
# Processing Record 27 of Set 2 | ola
# Processing Record 28 of Set 2 | saldanha
# Processing Record 29 of Set 2 | fos-sur-mer
# Processing Record 30 of Set 2 | almeirim
# Processing Record 31 of Set 2 | hithadhoo
# Processing Record 32 of Set 2 | gat
# Processing Record 33 of Set 2 | huarmey
# Processing Record 34 of Set 2 | nicoya
# Processing Record 35 of Set 2 | darque
# Processing Record 36 of Set 2 | shizunai
# Processing Record 37 of Set 2 | salto
# Processing Record 38 of Set 2 | hilo
# Processing Record 39 of Set 2 | butaritari
# Processing Record 40 of Set 2 | sisimiut
# Processing Record 41 of Set 2 | olafsvik
# Processing Record 42 of Set 2 | mount gambier
# Processing Record 43 of Set 2 | isangel
# Processing Record 44 of Set 2 | taoudenni
# Processing Record 45 of Set 2 | georgetown
# Processing Record 46 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 2 | laguna
# Processing Record 48 of Set 2 | kjollefjord
# Processing Record 49 of Set 2 | chicama
# Processing Record 50 of Set 2 | erenhot
# Processing Record 1 of Set 3 | port elizabeth
# Processing Record 2 of Set 3 | carnarvon
# Processing Record 3 of Set 3 | troy
# Processing Record 4 of Set 3 | albany
# Processing Record 5 of Set 3 | susuman
# Processing Record 6 of Set 3 | lebu
# Processing Record 7 of Set 3 | chokurdakh
# Processing Record 8 of Set 3 | aquiraz
# Processing Record 9 of Set 3 | sao filipe
# Processing Record 10 of Set 3 | capreol
# Processing Record 11 of Set 3 | biu
# Processing Record 12 of Set 3 | douglas
# Processing Record 13 of Set 3 | arraial do cabo
# Processing Record 14 of Set 3 | usinsk
# Processing Record 15 of Set 3 | mayor pablo lagerenza
# Processing Record 16 of Set 3 | sedelnikovo
# City not found. Skipping...
# Processing Record 17 of Set 3 | churapcha
# Processing Record 18 of Set 3 | sambava
# Processing Record 19 of Set 3 | bengkulu
# Processing Record 20 of Set 3 | itaituba
# Processing Record 21 of Set 3 | kaitangata
# Processing Record 22 of Set 3 | kapoeta
# Processing Record 23 of Set 3 | nanchong
# Processing Record 24 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 3 | inyonga
# Processing Record 26 of Set 3 | airai
# Processing Record 27 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 3 | belyy yar
# Processing Record 29 of Set 3 | dalvik
# Processing Record 30 of Set 3 | archidona
# Processing Record 31 of Set 3 | vanavara
# Processing Record 32 of Set 3 | koumac
# Processing Record 33 of Set 3 | chiredzi
# Processing Record 34 of Set 3 | zheleznodorozhnyy
# Processing Record 35 of Set 3 | sydney
# Processing Record 36 of Set 3 | matamoros
# Processing Record 37 of Set 3 | ponta do sol
# Processing Record 38 of Set 3 | asfi
# Processing Record 39 of Set 3 | sindang
# Processing Record 40 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 41 of Set 3 | lorengau
# Processing Record 42 of Set 3 | winnemucca
# Processing Record 43 of Set 3 | manta
# Processing Record 44 of Set 3 | hobart
# Processing Record 45 of Set 3 | kalengwa
# Processing Record 46 of Set 3 | norman wells
# Processing Record 47 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 48 of Set 3 | naze
# Processing Record 49 of Set 3 | chandbali
# Processing Record 50 of Set 3 | grand gaube
# Processing Record 1 of Set 4 | cherskiy
# Processing Record 2 of Set 4 | cap malheureux
# Processing Record 3 of Set 4 | bandarbeyla
# Processing Record 4 of Set 4 | dikson
# Processing Record 5 of Set 4 | iskateley
# Processing Record 6 of Set 4 | nantucket
# Processing Record 7 of Set 4 | rio grande
# Processing Record 8 of Set 4 | zhezkazgan
# Processing Record 9 of Set 4 | crotone
# Processing Record 10 of Set 4 | manyana
# Processing Record 11 of Set 4 | deshnok
# Processing Record 12 of Set 4 | pemangkat
# Processing Record 13 of Set 4 | talnakh
# Processing Record 14 of Set 4 | tiksi
# Processing Record 15 of Set 4 | parati
# Processing Record 16 of Set 4 | hambantota
# Processing Record 17 of Set 4 | itarema
# Processing Record 18 of Set 4 | alice springs
# Processing Record 19 of Set 4 | tomatlan
# Processing Record 20 of Set 4 | charters towers
# Processing Record 21 of Set 4 | san patricio
# Processing Record 22 of Set 4 | montanhas
# Processing Record 23 of Set 4 | saint george
# Processing Record 24 of Set 4 | eyrarbakki
# Processing Record 25 of Set 4 | of
# City not found. Skipping...
# Processing Record 26 of Set 4 | karaton
# Processing Record 27 of Set 4 | keflavik
# Processing Record 28 of Set 4 | souillac
# Processing Record 29 of Set 4 | nikolskoye
# Processing Record 30 of Set 4 | brae
# Processing Record 31 of Set 4 | madang
# Processing Record 32 of Set 4 | tabas
# Processing Record 33 of Set 4 | sioux lookout
# Processing Record 34 of Set 4 | ippy
# Processing Record 35 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 4 | kenai
# Processing Record 37 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 4 | haines junction
# Processing Record 39 of Set 4 | flinders
# Processing Record 40 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 4 | kankon
# Processing Record 42 of Set 4 | avarua
# Processing Record 43 of Set 4 | moose factory
# Processing Record 44 of Set 4 | muros
# Processing Record 45 of Set 4 | kon tum
# Processing Record 46 of Set 4 | itupiranga
# Processing Record 47 of Set 4 | pisco
# Processing Record 48 of Set 4 | half moon bay
# Processing Record 49 of Set 4 | biltine
# Processing Record 50 of Set 4 | castro
# Processing Record 1 of Set 5 | sawakin
# Processing Record 2 of Set 5 | mizan teferi
# Processing Record 3 of Set 5 | iqaluit
# Processing Record 4 of Set 5 | caohai
# Processing Record 5 of Set 5 | novikovo
# Processing Record 6 of Set 5 | assiniboia
# Processing Record 7 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 5 | kiunga
# Processing Record 9 of Set 5 | matagami
# Processing Record 10 of Set 5 | provideniya
# Processing Record 11 of Set 5 | ta khmau
# Processing Record 12 of Set 5 | port moresby
# Processing Record 13 of Set 5 | luderitz
# Processing Record 14 of Set 5 | margate
# Processing Record 15 of Set 5 | el balyana
# City not found. Skipping...
# Processing Record 16 of Set 5 | moerai
# Processing Record 17 of Set 5 | ivanteyevka
# Processing Record 18 of Set 5 | port alfred
# Processing Record 19 of Set 5 | shache
# Processing Record 20 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 5 | nemuro
# Processing Record 22 of Set 5 | bonfim
# Processing Record 23 of Set 5 | mazatlan
# Processing Record 24 of Set 5 | kumluca
# Processing Record 25 of Set 5 | qui nhon
# Processing Record 26 of Set 5 | krasnoselkup
# Processing Record 27 of Set 5 | kavieng
# Processing Record 28 of Set 5 | calderitas
# Processing Record 29 of Set 5 | presidencia roque saenz pena
# Processing Record 30 of Set 5 | bethel
# Processing Record 31 of Set 5 | beringovskiy
# Processing Record 32 of Set 5 | pangoa
# Processing Record 33 of Set 5 | pemba
# Processing Record 34 of Set 5 | katsuura
# Processing Record 35 of Set 5 | victoria
# Processing Record 36 of Set 5 | coahuayana
# Processing Record 37 of Set 5 | dingle
# Processing Record 38 of Set 5 | dudinka
# Processing Record 39 of Set 5 | reyes
# Processing Record 40 of Set 5 | yining
# Processing Record 41 of Set 5 | chapada dos guimaraes
# Processing Record 42 of Set 5 | maceio
# Processing Record 43 of Set 5 | jabinyanah
# Processing Record 44 of Set 5 | bluff
# Processing Record 45 of Set 5 | anadyr
# Processing Record 46 of Set 5 | urumqi
# Processing Record 47 of Set 5 | vero beach
# Processing Record 48 of Set 5 | singaraja
# Processing Record 49 of Set 5 | husavik
# Processing Record 50 of Set 5 | wonthaggi
# Processing Record 1 of Set 6 | sindand
# City not found. Skipping...
# Processing Record 2 of Set 6 | lompoc
# Processing Record 3 of Set 6 | santa lucia
# Processing Record 4 of Set 6 | straumen
# Processing Record 5 of Set 6 | mar del plata
# Processing Record 6 of Set 6 | san andres
# Processing Record 7 of Set 6 | nanortalik
# Processing Record 8 of Set 6 | srivardhan
# Processing Record 9 of Set 6 | tasiilaq
# Processing Record 10 of Set 6 | tuktoyaktuk
# Processing Record 11 of Set 6 | severo-kurilsk
# Processing Record 12 of Set 6 | dicabisagan
# Processing Record 13 of Set 6 | vardo
# Processing Record 14 of Set 6 | tateyama
# Processing Record 15 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 6 | makakilo city
# Processing Record 17 of Set 6 | mufulira
# Processing Record 18 of Set 6 | inta
# Processing Record 19 of Set 6 | cayenne
# Processing Record 20 of Set 6 | kahului
# Processing Record 21 of Set 6 | neiafu
# Processing Record 22 of Set 6 | cabra
# Processing Record 23 of Set 6 | beloha
# Processing Record 24 of Set 6 | tarnow
# Processing Record 25 of Set 6 | east london
# Processing Record 26 of Set 6 | hay river
# Processing Record 27 of Set 6 | stamsund
# City not found. Skipping...
# Processing Record 28 of Set 6 | belaya gora
# Processing Record 29 of Set 6 | weligama
# Processing Record 30 of Set 6 | egvekinot
# Processing Record 31 of Set 6 | kulhudhuffushi
# Processing Record 32 of Set 6 | doka
# Processing Record 33 of Set 6 | tillabery
# City not found. Skipping...
# Processing Record 34 of Set 6 | sungairaya
# Processing Record 35 of Set 6 | terney
# Processing Record 36 of Set 6 | pangnirtung
# Processing Record 37 of Set 6 | amapa
# Processing Record 38 of Set 6 | hibbing
# Processing Record 39 of Set 6 | yeppoon
# Processing Record 40 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 41 of Set 6 | richards bay
# Processing Record 42 of Set 6 | nara
# Processing Record 43 of Set 6 | ancud
# Processing Record 44 of Set 6 | hasaki
# Processing Record 45 of Set 6 | hofn
# Processing Record 46 of Set 6 | tual
# Processing Record 47 of Set 6 | vestmannaeyjar
# Processing Record 48 of Set 6 | atar
# Processing Record 49 of Set 6 | celestun
# Processing Record 50 of Set 6 | bambous virieux
# Processing Record 1 of Set 7 | longyearbyen
# Processing Record 2 of Set 7 | ostrovnoy
# Processing Record 3 of Set 7 | patacamaya
# Processing Record 4 of Set 7 | simao
# Processing Record 5 of Set 7 | ushtobe
# Processing Record 6 of Set 7 | upernavik
# Processing Record 7 of Set 7 | loreto
# Processing Record 8 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 7 | coelho neto
# Processing Record 10 of Set 7 | tautira
# Processing Record 11 of Set 7 | calnali
# Processing Record 12 of Set 7 | marzuq
# Processing Record 13 of Set 7 | gimli
# Processing Record 14 of Set 7 | bay roberts
# Processing Record 15 of Set 7 | beni
# Processing Record 16 of Set 7 | oyem
# Processing Record 17 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 7 | bonavista
# Processing Record 19 of Set 7 | kuzedeyevo
# Processing Record 20 of Set 7 | ahipara
# Processing Record 21 of Set 7 | klaksvik
# Processing Record 22 of Set 7 | faya
# Processing Record 23 of Set 7 | kamariotissa
# Processing Record 24 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 7 | barabai
# Processing Record 26 of Set 7 | manokwari
# Processing Record 27 of Set 7 | ndele
# Processing Record 28 of Set 7 | tairua
# Processing Record 29 of Set 7 | obo
# Processing Record 30 of Set 7 | sakakah
# Processing Record 31 of Set 7 | guanica
# Processing Record 32 of Set 7 | havoysund
# Processing Record 33 of Set 7 | nova prata
# Processing Record 34 of Set 7 | linhares
# Processing Record 35 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 7 | morant bay
# Processing Record 37 of Set 7 | agirish
# Processing Record 38 of Set 7 | taikang
# Processing Record 39 of Set 7 | coquimbo
# Processing Record 40 of Set 7 | camacha
# Processing Record 41 of Set 7 | rafai
# Processing Record 42 of Set 7 | carbonia
# Processing Record 43 of Set 7 | elk point
# Processing Record 44 of Set 7 | fort nelson
# Processing Record 45 of Set 7 | bataipora
# Processing Record 46 of Set 7 | monrovia
# Processing Record 47 of Set 7 | adrar
# Processing Record 48 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 7 | oriximina
# Processing Record 50 of Set 7 | waipawa
# Processing Record 1 of Set 8 | kalmunai
# Processing Record 2 of Set 8 | walvis bay
# Processing Record 3 of Set 8 | san cristobal
# Processing Record 4 of Set 8 | termoli
# Processing Record 5 of Set 8 | olinda
# Processing Record 6 of Set 8 | mehamn
# Processing Record 7 of Set 8 | san quintin
# Processing Record 8 of Set 8 | upington
# Processing Record 9 of Set 8 | zaraza
# Processing Record 10 of Set 8 | henties bay
# Processing Record 11 of Set 8 | clyde river
# Processing Record 12 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 8 | kinna
# Processing Record 14 of Set 8 | andros town
# Processing Record 15 of Set 8 | acapulco
# Processing Record 16 of Set 8 | meiganga
# Processing Record 17 of Set 8 | salalah
# Processing Record 18 of Set 8 | nome
# Processing Record 19 of Set 8 | ciras
# City not found. Skipping...
# Processing Record 20 of Set 8 | ixtapa
# Processing Record 21 of Set 8 | doha
# Processing Record 22 of Set 8 | praia da vitoria
# Processing Record 23 of Set 8 | baykit
# Processing Record 24 of Set 8 | maloy
# Processing Record 25 of Set 8 | andenes
# Processing Record 26 of Set 8 | vila franca do campo
# Processing Record 27 of Set 8 | mecca
# Processing Record 28 of Set 8 | coihaique
# Processing Record 29 of Set 8 | loveland
# Processing Record 30 of Set 8 | tari
# Processing Record 31 of Set 8 | sistranda
# Processing Record 32 of Set 8 | bainbridge
# Processing Record 33 of Set 8 | constitucion
# Processing Record 34 of Set 8 | aykhal
# Processing Record 35 of Set 8 | valera
# Processing Record 36 of Set 8 | itarana
# Processing Record 37 of Set 8 | ampanihy
# Processing Record 38 of Set 8 | hirara
# Processing Record 39 of Set 8 | bomet
# Processing Record 40 of Set 8 | bulgan
# Processing Record 41 of Set 8 | njombe
# Processing Record 42 of Set 8 | baker city
# Processing Record 43 of Set 8 | sao felix do xingu
# Processing Record 44 of Set 8 | isoka
# Processing Record 45 of Set 8 | boa vista
# Processing Record 46 of Set 8 | san pedro
# Processing Record 47 of Set 8 | praia
# Processing Record 48 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 49 of Set 8 | santana do livramento
# Processing Record 50 of Set 8 | loa janan
# Processing Record 1 of Set 9 | bekhtery
# Processing Record 2 of Set 9 | colorado
# Processing Record 3 of Set 9 | chihuahua
# Processing Record 4 of Set 9 | antalaha
# Processing Record 5 of Set 9 | birobidzhan
# Processing Record 6 of Set 9 | nakamura
# Processing Record 7 of Set 9 | geraldton
# Processing Record 8 of Set 9 | taitung
# Processing Record 9 of Set 9 | karratha
# Processing Record 10 of Set 9 | lhokseumawe
# Processing Record 11 of Set 9 | duldurga
# Processing Record 12 of Set 9 | agadez
# Processing Record 13 of Set 9 | kiruna
# Processing Record 14 of Set 9 | port hedland
# Processing Record 15 of Set 9 | asyut
# Processing Record 16 of Set 9 | dekar
# Processing Record 17 of Set 9 | kismayo
# Processing Record 18 of Set 9 | nuuk
# Processing Record 19 of Set 9 | southbridge
# Processing Record 20 of Set 9 | kokopo
# Processing Record 21 of Set 9 | wanning
# Processing Record 22 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 23 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 9 | ucluelet
# Processing Record 25 of Set 9 | saint-philippe
# Processing Record 26 of Set 9 | la ronge
# Processing Record 27 of Set 9 | qandala
# Processing Record 28 of Set 9 | maghama
# City not found. Skipping...
# Processing Record 29 of Set 9 | jiangyou
# Processing Record 30 of Set 9 | severomuysk
# Processing Record 31 of Set 9 | mendi
# Processing Record 32 of Set 9 | jertih
# Processing Record 33 of Set 9 | nazare
# Processing Record 34 of Set 9 | veraval
# Processing Record 35 of Set 9 | rocha
# Processing Record 36 of Set 9 | cururupu
# Processing Record 37 of Set 9 | shetpe
# Processing Record 38 of Set 9 | pochutla
# Processing Record 39 of Set 9 | kavaratti
# Processing Record 40 of Set 9 | soria
# Processing Record 41 of Set 9 | roma
# Processing Record 42 of Set 9 | gweta
# Processing Record 43 of Set 9 | roverud
# Processing Record 44 of Set 9 | mao
# Processing Record 45 of Set 9 | abbeville
# Processing Record 46 of Set 9 | awash
# Processing Record 47 of Set 9 | lujan
# Processing Record 48 of Set 9 | yankton
# Processing Record 49 of Set 9 | hovd
# Processing Record 50 of Set 9 | kalabo
# Processing Record 1 of Set 10 | qaqortoq
# Processing Record 2 of Set 10 | williamsburg
# Processing Record 3 of Set 10 | aldan
# Processing Record 4 of Set 10 | pokrovskoye
# Processing Record 5 of Set 10 | puerto escondido
# Processing Record 6 of Set 10 | beidao
# Processing Record 7 of Set 10 | fare
# Processing Record 8 of Set 10 | russellville
# Processing Record 9 of Set 10 | ilulissat
# Processing Record 10 of Set 10 | san ignacio
# Processing Record 11 of Set 10 | basco
# Processing Record 12 of Set 10 | juifang
# City not found. Skipping...
# Processing Record 13 of Set 10 | carlsbad
# Processing Record 14 of Set 10 | montauban
# Processing Record 15 of Set 10 | kingston
# Processing Record 16 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 10 | kaoma
# Processing Record 18 of Set 10 | bourail
# Processing Record 19 of Set 10 | vung tau
# Processing Record 20 of Set 10 | kapit
# Processing Record 21 of Set 10 | guadalupe y calvo
# Processing Record 22 of Set 10 | hobyo
# Processing Record 23 of Set 10 | mahibadhoo
# Processing Record 24 of Set 10 | nishihara
# Processing Record 25 of Set 10 | kupino
# Processing Record 26 of Set 10 | porto novo
# Processing Record 27 of Set 10 | bara
# Processing Record 28 of Set 10 | manoharpur
# Processing Record 29 of Set 10 | berlevag
# Processing Record 30 of Set 10 | borogontsy
# Processing Record 31 of Set 10 | sao gabriel da cachoeira
# Processing Record 32 of Set 10 | khabary
# Processing Record 33 of Set 10 | atkinson
# Processing Record 34 of Set 10 | saskylakh
# Processing Record 35 of Set 10 | araouane
# Processing Record 36 of Set 10 | touros
# Processing Record 37 of Set 10 | buckeye
# Processing Record 38 of Set 10 | buraydah
# Processing Record 39 of Set 10 | plettenberg bay
# Processing Record 40 of Set 10 | nizwa
# Processing Record 41 of Set 10 | lashio
# Processing Record 42 of Set 10 | vostok
# Processing Record 43 of Set 10 | kabo
# Processing Record 44 of Set 10 | baicheng
# Processing Record 45 of Set 10 | port macquarie
# Processing Record 46 of Set 10 | mayo
# Processing Record 47 of Set 10 | surgut
# Processing Record 48 of Set 10 | kiama
# Processing Record 49 of Set 10 | kodinsk
# Processing Record 50 of Set 10 | chuy
# Processing Record 1 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 2 of Set 11 | tabuk
# Processing Record 3 of Set 11 | jumla
# Processing Record 4 of Set 11 | madison
# Processing Record 5 of Set 11 | fukue
# Processing Record 6 of Set 11 | alofi
# Processing Record 7 of Set 11 | mahon
# Processing Record 8 of Set 11 | bereznik
# Processing Record 9 of Set 11 | leningradskiy
# Processing Record 10 of Set 11 | mandla
# Processing Record 11 of Set 11 | chichibu
# Processing Record 12 of Set 11 | sarakhs
# Processing Record 13 of Set 11 | moroni
# Processing Record 14 of Set 11 | calais
# Processing Record 15 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 16 of Set 11 | lufilufi
# Processing Record 17 of Set 11 | tilichiki
# Processing Record 18 of Set 11 | cabedelo
# Processing Record 19 of Set 11 | binzhou
# Processing Record 20 of Set 11 | the valley
# Processing Record 21 of Set 11 | emba
# Processing Record 22 of Set 11 | namibe
# Processing Record 23 of Set 11 | opuwo
# Processing Record 24 of Set 11 | aksarka
# Processing Record 25 of Set 11 | murray bridge
# Processing Record 26 of Set 11 | mana
# Processing Record 27 of Set 11 | achisay
# City not found. Skipping...
# Processing Record 28 of Set 11 | imphal
# Processing Record 29 of Set 11 | saryozek
# Processing Record 30 of Set 11 | banepa
# Processing Record 31 of Set 11 | karakol
# Processing Record 32 of Set 11 | saint-pierre
# Processing Record 33 of Set 11 | torbay
# Processing Record 34 of Set 11 | kasama
# Processing Record 35 of Set 11 | tongliao
# Processing Record 36 of Set 11 | chikwawa
# Processing Record 37 of Set 11 | bandarban
# Processing Record 38 of Set 11 | svetlogorsk
# Processing Record 39 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 40 of Set 11 | san policarpo
# Processing Record 41 of Set 11 | vilyuysk
# Processing Record 42 of Set 11 | nyuksenitsa
# Processing Record 43 of Set 11 | sur
# Processing Record 44 of Set 11 | batakil
# Processing Record 45 of Set 11 | maragogi
# Processing Record 46 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 47 of Set 11 | umba
# Processing Record 48 of Set 11 | alekseyevsk
# Processing Record 49 of Set 11 | sola
# Processing Record 50 of Set 11 | slave lake
# Processing Record 1 of Set 12 | nelson bay
# Processing Record 2 of Set 12 | paamiut
# Processing Record 3 of Set 12 | gamba
# Processing Record 4 of Set 12 | mormugao
# Processing Record 5 of Set 12 | norsup
# Processing Record 6 of Set 12 | labuhan
# Processing Record 7 of Set 12 | bonthe
# Processing Record 8 of Set 12 | bogandinskiy
# Processing Record 9 of Set 12 | padang
# Processing Record 10 of Set 12 | meulaboh
# Processing Record 11 of Set 12 | talaya
# Processing Record 12 of Set 12 | taylorville
# Processing Record 13 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 12 | jiaozuo
# Processing Record 15 of Set 12 | tlapacoyan
# Processing Record 16 of Set 12 | privolzhskiy
# Processing Record 17 of Set 12 | vikesa
# Processing Record 18 of Set 12 | rosita
# Processing Record 19 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 20 of Set 12 | boda
# Processing Record 21 of Set 12 | raga
# Processing Record 22 of Set 12 | mayachnyy
# Processing Record 23 of Set 12 | gazli
# Processing Record 24 of Set 12 | jardim
# Processing Record 25 of Set 12 | esperance
# Processing Record 26 of Set 12 | port-gentil
# Processing Record 27 of Set 12 | bousse
# Processing Record 28 of Set 12 | xiaoweizhai
# Processing Record 29 of Set 12 | waycross
# Processing Record 30 of Set 12 | chulman
# Processing Record 31 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 12 | chernyshevskiy
# Processing Record 33 of Set 12 | westport
# Processing Record 34 of Set 12 | vao
# Processing Record 35 of Set 12 | marienburg
# Processing Record 36 of Set 12 | eureka
# Processing Record 37 of Set 12 | palmer
# Processing Record 38 of Set 12 | yei
# Processing Record 39 of Set 12 | vila velha
# Processing Record 40 of Set 12 | nhulunbuy
# Processing Record 41 of Set 12 | zhangjiakou
# Processing Record 42 of Set 12 | rawson
# Processing Record 43 of Set 12 | malakal
# Processing Record 44 of Set 12 | leninskoye
# Processing Record 45 of Set 12 | grindavik
# Processing Record 46 of Set 12 | uige
# Processing Record 47 of Set 12 | capoterra
# Processing Record 48 of Set 12 | krasnyy chikoy
# Processing Record 49 of Set 12 | santa vitoria do palmar
# Processing Record 50 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 1 of Set 13 | portland
# Processing Record 2 of Set 13 | hamilton
# Processing Record 3 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 13 | socorro
# Processing Record 5 of Set 13 | san benito
# Processing Record 6 of Set 13 | sao joao del rei
# Processing Record 7 of Set 13 | alyangula
# Processing Record 8 of Set 13 | steamboat springs
# Processing Record 9 of Set 13 | muscle shoals
# Processing Record 10 of Set 13 | ambilobe
# Processing Record 11 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 12 of Set 13 | kingman
# Processing Record 13 of Set 13 | fortuna
# Processing Record 14 of Set 13 | north bend
# Processing Record 15 of Set 13 | mancio lima
# Processing Record 16 of Set 13 | champasak
# Processing Record 17 of Set 13 | tongren
# Processing Record 18 of Set 13 | vanimo
# Processing Record 19 of Set 13 | uray
# Processing Record 20 of Set 13 | catamarca
# Processing Record 21 of Set 13 | gwanda
# Processing Record 22 of Set 13 | saravan
# Processing Record 23 of Set 13 | cascais
# Processing Record 24 of Set 13 | bud
# Processing Record 25 of Set 13 | kinshasa
# Processing Record 26 of Set 13 | santa rita
# Processing Record 27 of Set 13 | zhuhai
# Processing Record 28 of Set 13 | road town
# Processing Record 29 of Set 13 | lagoa
# Processing Record 30 of Set 13 | dukat
# Processing Record 31 of Set 13 | vila do maio
# Processing Record 32 of Set 13 | guerrero negro
# Processing Record 33 of Set 13 | tahta
# Processing Record 34 of Set 13 | wyndham
# Processing Record 35 of Set 13 | okhotsk
# Processing Record 36 of Set 13 | bhikangaon
# Processing Record 37 of Set 13 | kaa-khem
# Processing Record 38 of Set 13 | las matas de farfan
# Processing Record 39 of Set 13 | charagua
# Processing Record 40 of Set 13 | napoleon
# Processing Record 41 of Set 13 | oxbow
# Processing Record 42 of Set 13 | akdepe
# Processing Record 43 of Set 13 | anloga
# Processing Record 44 of Set 13 | maryville
# Processing Record 45 of Set 13 | fasa
# Processing Record 46 of Set 13 | ishigaki
# Processing Record 47 of Set 13 | karasjok
# Processing Record 48 of Set 13 | krasnyy klyuch
# Processing Record 49 of Set 13 | pousat
# City not found. Skipping...
# Processing Record 50 of Set 13 | saint-joseph
# Processing Record 1 of Set 14 | hami
# Processing Record 2 of Set 14 | zhangye
# Processing Record 3 of Set 14 | santo antonio
# Processing Record 4 of Set 14 | mozirje
# Processing Record 5 of Set 14 | port hardy
# Processing Record 6 of Set 14 | gorokhovets
# Processing Record 7 of Set 14 | katubao
# Processing Record 8 of Set 14 | douentza
# Processing Record 9 of Set 14 | bayan
# Processing Record 10 of Set 14 | kunda
# Processing Record 11 of Set 14 | paraiso
# Processing Record 12 of Set 14 | union
# Processing Record 13 of Set 14 | dunkwa
# Processing Record 14 of Set 14 | quesnel
# Processing Record 15 of Set 14 | kyren
# Processing Record 16 of Set 14 | jalu
# Processing Record 17 of Set 14 | thinadhoo
# Processing Record 18 of Set 14 | mareeba
# Processing Record 19 of Set 14 | sarankhola
# Processing Record 20 of Set 14 | deputatskiy
# Processing Record 21 of Set 14 | hohhot
# Processing Record 22 of Set 14 | aswan
# Processing Record 23 of Set 14 | khorinsk
# Processing Record 24 of Set 14 | panino
# Processing Record 25 of Set 14 | saint-augustin
# Processing Record 26 of Set 14 | vakhrushev
# Processing Record 27 of Set 14 | freetown
# Processing Record 28 of Set 14 | roseburg
# Processing Record 29 of Set 14 | whitehaven
# Processing Record 30 of Set 14 | sinnamary
# Processing Record 31 of Set 14 | yinchuan
# Processing Record 32 of Set 14 | sun valley
# Processing Record 33 of Set 14 | santa cruz
# Processing Record 34 of Set 14 | sobolevo
# Processing Record 35 of Set 14 | havre-saint-pierre
# Processing Record 36 of Set 14 | matara
# Processing Record 37 of Set 14 | eirunepe
# Processing Record 38 of Set 14 | fosforitnyy
# Processing Record 39 of Set 14 | huai yot
# Processing Record 40 of Set 14 | los llanos de aridane
# Processing Record 41 of Set 14 | imeni poliny osipenko
# Processing Record 42 of Set 14 | miandrivazo
# Processing Record 43 of Set 14 | ternate
# Processing Record 44 of Set 14 | pokhara
# Processing Record 45 of Set 14 | jiaojiang
# Processing Record 46 of Set 14 | mansa
# Processing Record 47 of Set 14 | corumba
# Processing Record 48 of Set 14 | sao marcos
# Processing Record 49 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 50 of Set 14 | bastogne
# Processing Record 1 of Set 15 | shujalpur
# Processing Record 2 of Set 15 | ayagoz
# Processing Record 3 of Set 15 | bardiyah
# Processing Record 4 of Set 15 | pimenteiras
# Processing Record 5 of Set 15 | puro
# Processing Record 6 of Set 15 | vagay
# Processing Record 7 of Set 15 | cockburn town
# Processing Record 8 of Set 15 | harper
# Processing Record 9 of Set 15 | leshukonskoye
# Processing Record 10 of Set 15 | kununurra
# Processing Record 11 of Set 15 | winchester
# Processing Record 12 of Set 15 | tral
# Processing Record 13 of Set 15 | saiha
# Processing Record 14 of Set 15 | dhidhdhoo
# Processing Record 15 of Set 15 | rundu
# Processing Record 16 of Set 15 | saurimo
# Processing Record 17 of Set 15 | sitrah
# Processing Record 18 of Set 15 | khani
# Processing Record 19 of Set 15 | ketovo
# Processing Record 20 of Set 15 | paysandu
# Processing Record 21 of Set 15 | illela
# Processing Record 22 of Set 15 | waingapu
# Processing Record 23 of Set 15 | byron bay
# Processing Record 24 of Set 15 | broome
# Processing Record 25 of Set 15 | amazar
# Processing Record 26 of Set 15 | vaitape
# Processing Record 27 of Set 15 | shimoda
# Processing Record 28 of Set 15 | gushikawa
# Processing Record 29 of Set 15 | marysville
# Processing Record 30 of Set 15 | daokou
# Processing Record 31 of Set 15 | victor harbor
# Processing Record 32 of Set 15 | la mira
# Processing Record 33 of Set 15 | rolla
# Processing Record 34 of Set 15 | tunduru
# City not found. Skipping...
# Processing Record 35 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 36 of Set 15 | carutapera
# Processing Record 37 of Set 15 | ornes
# Processing Record 38 of Set 15 | garowe
# Processing Record 39 of Set 15 | bireun
# Processing Record 40 of Set 15 | kerteh
# City not found. Skipping...
# Processing Record 41 of Set 15 | nyurba
# Processing Record 42 of Set 15 | santander
# Processing Record 43 of Set 15 | kibaya
# Processing Record 44 of Set 15 | shahkot
# Processing Record 45 of Set 15 | changli
# Processing Record 46 of Set 15 | zhigansk
# Processing Record 47 of Set 15 | kargopol
# Processing Record 48 of Set 15 | lasem
# Processing Record 49 of Set 15 | bull savanna
# Processing Record 50 of Set 15 | ishinomaki
# Processing Record 1 of Set 16 | antofagasta
# Processing Record 2 of Set 16 | benghazi
# Processing Record 3 of Set 16 | ahuimanu
# Processing Record 4 of Set 16 | srednekolymsk
# Processing Record 5 of Set 16 | barcelona
# Processing Record 6 of Set 16 | ust-ishim
# Processing Record 7 of Set 16 | rio gallegos
# Processing Record 8 of Set 16 | babanusah
# City not found. Skipping...
# Processing Record 9 of Set 16 | nokaneng
# Processing Record 10 of Set 16 | paso de carrasco
# Processing Record 11 of Set 16 | mezen
# Processing Record 12 of Set 16 | arteaga
# Processing Record 13 of Set 16 | tuyen quang
# Processing Record 14 of Set 16 | teguise
# Processing Record 15 of Set 16 | ambon
# Processing Record 16 of Set 16 | hengshui
# Processing Record 17 of Set 16 | pervomayskoye
# Processing Record 18 of Set 16 | stillwater
# Processing Record 19 of Set 16 | bardsir
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Get the number of the cities
len(city_data)
# Out:
# 717

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                 Barrow  71.2906 -156.7887     37.42        75          75
# 1  Conceicao Do Araguaia  -8.2578  -49.2647     77.22        38           8
# 2            Carpinteria  34.3989 -119.5185     89.37        64          22
# 3              Mahebourg -20.4081   57.7000     66.25        77          61
# 4               Yar-Sale  66.8333   70.8333     48.22        60           5
# 5              Cape Town -33.9258   18.4232     49.12        95          51
# 6                  Beira -19.8436   34.8389     68.23        85          76
# 7                Qaanaaq  77.4840  -69.3632     38.59        98         100
# 8                 Newala -10.9431   39.2787     60.12        96          27
# 9                Sorland  67.6670   12.6934     56.35        87          84
#
#    Wind Speed Current Description Country                 Date
# 0        9.22       broken clouds      US  2021-07-15 00:14:52
# 1        3.18           clear sky      BR  2021-07-15 00:14:27
# 2        5.66          few clouds      US  2021-07-15 00:14:54
# 3        9.28       broken clouds      MU  2021-07-15 00:14:55
# 4        5.61           clear sky      RU  2021-07-15 00:14:56
# 5        4.34       broken clouds      ZA  2021-07-15 00:14:57
# 6       13.53          light rain      MZ  2021-07-15 00:11:55
# 7        2.53          light rain      GL  2021-07-15 00:14:58
# 8        3.76    scattered clouds      TZ  2021-07-15 00:14:58
# 9        4.54       broken clouds      NO  2021-07-15 00:14:59

# %%
#have a sytax error here  to fix still  
#Organize the columns in the DataFrame.
city_data__no_date_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']]
city_data__no_date_df.head(10)
# Out:
#                     City Country      Lat       Lng  Max Temp  Humidity  \
# 0                 Barrow      US  71.2906 -156.7887     37.42        75
# 1  Conceicao Do Araguaia      BR  -8.2578  -49.2647     77.22        38
# 2            Carpinteria      US  34.3989 -119.5185     89.37        64
# 3              Mahebourg      MU -20.4081   57.7000     66.25        77
# 4               Yar-Sale      RU  66.8333   70.8333     48.22        60
# 5              Cape Town      ZA -33.9258   18.4232     49.12        95
# 6                  Beira      MZ -19.8436   34.8389     68.23        85
# 7                Qaanaaq      GL  77.4840  -69.3632     38.59        98
# 8                 Newala      TZ -10.9431   39.2787     60.12        96
# 9                Sorland      NO  67.6670   12.6934     56.35        87
#
#    Cloudiness  Wind Speed Current Description
# 0          75        9.22       broken clouds
# 1           8        3.18           clear sky
# 2          22        5.66          few clouds
# 3          61        9.28       broken clouds
# 4           5        5.61           clear sky
# 5          51        4.34       broken clouds
# 6          76       13.53          light rain
# 7         100        2.53          light rain
# 8          27        3.76    scattered clouds
# 9          84        4.54       broken clouds

# %%
#make this active after sure I know where it's going and its' right  I have not run this yet. check with JUSTIn first
# Create and export the final Data Frame into a CSV
city_data__no_date_df.to_csv("WeatherPy_Database.csv", index_label="City_ID")

# %%
#csv files feeds into activity 2 and 3
