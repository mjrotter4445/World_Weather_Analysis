# %%
#Challenge part 1 pull the l and l info make a place for cities, count em, 
#Start here with Justin

# Import the dependencies.
import pandas as pd
#import matplotlib.pyplot as plt
import numpy as np

#Use the citipy module to determine city based on latitude and longitude.
# %pip install citipy
from citipy import citipy
# Out:
# Requirement already satisfied: citipy in c:\users\mjrot\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\mjrot\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Create a set of random 2000 latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

#Zipping the pairs in a tuple with zip() function.
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
#Import the requests library.
import requests

#Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#from starting mod 626
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list using enumerate function.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]['description']
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | busselton
# Processing Record 2 of Set 1 | ashland
# Processing Record 3 of Set 1 | longyearbyen
# Processing Record 4 of Set 1 | kattivakkam
# Processing Record 5 of Set 1 | ngunguru
# Processing Record 6 of Set 1 | upernavik
# Processing Record 7 of Set 1 | komsomolskiy
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | aklavik
# Processing Record 10 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 1 | thompson
# Processing Record 12 of Set 1 | norman wells
# Processing Record 13 of Set 1 | sharan
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | new norfolk
# Processing Record 16 of Set 1 | georgetown
# Processing Record 17 of Set 1 | boralday
# Processing Record 18 of Set 1 | nanortalik
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | san quintin
# Processing Record 21 of Set 1 | carnarvon
# Processing Record 22 of Set 1 | fairbanks
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | ribeira grande
# Processing Record 25 of Set 1 | pevek
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | vaini
# Processing Record 29 of Set 1 | coahuayana
# Processing Record 30 of Set 1 | bacuit
# City not found. Skipping...
# Processing Record 31 of Set 1 | pombas
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | ituni
# City not found. Skipping...
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 1 | inderborskiy
# City not found. Skipping...
# Processing Record 37 of Set 1 | yenagoa
# Processing Record 38 of Set 1 | tranas
# Processing Record 39 of Set 1 | kodiak
# Processing Record 40 of Set 1 | avarua
# Processing Record 41 of Set 1 | kapaa
# Processing Record 42 of Set 1 | cape town
# Processing Record 43 of Set 1 | aksarka
# Processing Record 44 of Set 1 | butaritari
# Processing Record 45 of Set 1 | east london
# Processing Record 46 of Set 1 | saint-philippe
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | mehamn
# Processing Record 49 of Set 1 | vossevangen
# Processing Record 50 of Set 1 | dod ballapur
# Processing Record 1 of Set 2 | pandan
# Processing Record 2 of Set 2 | trinidad
# Processing Record 3 of Set 2 | faanui
# Processing Record 4 of Set 2 | ayotzintepec
# Processing Record 5 of Set 2 | geraldton
# Processing Record 6 of Set 2 | kijang
# Processing Record 7 of Set 2 | linxia
# Processing Record 8 of Set 2 | mataura
# Processing Record 9 of Set 2 | chuy
# Processing Record 10 of Set 2 | bambous virieux
# Processing Record 11 of Set 2 | maxixe
# Processing Record 12 of Set 2 | hermanus
# Processing Record 13 of Set 2 | westpunt
# City not found. Skipping...
# Processing Record 14 of Set 2 | castro
# Processing Record 15 of Set 2 | hasaki
# Processing Record 16 of Set 2 | ayan
# Processing Record 17 of Set 2 | punta arenas
# Processing Record 18 of Set 2 | kilindoni
# Processing Record 19 of Set 2 | urucui
# Processing Record 20 of Set 2 | khormuj
# City not found. Skipping...
# Processing Record 21 of Set 2 | kruisfontein
# Processing Record 22 of Set 2 | chokurdakh
# Processing Record 23 of Set 2 | sabang
# Processing Record 24 of Set 2 | fare
# Processing Record 25 of Set 2 | anchorage
# Processing Record 26 of Set 2 | camana
# Processing Record 27 of Set 2 | varhaug
# Processing Record 28 of Set 2 | thanh hoa
# Processing Record 29 of Set 2 | saint-pierre
# Processing Record 30 of Set 2 | airai
# Processing Record 31 of Set 2 | puerto ayora
# Processing Record 32 of Set 2 | bandarbeyla
# Processing Record 33 of Set 2 | atambua
# Processing Record 34 of Set 2 | ixtapa
# Processing Record 35 of Set 2 | beringovskiy
# Processing Record 36 of Set 2 | bengkulu
# Processing Record 37 of Set 2 | yialos
# City not found. Skipping...
# Processing Record 38 of Set 2 | esperance
# Processing Record 39 of Set 2 | lagoa
# Processing Record 40 of Set 2 | plettenberg bay
# Processing Record 41 of Set 2 | baiyin
# Processing Record 42 of Set 2 | evensk
# Processing Record 43 of Set 2 | arraial do cabo
# Processing Record 44 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 2 | souillac
# Processing Record 46 of Set 2 | adre
# Processing Record 47 of Set 2 | basco
# Processing Record 48 of Set 2 | hithadhoo
# Processing Record 49 of Set 2 | saint-francois
# Processing Record 50 of Set 2 | dalvik
# Processing Record 1 of Set 3 | san patricio
# Processing Record 2 of Set 3 | buturlino
# Processing Record 3 of Set 3 | karratha
# Processing Record 4 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 5 of Set 3 | cedar city
# Processing Record 6 of Set 3 | kaitangata
# Processing Record 7 of Set 3 | san angelo
# Processing Record 8 of Set 3 | dikson
# Processing Record 9 of Set 3 | hualmay
# Processing Record 10 of Set 3 | tuktoyaktuk
# Processing Record 11 of Set 3 | jamestown
# Processing Record 12 of Set 3 | nikolskoye
# Processing Record 13 of Set 3 | macaboboni
# City not found. Skipping...
# Processing Record 14 of Set 3 | sosnovo-ozerskoye
# Processing Record 15 of Set 3 | yellowknife
# Processing Record 16 of Set 3 | afmadu
# City not found. Skipping...
# Processing Record 17 of Set 3 | meybod
# Processing Record 18 of Set 3 | praia da vitoria
# Processing Record 19 of Set 3 | barrow
# Processing Record 20 of Set 3 | port alfred
# Processing Record 21 of Set 3 | kununurra
# Processing Record 22 of Set 3 | victoria
# Processing Record 23 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 24 of Set 3 | cheremshan
# Processing Record 25 of Set 3 | sampit
# Processing Record 26 of Set 3 | ullapool
# Processing Record 27 of Set 3 | kuli
# Processing Record 28 of Set 3 | egvekinot
# Processing Record 29 of Set 3 | jalu
# Processing Record 30 of Set 3 | cayeli
# Processing Record 31 of Set 3 | portmore
# Processing Record 32 of Set 3 | saskylakh
# Processing Record 33 of Set 3 | hakodate
# Processing Record 34 of Set 3 | lebu
# Processing Record 35 of Set 3 | dwarka
# Processing Record 36 of Set 3 | atasu
# Processing Record 37 of Set 3 | albany
# Processing Record 38 of Set 3 | haikou
# Processing Record 39 of Set 3 | kropotkin
# Processing Record 40 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 3 | bilibino
# Processing Record 42 of Set 3 | tuatapere
# Processing Record 43 of Set 3 | saint george
# Processing Record 44 of Set 3 | areosa
# Processing Record 45 of Set 3 | abu zabad
# Processing Record 46 of Set 3 | gamba
# Processing Record 47 of Set 3 | caravelas
# Processing Record 48 of Set 3 | abu kamal
# Processing Record 49 of Set 3 | brae
# Processing Record 50 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 4 | nizhniy baskunchak
# Processing Record 2 of Set 4 | hongjiang
# Processing Record 3 of Set 4 | port elizabeth
# Processing Record 4 of Set 4 | mount gambier
# Processing Record 5 of Set 4 | dawlatabad
# Processing Record 6 of Set 4 | vao
# Processing Record 7 of Set 4 | itoman
# Processing Record 8 of Set 4 | birjand
# Processing Record 9 of Set 4 | matranovak
# Processing Record 10 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 4 | gizo
# Processing Record 12 of Set 4 | sokolo
# Processing Record 13 of Set 4 | katangli
# Processing Record 14 of Set 4 | newport
# Processing Record 15 of Set 4 | baruun-urt
# Processing Record 16 of Set 4 | marica
# Processing Record 17 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 18 of Set 4 | mar del plata
# Processing Record 19 of Set 4 | bethel
# Processing Record 20 of Set 4 | te anau
# Processing Record 21 of Set 4 | walvis bay
# Processing Record 22 of Set 4 | olafsvik
# Processing Record 23 of Set 4 | sao filipe
# Processing Record 24 of Set 4 | honningsvag
# Processing Record 25 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 4 | katsuura
# Processing Record 27 of Set 4 | balykshi
# Processing Record 28 of Set 4 | north bend
# Processing Record 29 of Set 4 | cabo san lucas
# Processing Record 30 of Set 4 | deputatskiy
# Processing Record 31 of Set 4 | stoyba
# City not found. Skipping...
# Processing Record 32 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 4 | neckargemund
# Processing Record 34 of Set 4 | shalakusha
# Processing Record 35 of Set 4 | sulangan
# Processing Record 36 of Set 4 | nuuk
# Processing Record 37 of Set 4 | inhambane
# Processing Record 38 of Set 4 | magomeni
# Processing Record 39 of Set 4 | jipijapa
# Processing Record 40 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 4 | scottsbluff
# Processing Record 42 of Set 4 | dukat
# Processing Record 43 of Set 4 | richards bay
# Processing Record 44 of Set 4 | saint-augustin
# Processing Record 45 of Set 4 | guantanamo
# Processing Record 46 of Set 4 | maningrida
# Processing Record 47 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 4 | saldanha
# Processing Record 49 of Set 4 | ilulissat
# Processing Record 50 of Set 4 | grand gaube
# Processing Record 1 of Set 5 | lloydminster
# Processing Record 2 of Set 5 | mirabad
# Processing Record 3 of Set 5 | flin flon
# Processing Record 4 of Set 5 | khatanga
# Processing Record 5 of Set 5 | hofn
# Processing Record 6 of Set 5 | klaksvik
# Processing Record 7 of Set 5 | maniwaki
# Processing Record 8 of Set 5 | sragen
# Processing Record 9 of Set 5 | syava
# Processing Record 10 of Set 5 | valparaiso
# Processing Record 11 of Set 5 | touros
# Processing Record 12 of Set 5 | taoudenni
# Processing Record 13 of Set 5 | luena
# Processing Record 14 of Set 5 | paita
# Processing Record 15 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 16 of Set 5 | karachi
# Processing Record 17 of Set 5 | mahebourg
# Processing Record 18 of Set 5 | vestmanna
# Processing Record 19 of Set 5 | gambela
# Processing Record 20 of Set 5 | yining
# Processing Record 21 of Set 5 | narsaq
# Processing Record 22 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 5 | porto walter
# Processing Record 24 of Set 5 | lompoc
# Processing Record 25 of Set 5 | piacabucu
# Processing Record 26 of Set 5 | kimbe
# Processing Record 27 of Set 5 | cawayan
# Processing Record 28 of Set 5 | patuli
# Processing Record 29 of Set 5 | brigantine
# Processing Record 30 of Set 5 | tasiilaq
# Processing Record 31 of Set 5 | althofen
# Processing Record 32 of Set 5 | palmer
# Processing Record 33 of Set 5 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 34 of Set 5 | avera
# Processing Record 35 of Set 5 | gat
# Processing Record 36 of Set 5 | lovozero
# Processing Record 37 of Set 5 | poum
# Processing Record 38 of Set 5 | kangaatsiaq
# Processing Record 39 of Set 5 | xihe
# Processing Record 40 of Set 5 | bonthe
# Processing Record 41 of Set 5 | de-kastri
# Processing Record 42 of Set 5 | tiksi
# Processing Record 43 of Set 5 | sines
# Processing Record 44 of Set 5 | korem
# Processing Record 45 of Set 5 | ponta do sol
# Processing Record 46 of Set 5 | turukhansk
# Processing Record 47 of Set 5 | benjamin constant
# Processing Record 48 of Set 5 | lakatoro
# Processing Record 49 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 5 | gornyy
# Processing Record 1 of Set 6 | samana
# Processing Record 2 of Set 6 | neyshabur
# Processing Record 3 of Set 6 | tarbes
# Processing Record 4 of Set 6 | channel-port aux basques
# Processing Record 5 of Set 6 | mandalgovi
# Processing Record 6 of Set 6 | berlevag
# Processing Record 7 of Set 6 | flinders
# Processing Record 8 of Set 6 | conde
# Processing Record 9 of Set 6 | kidal
# Processing Record 10 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 6 | banjar
# Processing Record 12 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 6 | la tuque
# Processing Record 14 of Set 6 | padang
# Processing Record 15 of Set 6 | srednekolymsk
# Processing Record 16 of Set 6 | talnakh
# Processing Record 17 of Set 6 | tessalit
# Processing Record 18 of Set 6 | penzance
# Processing Record 19 of Set 6 | morehead
# Processing Record 20 of Set 6 | sibolga
# Processing Record 21 of Set 6 | bin qirdan
# Processing Record 22 of Set 6 | nehe
# Processing Record 23 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 24 of Set 6 | yarada
# Processing Record 25 of Set 6 | vanderhoof
# Processing Record 26 of Set 6 | necochea
# Processing Record 27 of Set 6 | puerto armuelles
# Processing Record 28 of Set 6 | mildura
# Processing Record 29 of Set 6 | cidreira
# Processing Record 30 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 31 of Set 6 | reguengos de monsaraz
# Processing Record 32 of Set 6 | meulaboh
# Processing Record 33 of Set 6 | vigrestad
# Processing Record 34 of Set 6 | denpasar
# Processing Record 35 of Set 6 | kalanchak
# Processing Record 36 of Set 6 | namibe
# Processing Record 37 of Set 6 | balkanabat
# Processing Record 38 of Set 6 | kajaani
# Processing Record 39 of Set 6 | narathiwat
# Processing Record 40 of Set 6 | garwolin
# Processing Record 41 of Set 6 | areia branca
# Processing Record 42 of Set 6 | bara
# Processing Record 43 of Set 6 | charagua
# Processing Record 44 of Set 6 | axim
# Processing Record 45 of Set 6 | merauke
# Processing Record 46 of Set 6 | shestakovo
# Processing Record 47 of Set 6 | miramar
# Processing Record 48 of Set 6 | middelburg
# Processing Record 49 of Set 6 | dicabisagan
# Processing Record 50 of Set 6 | srivilliputtur
# Processing Record 1 of Set 7 | ostrovnoy
# Processing Record 2 of Set 7 | port macquarie
# Processing Record 3 of Set 7 | alofi
# Processing Record 4 of Set 7 | el tigre
# Processing Record 5 of Set 7 | tabou
# Processing Record 6 of Set 7 | vila franca do campo
# Processing Record 7 of Set 7 | seddon
# Processing Record 8 of Set 7 | omaruru
# Processing Record 9 of Set 7 | leh
# Processing Record 10 of Set 7 | barcelona
# Processing Record 11 of Set 7 | luderitz
# Processing Record 12 of Set 7 | marzuq
# Processing Record 13 of Set 7 | lesnoy
# Processing Record 14 of Set 7 | murray bridge
# Processing Record 15 of Set 7 | korla
# Processing Record 16 of Set 7 | hinton
# Processing Record 17 of Set 7 | margate
# Processing Record 18 of Set 7 | verkhniye kigi
# Processing Record 19 of Set 7 | honefoss
# Processing Record 20 of Set 7 | college
# Processing Record 21 of Set 7 | port moresby
# Processing Record 22 of Set 7 | severo-kurilsk
# Processing Record 23 of Set 7 | hede
# Processing Record 24 of Set 7 | akdepe
# Processing Record 25 of Set 7 | belaya gora
# Processing Record 26 of Set 7 | mount isa
# Processing Record 27 of Set 7 | acarau
# Processing Record 28 of Set 7 | moerai
# Processing Record 29 of Set 7 | jacqueville
# Processing Record 30 of Set 7 | cherskiy
# Processing Record 31 of Set 7 | torbay
# Processing Record 32 of Set 7 | kapit
# Processing Record 33 of Set 7 | kiunga
# Processing Record 34 of Set 7 | svetlogorsk
# Processing Record 35 of Set 7 | barranca
# Processing Record 36 of Set 7 | soyo
# Processing Record 37 of Set 7 | matara
# Processing Record 38 of Set 7 | bridlington
# Processing Record 39 of Set 7 | broken hill
# Processing Record 40 of Set 7 | tutoia
# Processing Record 41 of Set 7 | pilot butte
# Processing Record 42 of Set 7 | insar
# Processing Record 43 of Set 7 | aleksandrovskiy zavod
# Processing Record 44 of Set 7 | takoradi
# Processing Record 45 of Set 7 | sinnamary
# Processing Record 46 of Set 7 | asau
# Processing Record 47 of Set 7 | severnyy
# Processing Record 48 of Set 7 | isangel
# Processing Record 49 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 50 of Set 7 | forssa
# Processing Record 1 of Set 8 | hay river
# Processing Record 2 of Set 8 | half moon bay
# Processing Record 3 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 8 | prainha
# Processing Record 5 of Set 8 | darnah
# Processing Record 6 of Set 8 | poronaysk
# Processing Record 7 of Set 8 | eastbourne
# Processing Record 8 of Set 8 | pisco
# Processing Record 9 of Set 8 | shache
# Processing Record 10 of Set 8 | terra rica
# Processing Record 11 of Set 8 | murwara
# Processing Record 12 of Set 8 | kabinda
# Processing Record 13 of Set 8 | ati
# Processing Record 14 of Set 8 | srisailam
# Processing Record 15 of Set 8 | gemlik
# Processing Record 16 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 8 | hervey bay
# Processing Record 18 of Set 8 | lensk
# Processing Record 19 of Set 8 | zhovtneve
# Processing Record 20 of Set 8 | cap malheureux
# Processing Record 21 of Set 8 | seoul
# Processing Record 22 of Set 8 | nichinan
# Processing Record 23 of Set 8 | grindavik
# Processing Record 24 of Set 8 | trento
# Processing Record 25 of Set 8 | sitka
# Processing Record 26 of Set 8 | nouakchott
# Processing Record 27 of Set 8 | dauriya
# Processing Record 28 of Set 8 | biryusinsk
# Processing Record 29 of Set 8 | palaikastron
# Processing Record 30 of Set 8 | breves
# Processing Record 31 of Set 8 | bayir
# Processing Record 32 of Set 8 | menongue
# Processing Record 33 of Set 8 | ahipara
# Processing Record 34 of Set 8 | sungaipenuh
# Processing Record 35 of Set 8 | pitimbu
# Processing Record 36 of Set 8 | marawi
# Processing Record 37 of Set 8 | charters towers
# Processing Record 38 of Set 8 | tanout
# Processing Record 39 of Set 8 | japura
# Processing Record 40 of Set 8 | port hedland
# Processing Record 41 of Set 8 | ketchikan
# Processing Record 42 of Set 8 | bathsheba
# Processing Record 43 of Set 8 | nishihara
# Processing Record 44 of Set 8 | char bhadrasan
# Processing Record 45 of Set 8 | tocopilla
# Processing Record 46 of Set 8 | fassuta
# Processing Record 47 of Set 8 | ancud
# Processing Record 48 of Set 8 | karaton
# Processing Record 49 of Set 8 | bijar
# Processing Record 50 of Set 8 | felidhoo
# City not found. Skipping...
# Processing Record 1 of Set 9 | bossangoa
# Processing Record 2 of Set 9 | develi
# Processing Record 3 of Set 9 | faya
# Processing Record 4 of Set 9 | krasnovishersk
# Processing Record 5 of Set 9 | rio gallegos
# Processing Record 6 of Set 9 | kavaratti
# Processing Record 7 of Set 9 | tautira
# Processing Record 8 of Set 9 | besikduzu
# Processing Record 9 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 9 | aksarayskiy
# Processing Record 11 of Set 9 | tarauaca
# Processing Record 12 of Set 9 | yumen
# Processing Record 13 of Set 9 | preobrazheniye
# Processing Record 14 of Set 9 | cayenne
# Processing Record 15 of Set 9 | daru
# Processing Record 16 of Set 9 | guarapari
# Processing Record 17 of Set 9 | mahajanga
# Processing Record 18 of Set 9 | kahului
# Processing Record 19 of Set 9 | yangambi
# Processing Record 20 of Set 9 | grand baie
# Processing Record 21 of Set 9 | adrar
# Processing Record 22 of Set 9 | libertador general san martin
# Processing Record 23 of Set 9 | ugoofaaru
# Processing Record 24 of Set 9 | santa maria
# Processing Record 25 of Set 9 | bronnoysund
# Processing Record 26 of Set 9 | buin
# Processing Record 27 of Set 9 | iqaluit
# Processing Record 28 of Set 9 | saint anthony
# Processing Record 29 of Set 9 | cockburn town
# Processing Record 30 of Set 9 | mapulo
# Processing Record 31 of Set 9 | mangrol
# Processing Record 32 of Set 9 | deniliquin
# Processing Record 33 of Set 9 | lata
# Processing Record 34 of Set 9 | haines junction
# Processing Record 35 of Set 9 | sao joao da barra
# Processing Record 36 of Set 9 | sept-iles
# Processing Record 37 of Set 9 | kavieng
# Processing Record 38 of Set 9 | thinadhoo
# Processing Record 39 of Set 9 | auki
# Processing Record 40 of Set 9 | george
# Processing Record 41 of Set 9 | bosaso
# Processing Record 42 of Set 9 | peranamallur
# Processing Record 43 of Set 9 | espirito santo do pinhal
# Processing Record 44 of Set 9 | naze
# Processing Record 45 of Set 9 | ginir
# Processing Record 46 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 47 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 48 of Set 9 | arlit
# Processing Record 49 of Set 9 | carndonagh
# Processing Record 50 of Set 9 | tartagal
# Processing Record 1 of Set 10 | hobyo
# Processing Record 2 of Set 10 | cabedelo
# Processing Record 3 of Set 10 | helsingborg
# Processing Record 4 of Set 10 | ulagan
# Processing Record 5 of Set 10 | kudahuvadhoo
# Processing Record 6 of Set 10 | narasannapeta
# Processing Record 7 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 10 | yerbogachen
# Processing Record 9 of Set 10 | poya
# Processing Record 10 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 11 of Set 10 | bubaque
# Processing Record 12 of Set 10 | fukue
# Processing Record 13 of Set 10 | cuxhaven
# Processing Record 14 of Set 10 | watertown
# Processing Record 15 of Set 10 | aykino
# Processing Record 16 of Set 10 | svetlyy
# Processing Record 17 of Set 10 | vestmannaeyjar
# Processing Record 18 of Set 10 | polyarnyy
# Processing Record 19 of Set 10 | alice springs
# Processing Record 20 of Set 10 | ferme-neuve
# Processing Record 21 of Set 10 | sheridan
# Processing Record 22 of Set 10 | nago
# Processing Record 23 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 24 of Set 10 | kachug
# Processing Record 25 of Set 10 | ushtobe
# Processing Record 26 of Set 10 | zima
# Processing Record 27 of Set 10 | qaqortoq
# Processing Record 28 of Set 10 | kijaba
# City not found. Skipping...
# Processing Record 29 of Set 10 | pemangkat
# Processing Record 30 of Set 10 | havelock
# Processing Record 31 of Set 10 | hukuntsi
# Processing Record 32 of Set 10 | rawson
# Processing Record 33 of Set 10 | goderich
# Processing Record 34 of Set 10 | nome
# Processing Record 35 of Set 10 | hambantota
# Processing Record 36 of Set 10 | sumbe
# Processing Record 37 of Set 10 | nizwa
# Processing Record 38 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 10 | mahanoro
# Processing Record 40 of Set 10 | namatanai
# Processing Record 41 of Set 10 | salinopolis
# Processing Record 42 of Set 10 | launceston
# Processing Record 43 of Set 10 | adeje
# Processing Record 44 of Set 10 | pelham
# Processing Record 45 of Set 10 | fortuna
# Processing Record 46 of Set 10 | pimenta bueno
# Processing Record 47 of Set 10 | srandakan
# Processing Record 48 of Set 10 | harper
# Processing Record 49 of Set 10 | pizarro
# Processing Record 50 of Set 10 | jinchang
# Processing Record 1 of Set 11 | constitucion
# Processing Record 2 of Set 11 | shelburne
# Processing Record 3 of Set 11 | jumla
# Processing Record 4 of Set 11 | hemnesberget
# Processing Record 5 of Set 11 | skiros
# City not found. Skipping...
# Processing Record 6 of Set 11 | warrnambool
# Processing Record 7 of Set 11 | nouadhibou
# Processing Record 8 of Set 11 | roald
# Processing Record 9 of Set 11 | thurso
# Processing Record 10 of Set 11 | port-de-paix
# City not found. Skipping...
# Processing Record 11 of Set 11 | shimoda
# Processing Record 12 of Set 11 | chino valley
# Processing Record 13 of Set 11 | indian head
# Processing Record 14 of Set 11 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 15 of Set 11 | banikoara
# Processing Record 16 of Set 11 | vardo
# Processing Record 17 of Set 11 | chimbote
# Processing Record 18 of Set 11 | champoton
# Processing Record 19 of Set 11 | takefu
# Processing Record 20 of Set 11 | clyde river
# Processing Record 21 of Set 11 | horizontina
# Processing Record 22 of Set 11 | manado
# Processing Record 23 of Set 11 | abrau-dyurso
# Processing Record 24 of Set 11 | ardistan
# City not found. Skipping...
# Processing Record 25 of Set 11 | innisfail
# Processing Record 26 of Set 11 | bossembele
# City not found. Skipping...
# Processing Record 27 of Set 11 | souris
# Processing Record 28 of Set 11 | green valley
# Processing Record 29 of Set 11 | lukovetskiy
# Processing Record 30 of Set 11 | dengzhou
# Processing Record 31 of Set 11 | iaciara
# Processing Record 32 of Set 11 | henties bay
# Processing Record 33 of Set 11 | honiara
# Processing Record 34 of Set 11 | ko samui
# Processing Record 35 of Set 11 | vartej
# Processing Record 36 of Set 11 | ramanuj ganj
# Processing Record 37 of Set 11 | lyantonde
# Processing Record 38 of Set 11 | shipitsyno
# Processing Record 39 of Set 11 | peace river
# Processing Record 40 of Set 11 | makarov
# Processing Record 41 of Set 11 | hamilton
# Processing Record 42 of Set 11 | vila velha
# Processing Record 43 of Set 11 | coari
# Processing Record 44 of Set 11 | kalianget
# Processing Record 45 of Set 11 | camalu
# Processing Record 46 of Set 11 | yabelo
# Processing Record 47 of Set 11 | portland
# Processing Record 48 of Set 11 | general roca
# Processing Record 49 of Set 11 | urumqi
# Processing Record 50 of Set 11 | laukaa
# Processing Record 1 of Set 12 | horia
# Processing Record 2 of Set 12 | kathmandu
# Processing Record 3 of Set 12 | rognan
# Processing Record 4 of Set 12 | aswan
# Processing Record 5 of Set 12 | noumea
# Processing Record 6 of Set 12 | romitan
# Processing Record 7 of Set 12 | leningradskiy
# Processing Record 8 of Set 12 | provideniya
# Processing Record 9 of Set 12 | byron bay
# Processing Record 10 of Set 12 | ust-omchug
# Processing Record 11 of Set 12 | huangpi
# Processing Record 12 of Set 12 | oktyabrskiy
# Processing Record 13 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 14 of Set 12 | broome
# Processing Record 15 of Set 12 | prince rupert
# Processing Record 16 of Set 12 | nioro
# Processing Record 17 of Set 12 | san isidro
# Processing Record 18 of Set 12 | jiayuguan
# Processing Record 19 of Set 12 | oistins
# Processing Record 20 of Set 12 | alta floresta
# Processing Record 21 of Set 12 | cascais
# Processing Record 22 of Set 12 | laguna
# Processing Record 23 of Set 12 | oga
# Processing Record 24 of Set 12 | galle
# Processing Record 25 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 26 of Set 12 | pangnirtung
# Processing Record 27 of Set 12 | dubbo
# Processing Record 28 of Set 12 | hirara
# Processing Record 29 of Set 12 | carutapera
# Processing Record 30 of Set 12 | manaure
# Processing Record 31 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 32 of Set 12 | bilma
# Processing Record 33 of Set 12 | coruripe
# Processing Record 34 of Set 12 | yar-sale
# Processing Record 35 of Set 12 | kyabe
# Processing Record 36 of Set 12 | sudak
# Processing Record 37 of Set 12 | moose factory
# Processing Record 38 of Set 12 | oviedo
# Processing Record 39 of Set 12 | erzin
# Processing Record 40 of Set 12 | soe
# Processing Record 41 of Set 12 | sola
# Processing Record 42 of Set 12 | yeppoon
# Processing Record 43 of Set 12 | chabahar
# Processing Record 44 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 45 of Set 12 | loralai
# Processing Record 46 of Set 12 | dongsheng
# Processing Record 47 of Set 12 | salalah
# Processing Record 48 of Set 12 | westport
# Processing Record 49 of Set 12 | juruti
# Processing Record 50 of Set 12 | chihuahua
# Processing Record 1 of Set 13 | vangaindrano
# Processing Record 2 of Set 13 | sorland
# Processing Record 3 of Set 13 | xichang
# Processing Record 4 of Set 13 | tahta
# Processing Record 5 of Set 13 | kaseda
# Processing Record 6 of Set 13 | husavik
# Processing Record 7 of Set 13 | san cristobal
# Processing Record 8 of Set 13 | copiapo
# Processing Record 9 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 13 | kualakapuas
# Processing Record 11 of Set 13 | naryan-mar
# Processing Record 12 of Set 13 | leland
# Processing Record 13 of Set 13 | arman
# Processing Record 14 of Set 13 | karpinsk
# Processing Record 15 of Set 13 | mount barker
# Processing Record 16 of Set 13 | butembo
# Processing Record 17 of Set 13 | yirol
# City not found. Skipping...
# Processing Record 18 of Set 13 | sigli
# Processing Record 19 of Set 13 | coihaique
# Processing Record 20 of Set 13 | murgab
# Processing Record 21 of Set 13 | conceicao do mato dentro
# Processing Record 22 of Set 13 | moree
# Processing Record 23 of Set 13 | vestbygda
# City not found. Skipping...
# Processing Record 24 of Set 13 | odessa
# Processing Record 25 of Set 13 | tayturka
# Processing Record 26 of Set 13 | mayumba
# Processing Record 27 of Set 13 | ploemeur
# Processing Record 28 of Set 13 | dossor
# Processing Record 29 of Set 13 | kon tum
# Processing Record 30 of Set 13 | neulengbach
# Processing Record 31 of Set 13 | hovd
# Processing Record 32 of Set 13 | kuala krai
# City not found. Skipping...
# Processing Record 33 of Set 13 | champerico
# Processing Record 34 of Set 13 | umm lajj
# Processing Record 35 of Set 13 | bhadrachalam
# Processing Record 36 of Set 13 | challans
# Processing Record 37 of Set 13 | polovinnoye
# Processing Record 38 of Set 13 | dakoro
# Processing Record 39 of Set 13 | xiuyan
# Processing Record 40 of Set 13 | shediac
# Processing Record 41 of Set 13 | northam
# Processing Record 42 of Set 13 | mbandaka
# Processing Record 43 of Set 13 | balilihan
# Processing Record 44 of Set 13 | kosonsoy
# Processing Record 45 of Set 13 | khonsa
# Processing Record 46 of Set 13 | fenoarivo atsinanana
# Processing Record 47 of Set 13 | kirakira
# Processing Record 48 of Set 13 | samarai
# Processing Record 49 of Set 13 | mercedes
# Processing Record 50 of Set 13 | buraydah
# Processing Record 1 of Set 14 | muisne
# Processing Record 2 of Set 14 | pauini
# Processing Record 3 of Set 14 | trindade
# Processing Record 4 of Set 14 | atsiki
# City not found. Skipping...
# Processing Record 5 of Set 14 | pacifica
# Processing Record 6 of Set 14 | gravdal
# Processing Record 7 of Set 14 | krasnorechenskiy
# Processing Record 8 of Set 14 | dandong
# Processing Record 9 of Set 14 | tiznit
# Processing Record 10 of Set 14 | namwala
# Processing Record 11 of Set 14 | san-pedro
# Processing Record 12 of Set 14 | eureka
# Processing Record 13 of Set 14 | baker city
# Processing Record 14 of Set 14 | ulladulla
# Processing Record 15 of Set 14 | makat
# Processing Record 16 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 14 | carlos chagas
# Processing Record 18 of Set 14 | scottsburgh
# City not found. Skipping...
# Processing Record 19 of Set 14 | anushavan
# Processing Record 20 of Set 14 | kerteh
# City not found. Skipping...
# Processing Record 21 of Set 14 | sapao
# City not found. Skipping...
# Processing Record 22 of Set 14 | kyra
# Processing Record 23 of Set 14 | emerald
# Processing Record 24 of Set 14 | tashara
# Processing Record 25 of Set 14 | adelaide
# Processing Record 26 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 14 | mitchell
# Processing Record 28 of Set 14 | biltine
# Processing Record 29 of Set 14 | chaguanas
# Processing Record 30 of Set 14 | halifax
# Processing Record 31 of Set 14 | kieta
# Processing Record 32 of Set 14 | dudinka
# Processing Record 33 of Set 14 | kargasok
# Processing Record 34 of Set 14 | okha
# Processing Record 35 of Set 14 | bonavista
# Processing Record 36 of Set 14 | saint-joseph
# Processing Record 37 of Set 14 | barcelos
# Processing Record 38 of Set 14 | malanje
# Processing Record 39 of Set 14 | abha
# Processing Record 40 of Set 14 | port-cartier
# Processing Record 41 of Set 14 | avigliana
# Processing Record 42 of Set 14 | siirt
# Processing Record 43 of Set 14 | tura
# Processing Record 44 of Set 14 | beauchamps
# Processing Record 45 of Set 14 | kataysk
# Processing Record 46 of Set 14 | wasilla
# Processing Record 47 of Set 14 | pudozh
# Processing Record 48 of Set 14 | boyabat
# Processing Record 49 of Set 14 | derzhavinsk
# Processing Record 50 of Set 14 | comodoro rivadavia
# Processing Record 1 of Set 15 | nacozari
# Processing Record 2 of Set 15 | marsabit
# Processing Record 3 of Set 15 | verkhoyansk
# Processing Record 4 of Set 15 | ambilobe
# Processing Record 5 of Set 15 | ponta delgada
# Processing Record 6 of Set 15 | vallenar
# Processing Record 7 of Set 15 | kushmurun
# Processing Record 8 of Set 15 | troitsko-pechorsk
# Processing Record 9 of Set 15 | oktyabrskoye
# Processing Record 10 of Set 15 | biak
# Processing Record 11 of Set 15 | kenai
# Processing Record 12 of Set 15 | sibu
# Processing Record 13 of Set 15 | lufkin
# Processing Record 14 of Set 15 | fort nelson
# Processing Record 15 of Set 15 | dahuk
# Processing Record 16 of Set 15 | paamiut
# Processing Record 17 of Set 15 | maragogi
# Processing Record 18 of Set 15 | lufilufi
# Processing Record 19 of Set 15 | kawhia
# Processing Record 20 of Set 15 | saint-georges
# Processing Record 21 of Set 15 | saint pete beach
# Processing Record 22 of Set 15 | kysyl-syr
# Processing Record 23 of Set 15 | roseburg
# Processing Record 24 of Set 15 | muli
# Processing Record 25 of Set 15 | bam
# Processing Record 26 of Set 15 | ahumada
# City not found. Skipping...
# Processing Record 27 of Set 15 | jiazi
# Processing Record 28 of Set 15 | quatre cocos
# Processing Record 29 of Set 15 | laredo
# Processing Record 30 of Set 15 | xinyu
# Processing Record 31 of Set 15 | moctezuma
# Processing Record 32 of Set 15 | villa oliva
# City not found. Skipping...
# Processing Record 33 of Set 15 | vredendal
# Processing Record 34 of Set 15 | ust-kulom
# Processing Record 35 of Set 15 | iquitos
# Processing Record 36 of Set 15 | oyama
# Processing Record 37 of Set 15 | guaraniacu
# Processing Record 38 of Set 15 | guerrero negro
# Processing Record 39 of Set 15 | manyana
# Processing Record 40 of Set 15 | jaipur hat
# City not found. Skipping...
# Processing Record 41 of Set 15 | zhicheng
# Processing Record 42 of Set 15 | camopi
# Processing Record 43 of Set 15 | riyadh
# Processing Record 44 of Set 15 | dingle
# Processing Record 45 of Set 15 | massaguet
# Processing Record 46 of Set 15 | novoagansk
# Processing Record 47 of Set 15 | kamachumu
# Processing Record 48 of Set 15 | kigoma
# Processing Record 49 of Set 15 | port lincoln
# Processing Record 50 of Set 15 | rio grande
# Processing Record 1 of Set 16 | bambanglipuro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Get the number of the cities
len(city_data)
# Out:
# 686

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Busselton -33.6500  115.3333     53.04        74          80
# 1       Ashland  40.8167  -82.2665     80.64        90          99
# 2  Longyearbyen  78.2186   15.6401     40.84        93          75
# 3   Kattivakkam  13.2167   80.3167     84.29        77         100
# 4      Ngunguru -35.6167  174.5000     43.16        79          48
# 5     Upernavik  72.7868  -56.1549     40.91        83         100
# 6  Komsomolskiy  40.4272   71.7189     81.32        34          81
# 7        Atuona  -9.8000 -139.0333     77.52        70          44
# 8       Aklavik  68.2191 -135.0107     72.32        43          81
# 9      Thompson  55.7435  -97.8558     62.76        55          75
#
#    Wind Speed Current Description Country                 Date
# 0       15.57       broken clouds      AU  2021-07-13 16:57:06
# 1       14.85     overcast clouds      US  2021-07-13 16:57:06
# 2       10.36       broken clouds      SJ  2021-07-13 16:57:06
# 3       10.76          light rain      IN  2021-07-13 16:57:07
# 4        8.34    scattered clouds      NZ  2021-07-13 16:57:07
# 5        7.87          light rain      GL  2021-07-13 16:57:07
# 6        6.91       broken clouds      UZ  2021-07-13 16:57:08
# 7       24.25    scattered clouds      PF  2021-07-13 16:57:08
# 8       16.58       broken clouds      CA  2021-07-13 16:57:08
# 9        8.05       broken clouds      CA  2021-07-13 16:57:09

# %%
#have a sytax error here  to fix still  
#Organize the columns in the DataFrame.
city_data__no_date_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']]
city_data__no_date_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Busselton      AU -33.6500  115.3333     53.04        74          80
# 1       Ashland      US  40.8167  -82.2665     80.64        90          99
# 2  Longyearbyen      SJ  78.2186   15.6401     40.84        93          75
# 3   Kattivakkam      IN  13.2167   80.3167     84.29        77         100
# 4      Ngunguru      NZ -35.6167  174.5000     43.16        79          48
# 5     Upernavik      GL  72.7868  -56.1549     40.91        83         100
# 6  Komsomolskiy      UZ  40.4272   71.7189     81.32        34          81
# 7        Atuona      PF  -9.8000 -139.0333     77.52        70          44
# 8       Aklavik      CA  68.2191 -135.0107     72.32        43          81
# 9      Thompson      CA  55.7435  -97.8558     62.76        55          75
#
#    Wind Speed Current Description
# 0       15.57       broken clouds
# 1       14.85     overcast clouds
# 2       10.36       broken clouds
# 3       10.76          light rain
# 4        8.34    scattered clouds
# 5        7.87          light rain
# 6        6.91       broken clouds
# 7       24.25    scattered clouds
# 8       16.58       broken clouds
# 9        8.05       broken clouds

# %%
#make this active after sure I know where it's going and its' right  I have not run this yet. check with JUSTIn first
# Create and export the final Data Frame into a CSV
##city_data__no_date_df.to_csv("WeatherPy_Database.csv", index_label="City_ID")

# %%
#csv files feeds into activity 2 and 3
